# %%
using RCall
using DataFrames, DataFramesMeta
using CSV
using DataVoyager
using AMLPipelineBase
using AutoMLPipeline
using Statistics

using Distributed
nprocs() == 1 && addprocs(;exeflags="--project")
@everywhere begin
    using AutoMLPipeline
    using DataFrames
    using Statistics
end

ENV["LINES"] = 10
ENV["COLUMNS"]=10000;

# %% [markdown]
# ### Load Covid Data
#
# source: https://covid.ourworldindata.org/data/owid-covid-data.csv

# %%
function getdata()
   df = CSV.read("../data/owid-covid-data.csv",DataFrame);
   @rput df
   R"""
      library(tidyverse)
      library(mice)

      sdf = df %>% group_by(location) %>% 
      summarise(
        mnewcases = mean(new_cases,na.rm=T),
        mnewdeaths = mean(new_deaths,na.rm=T),
        mpopulation = mean(population,na.rm=T),
        mcardio = mean(cardiovasc_death_rate,na.rm=T),
        mdiab = mean(diabetes_prevalence,na.rm=T),
        mhandwash = mean(handwashing_facilities,na.rm=T),
        mhbed = mean(hospital_beds_per_thousand,na.rm=T),
        mpatient = mean(hosp_patients,na.rm=T),
        madmission = mean(weekly_hosp_admissions,na.rm=T),
        mhdi = mean(human_development_index,na.rm=T),
        mle = mean(life_expectancy,na.rm=T)
      ) 
      imputed=mice(sdf,meth='sample',printFlag=F)
      complete(imputed)
   """ |> rcopy
end;

# %%
dfimp = getdata()
X = dfimp[:,Not([:location,:mnewdeaths])]
Y = dfimp.mnewdeaths;
# Out:
# ┌ Warning: RCall.jl: `summarise()` ungrouping output (override with `.groups` argument)
# └ @ RCall /Users/ppalmes/.julia/packages/RCall/eRsxl/src/io.jl:160
# ┌ Warning: RCall.jl: Warning: Number of logged events: 1
# └ @ RCall /Users/ppalmes/.julia/packages/RCall/eRsxl/src/io.jl:160

# %% [markdown]
# ### Baseline performance using Random Forest

# %%
R"""
library(caret)

fitControl <- trainControl(method = "repeatedcv",number = 5)
rfcaret <- train($X,$Y, method = "rf",trControl = fitControl)
rfcaret
"""
# Out:
# RObject{VecSxp}
# Random Forest
#
# 190 samples
#  10 predictor
#
# No pre-processing
# Resampling: Cross-Validated (5 fold, repeated 1 times)
# Summary of sample sizes: 151, 153, 153, 151, 152
# Resampling results across tuning parameters:
#
#   mtry  RMSE      Rsquared   MAE
#    2    61.02000  0.6183065  23.48515
#    6    51.84704  0.6960727  17.08586
#   10    52.35961  0.7024063  15.34290
#
# RMSE was used to select the optimal model using the smallest value.
# The final value used for the model was mtry = 6.

# %% [markdown]
# #### NOTE: Best RMSE is around 44

# %% [markdown]
# ### Use AutoML to find better RMSE by searching optimal pipelines

# %%
using AutoMLPipeline

#### Decomposition
pca = SKPreprocessor("PCA")
fa  = SKPreprocessor("FactorAnalysis")
ica = SKPreprocessor("FastICA")

#### Scaler 
rb   = SKPreprocessor("RobustScaler")
pt   = SKPreprocessor("PowerTransformer")
norm = SKPreprocessor("Normalizer")
mx   = SKPreprocessor("MinMaxScaler")
mstd    = SKPreprocessor("StandardScaler")

#### categorical preprocessing
ohe = OneHotEncoder()
noop = Identity(Dict(:name=>"Noop"))

#### Column selector
catf = CatFeatureSelector()
numf = NumFeatureSelector()

#### Learners
sk_rf       = SKLearner("RandomForestRegressor")
sk_gb       = SKLearner("GradientBoostingRegressor")
sk_svr      = SKLearner("SVR")
sk_gp       = SKLearner("GaussianProcessRegressor")
sk_ard      = SKLearner("ARDRegression")
jl_rf       = RandomForest()
jl_vote     = VoteEnsemble()
jl_stack    = StackEnsemble()
jl_best     = BestLearner();

# %%
plsvc = @pipeline  numf |> rb |> sk_svr
pred = fit_transform!(plsvc,X,Y)
# Out:
# 190-element Array{Float64,1}:
#  1.545499224143862
#  1.6262378864793403
#  4.359239387528533
#  ⋮
#  1.0221421504968689
#  0.8491585976134459

# %%
@everywhere rmse(x,y) = sqrt(mean((x .- y).^2))

plsvc = @pipeline ((numf |> rb |> ica )) |> sk_gb
crossvalidate(plsvc,X,Y,rmse)
# Out:
# fold: 1, 6.743727618927776
# fold: 2, 11.412466967613046
# fold: 3, 18.20752085294149
# fold: 4, 33.41345125291111
# fold: 5, 74.08810729497955
# fold: 6, 93.00217981052387
# fold: 7, 38.997278580339966
# fold: 8, 62.49401848294808
# fold: 9, 8.584518289085185
# fold: 10, 64.16899323574091
# errors: 0
# (mean = 41.1112262386011, std = 30.692855481251648, folds = 10, errors = 0)

# %% [markdown]
# ### Parallel algo to search optimal combinations of preprocessing elements and learner

# %%
function prpsearch(X,Y)
    learners = [sk_rf,sk_gb,sk_svr,sk_ard,sk_gp,jl_rf];
    scalers = [rb,pt,norm,mx,mstd,noop];
    extractors = [ica,noop];
    dftable = @sync @distributed (vcat) for lr in learners
    @distributed (vcat) for sc in scalers
     @distributed (vcat) for xt  in extractors
          pipe  = @pipeline (numf |> sc |> xt)  |> lr
          scn   = sc.name[1:end - 4]; xtn = xt.name[1:end - 4]; lrn = lr.name[1:end - 4]
          pname = "$scn |> $xtn |> $lrn"
          ptime = @elapsed begin
             mean, sd, kfold, _ = crossvalidate(pipe, X, Y, rmse, 5,true)
          end
          DataFrame(pipeline=pname, mean=mean, sd=sd, time=ptime, folds=kfold)
        end
     end
    end
    sort!(dftable, :mean, rev=false);
    dftable
end
# Out:
# prpsearch (generic function with 1 method)

# %%
ENV["LINES"]=1000

runtime = @elapsed begin
    dfres = prpsearch(X,Y)
end;
serialtime = dfres.time |> sum;

(serialtime = "$(round(serialtime / 60.0)) minutes", 
    paralleltime = "$(round(runtime)) seconds")
# Out:
#       From worker 4:	fold: 1, 55.618515824596095
#       From worker 4:	fold: 2, 117.07759225697248
#       From worker 5:	fold: 1, 84.96770590460763
#       From worker 3:	fold: 1, 50.390389333583684
#       From worker 4:	fold: 3, 65.74017868600878
#       From worker 6:	fold: 1, 48.45460977174831
#       From worker 7:	fold: 1, 21.74677563821194
#       From worker 4:	fold: 4, 38.49457713236518
#       From worker 5:	fold: 2, 40.31302851256214
#       From worker 6:	fold: 2, 903.580332927692
#       From worker 7:	fold: 1, 176.26646773606478
#       From worker 5:	fold: 3, 47.98734099496711
#       From worker 7:	fold: 2, 43.7269520324854
#       From worker 4:	fold: 5, 149.37835777658435
#       From worker 6:	fold: 3, 212.45898992586095
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 63.35747514525789
#       From worker 7:	fold: 3, 83.36026580487345
#       From worker 6:	fold: 4, 67.07236700024602
#       From worker 7:	fold: 4, 62.76969491024395
#       From worker 5:	fold: 4, 12.899674727306195
#       From worker 7:	fold: 5, 32.25330589694737
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 128.8596436570169
#       From worker 6:	fold: 5, 1182.5493168801158
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 172.0645826128189
#       From worker 5:	fold: 5, 12.400006256835182
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 13.831482900756182
#       From worker 5:	fold: 2, 153.96069001747466
#       From worker 5:	fold: 3, 90.98680333895544
#       From worker 6:	fold: 2, 11.486535721468012
#       From worker 5:	fold: 4, 32.89377600362386
#       From worker 4:	fold: 2, 97.56061393172301
#       From worker 6:	fold: 3, 28.534427869596023
#       From worker 3:	fold: 2, 24.036414847151317
#       From worker 6:	fold: 4, 71.93461841572712
#       From worker 2:	fold: 1, 22.114815407885796
#       From worker 5:	fold: 5, 107.88478099786126
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 37.27931009192241
#       From worker 3:	fold: 3, 155.6381369678202
#       From worker 7:	fold: 2, 40.27269448772203
#       From worker 3:	fold: 4, 13.842538337744454
#       From worker 4:	fold: 3, 97.24112015289985
#       From worker 6:	fold: 5, 95.26328393223581
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 23.586075844923727
#       From worker 3:	fold: 5, 26.53482554070164
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 89.9426057413949
#       From worker 5:	fold: 2, 37.01530252636089
#       From worker 4:	fold: 4, 34.973925456258044
#       From worker 6:	fold: 2, 97.99131882670055
#       From worker 7:	fold: 3, 39.8489987211225
#       From worker 5:	fold: 3, 92.68753738767734
#       From worker 3:	fold: 2, 51.93544887461305
#       From worker 7:	fold: 4, 20.267666839089486
#       From worker 4:	fold: 5, 134.48440135792035
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 74.79597683328636
#       From worker 6:	fold: 3, 16.52556034493317
#       From worker 5:	fold: 4, 46.35945869403145
#       From worker 4:	fold: 2, 160.80858536701518
#       From worker 3:	fold: 3, 61.337052864706315
#       From worker 4:	fold: 3, 53.04442989158492
#       From worker 7:	fold: 5, 44.16556083526986
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 46.39843470067319
#       From worker 4:	fold: 4, 39.790698592072225
#       From worker 6:	fold: 4, 30.280406801514808
#       From worker 7:	fold: 2, 29.161498982053423
#       From worker 5:	fold: 5, 12.535110857613407
#       From worker 5:	errors: 0
#       From worker 4:	fold: 5, 129.91598103845155
#       From worker 5:	fold: 1, 46.06508856461273
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 36.24581233892692
#       From worker 7:	fold: 3, 100.66253250695195
#       From worker 5:	fold: 2, 24.406815966596195
#       From worker 4:	fold: 2, 23.483750304824373
#       From worker 4:	fold: 3, 51.132848392631736
#       From worker 3:	fold: 4, 121.27828513019705
#       From worker 5:	fold: 3, 90.2388432334007
#       From worker 7:	fold: 4, 33.52565368121992
#       From worker 4:	fold: 4, 31.305092976802662
#       From worker 6:	fold: 5, 63.68082981876184
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 42.59780554844855
#       From worker 4:	fold: 5, 9.25439319184499
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 1361.2626727023153
#       From worker 5:	fold: 4, 24.612183422833787
#       From worker 4:	fold: 2, 1124.564710662765
#       From worker 7:	fold: 5, 27.68899251122589
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 34.63747361797463
#       From worker 6:	fold: 2, 44.119748853263545
#       From worker 7:	fold: 2, 32.72742475899012
#       From worker 5:	fold: 5, 34.0974575103653
#       From worker 5:	errors: 0
#       From worker 4:	fold: 3, 1196.154985599212
#       From worker 5:	fold: 1, 46.11086692471597
#       From worker 6:	fold: 3, 17.989241410452696
#       From worker 7:	fold: 3, 29.60075880231626
#       From worker 5:	fold: 2, 1082.3803340444429
#       From worker 4:	fold: 4, 38.5747288812955
#       From worker 4:	fold: 5, 47.218343018160056
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 48.96939395328956
#       From worker 5:	fold: 3, 364.0018833048477
#       From worker 3:	fold: 5, 21.83677334778429
#       From worker 7:	fold: 4, 8.757153981062439
#       From worker 3:	errors: 0
#       From worker 4:	fold: 2, 60.24844434486792
#       From worker 3:	fold: 1, 16.859613834312157
#       From worker 6:	fold: 4, 59.592699910281965
#       From worker 2:	fold: 2, 53.42795583248821
#       From worker 5:	fold: 4, 652.2927040883768
#       From worker 4:	fold: 3, 44.39078768997801
#       From worker 5:	fold: 5, 67.72830753361835
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 41.32694772862054
#       From worker 5:	fold: 2, 54.61656772660829
#       From worker 3:	fold: 2, 114.95313635557957
#       From worker 4:	fold: 4, 32.540787074953904
#       From worker 7:	fold: 5, 49.49318369810196
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 37.57096291921948
#       From worker 5:	fold: 3, 56.952542547805415
#       From worker 3:	fold: 3, 149.6357228383527
#       From worker 7:	fold: 2, 166.14262567997156
#       From worker 6:	fold: 5, 103.59473916523538
#       From worker 6:	errors: 0
#       From worker 3:	fold: 4, 33.59262780351074
#       From worker 6:	fold: 1, 47.892275297646286
#       From worker 7:	fold: 3, 487.67030641875004
#       From worker 4:	fold: 5, 113.48710074688853
#       From worker 4:	errors: 0
#       From worker 3:	fold: 5, 85.35796971400542
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 43.38474000288478
#       From worker 5:	fold: 4, 59.01953620723375
#       From worker 5:	fold: 5, 111.82583260317357
#       From worker 5:	errors: 0
#       From worker 3:	fold: 2, 27.920538356278097
#       From worker 6:	fold: 2, 25.934876821274944
#       From worker 7:	fold: 4, 1071.1559570600543
#       From worker 3:	fold: 3, 97.09204844565446
#       From worker 6:	fold: 3, 31.0537350764777
#       From worker 7:	fold: 5, 69.97839672400707
#       From worker 7:	errors: 0
#       From worker 7:	fold: 2, 37.784913769352734
#       From worker 3:	fold: 4, 1491.8476930690833
#       From worker 6:	fold: 4, 35.787624579286515
#       From worker 2:	fold: 3, 29.71069688993711
#       From worker 7:	fold: 3, 118.76531654068442
#       From worker 3:	fold: 5, 148.82856647025594
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 181677.62785088125
#       From worker 6:	fold: 5, 26.558372667807546
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 29.500759743840238
#       From worker 3:	fold: 2, 4522.1906605785125
#       From worker 6:	fold: 2, 24.20941075218948
#       From worker 7:	fold: 4, 54.21098220380445
#       From worker 3:	fold: 3, 4288.600462505366
#       From worker 3:	fold: 4, 134267.49869611254
#       From worker 3:	fold: 5, 40393.333679721756
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 86.68904425214399
#       From worker 3:	fold: 1, 20.852939286931445
#       From worker 6:	fold: 3, 149.0103834962214
#       From worker 7:	fold: 5, 46.29336318068448
#       From worker 7:	errors: 0
#       From worker 6:	fold: 4, 54.696194863847474
#       From worker 6:	fold: 5, 69.58232779186662
#       From worker 6:	errors: 0
#       From worker 2:	fold: 4, 20.48734463279349
#       From worker 3:	fold: 2, 23.02324063257822
#       From worker 2:	fold: 5, 141.34920466178056
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 49.859515022765635
#       From worker 2:	fold: 1, 22.05612906440077
#       From worker 2:	fold: 2, 166.70227025662803
#       From worker 2:	fold: 3, 53.43886635202109
#       From worker 2:	fold: 4, 106.33094219828753
#       From worker 2:	fold: 5, 32.020497000961605
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 18.150891146442007
#       From worker 3:	fold: 3, 29.460747881457724
#       From worker 2:	fold: 2, 12.441555715107878
#       From worker 3:	fold: 4, 91.36108982675718
#       From worker 2:	fold: 3, 56.42993632309373
#       From worker 3:	fold: 5, 53.4382110536144
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 93.26520350652663
#       From worker 3:	fold: 2, 148.10610853758882
#       From worker 3:	fold: 3, 53.78745388131175
#       From worker 3:	fold: 4, 42.49676270411647
#       From worker 3:	fold: 5, 91.60540385464572
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 54.34990527902134
#       From worker 2:	fold: 4, 112.25942446703117
#       From worker 3:	fold: 2, 53.78134812904418
#       From worker 3:	fold: 3, 14.606968403743762
#       From worker 2:	fold: 5, 95.25736101555235
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 37.86939902680085
#       From worker 3:	fold: 4, 75.61076337023587
#       From worker 2:	fold: 2, 88.11090327501462
#       From worker 3:	fold: 5, 18.478942068371655
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 49.41422275840198
#       From worker 2:	fold: 3, 18.21731034591795
#       From worker 3:	fold: 2, 63.537977905844876
#       From worker 2:	fold: 4, 111.46356763351247
#       From worker 3:	fold: 3, 57.8494240359057
#       From worker 3:	fold: 4, 34.52799527753906
#       From worker 2:	fold: 5, 14.94747665524544
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 75.5075792898229
#       From worker 2:	fold: 2, 16.042028468843924
#       From worker 3:	fold: 5, 154.19272161270112
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 21.70717182242182
#       From worker 2:	fold: 3, 56.64153752326254
#       From worker 3:	fold: 2, 52.84630701045395
#       From worker 2:	fold: 4, 30.922963229427527
#       From worker 2:	fold: 5, 16.348760198736958
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 71.45032563112309
#       From worker 2:	fold: 2, 100.16261281474942
#       From worker 3:	fold: 3, 26.218932451498304
#       From worker 2:	fold: 3, 167.03336189523992
#       From worker 2:	fold: 4, 19.316113913560784
#       From worker 2:	fold: 5, 38.324368904067164
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 81.90688617752113
#       From worker 2:	fold: 2, 54.96730942291775
#       From worker 3:	fold: 4, 73.09983301677147
#       From worker 2:	fold: 3, 155.37929091000174
#       From worker 2:	fold: 4, 47.753121804779006
#       From worker 2:	fold: 5, 94.23925334897976
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 43.957960022220874
#       From worker 2:	fold: 2, 33.82681054681823
#       From worker 3:	fold: 5, 171.9366470728242
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 54.708453868796106
#       From worker 2:	fold: 3, 34.488530482346945
#       From worker 2:	fold: 4, 190.43004676949482
#       From worker 2:	fold: 5, 62.87558830161681
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 13.471363450059394
#       From worker 3:	fold: 2, 84.30012393512496
#       From worker 3:	fold: 2, 8.32544423540037
#       From worker 3:	fold: 3, 36.81208322277406
#       From worker 3:	fold: 3, 17.543347277327932
#       From worker 2:	fold: 2, 30.305813948600722
#       From worker 3:	fold: 4, 46.82251700874337
#       From worker 3:	fold: 4, 114.13529024070307
#       From worker 2:	fold: 3, 95.7075143962056
#       From worker 3:	fold: 5, 154.07607621869772
#       From worker 3:	errors: 0
#       From worker 3:	fold: 5, 54.26002905835768
#       From worker 3:	errors: 0
#       From worker 2:	fold: 4, 177.70547156938278
#       From worker 2:	fold: 5, 48.72816392176495
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 130.68183149567474
#       From worker 2:	fold: 2, 69.86112465205076
#       From worker 2:	fold: 3, 66.44633254679269
#       From worker 2:	fold: 4, 56.58839843003188
#       From worker 2:	fold: 5, 116.6065594916423
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 132.16462473529822
#       From worker 2:	fold: 2, 73.95752285610743
#       From worker 2:	fold: 3, 44.220442744504446
#       From worker 2:	fold: 4, 45.103825492285445
#       From worker 2:	fold: 5, 85.63101996494478
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 125.25185928008925
#       From worker 2:	fold: 2, 96.44418412881805
#       From worker 2:	fold: 3, 80.74792157562821
#       From worker 2:	fold: 4, 71.27625521890133
#       From worker 2:	fold: 5, 78.68318342108643
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 43.59461696778991
#       From worker 2:	fold: 1, 126.0967865633514
#       From worker 2:	fold: 1, 11.300592336500166
#       From worker 2:	fold: 2, 29.007061729005844
#       From worker 2:	fold: 3, 20.983925920501925
#       From worker 2:	fold: 4, 90.6241215323088
#       From worker 2:	fold: 5, 44.21587365588807
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 25.10472532555532
#       From worker 2:	fold: 2, 41.083714966849605
#       From worker 2:	fold: 3, 34.173398838002505
#       From worker 2:	fold: 4, 155.27785213062324
#       From worker 2:	fold: 5, 133.45768301150034
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 45.06730644898585
#       From worker 2:	fold: 2, 33.02480882554121
#       From worker 2:	fold: 3, 193.51916763508584
#       From worker 2:	fold: 4, 40.51594423080362
#       From worker 2:	fold: 5, 36.03184798111436
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 7440.228129093073
#       From worker 2:	fold: 2, 125.1894759796437
#       From worker 2:	fold: 3, 65.27446419754811
#       From worker 2:	fold: 4, 149.41291667670282
#       From worker 2:	fold: 5, 161.0038478166111
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 50.416922282567214
#       From worker 2:	fold: 2, 133.19725677484146
#       From worker 2:	fold: 3, 23.93403398852669
#       From worker 2:	fold: 4, 57.27384478350779
#       From worker 2:	fold: 5, 74.48999831418053
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 24.956699995460017
#       From worker 2:	fold: 2, 15.562400961307866
#       From worker 2:	fold: 3, 53.86782139166602
#       From worker 2:	fold: 4, 35.00312979294434
#       From worker 2:	fold: 5, 33.73429082304014
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 247.88529064280127
#       From worker 2:	fold: 2, 44.97615078950518
#       From worker 2:	fold: 3, 47.07487740515928
#       From worker 2:	fold: 4, 58.332994246748
#       From worker 2:	fold: 5, 52.33335073827449
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 11.503939813366184
#       From worker 2:	fold: 2, 38.584047675464284
#       From worker 2:	fold: 3, 40.70438608504473
#       From worker 2:	fold: 4, 51.46212412102624
#       From worker 2:	fold: 5, 93.801172341388
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 39.64522914814853
#       From worker 2:	fold: 2, 15.748263733831113
#       From worker 2:	fold: 3, 25.55546854230436
#       From worker 2:	fold: 4, 41.608234045872074
#       From worker 2:	fold: 5, 82.71852247578502
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 94.13268551199276
#       From worker 2:	fold: 2, 23.393976643372888
#       From worker 2:	fold: 3, 78.83763038775366
#       From worker 2:	fold: 4, 153.07498752437266
#       From worker 2:	fold: 5, 47.756219692137535
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 145.13878979158017
#       From worker 2:	fold: 1, 96.7139486973376
#       From worker 2:	fold: 2, 14.286202249524134
#       From worker 2:	fold: 3, 51.11540479679268
#       From worker 2:	fold: 4, 25.06016893148373
#       From worker 2:	fold: 5, 79.15555709598006
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 38.145935666332356
#       From worker 2:	fold: 2, 14.865192507195424
#       From worker 2:	fold: 3, 42.299445225695706
#       From worker 2:	fold: 4, 71.4211622640365
#       From worker 2:	fold: 5, 40.068476263260635
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 34.46212246160417
#       From worker 2:	fold: 2, 18.921653397684807
#       From worker 2:	fold: 3, 10.138098268494083
#       From worker 2:	fold: 4, 28.687028737689662
#       From worker 2:	fold: 5, 91.11167869387165
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 125.4733888719907
#       From worker 2:	fold: 1, 78.38546172359223
#       From worker 2:	fold: 2, 151.3619555369334
#       From worker 2:	fold: 3, 29.88940070484285
#       From worker 2:	fold: 4, 109.44244728673875
#       From worker 2:	fold: 5, 47.23131369304999
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 36.3153363538389
#       From worker 2:	fold: 2, 21.97991674073669
#       From worker 2:	fold: 3, 35.791058588139194
#       From worker 2:	fold: 4, 40.83654343709692
#       From worker 2:	fold: 5, 101.1188595443183
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 34.88776586064804
#       From worker 2:	fold: 2, 123.29343943918185
#       From worker 2:	fold: 3, 12.18213004232466
#       From worker 2:	fold: 4, 46.34162973836012
#       From worker 2:	fold: 5, 24.558951100592626
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 33.723019398078065
#       From worker 2:	fold: 2, 10.580499185547488
#       From worker 2:	fold: 3, 30.389225466657848
#       From worker 2:	fold: 4, 46.17404480517609
#       From worker 2:	fold: 5, 18.957150687355117
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 34.431731295833636
#       From worker 2:	fold: 2, 155.43280779520094
#       From worker 2:	fold: 3, 67.9238092265592
#       From worker 2:	fold: 4, 99.83826086130478
#       From worker 2:	fold: 5, 76.50236616174313
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 121.228821225299
#       From worker 2:	fold: 2, 135.78266522724917
#       From worker 2:	fold: 2, 179.3181585074826
#       From worker 2:	fold: 2, 54.09878447283016
#       From worker 2:	fold: 2, 40.83719697395222
#       From worker 2:	fold: 2, 28.017700891770403
#       From worker 2:	fold: 2, 48.19265110619112
#       From worker 2:	fold: 3, 20.204957531354324
#       From worker 2:	fold: 3, 43.52110153999989
#       From worker 2:	fold: 3, 36.49836522944771
#       From worker 2:	fold: 3, 19.35556579412395
#       From worker 2:	fold: 4, 37.12447522084206
#       From worker 2:	fold: 3, 18.186924243974243
#       From worker 2:	fold: 4, 46.47880226654245
#       From worker 2:	fold: 3, 42.387090448549735
#       From worker 2:	fold: 4, 13.73971998144526
#       From worker 2:	fold: 4, 52.0046749184638
#       From worker 2:	fold: 4, 37.610593057170846
#       From worker 2:	fold: 5, 38.095022139734596
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 61.6215042572162
#       From worker 2:	errors: 0
#       From worker 2:	fold: 4, 30.263014428423098
#       From worker 2:	fold: 5, 49.30762397816658
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 31.457996501492463
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 20.428992727649103
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 77.6721455970396
#       From worker 2:	errors: 0
# (serialtime = "8.0 minutes", paralleltime = "15.0 seconds")

# %%
dfres
# Out:
# 72×5 DataFrame
# │ Row │ pipeline                                                 │ mean    │ sd      │ time    │ folds │
# │     │ String                                                   │ Float64 │ Float64 │ Float64 │ Int64 │
# ├─────┼──────────────────────────────────────────────────────────┼─────────┼─────────┼─────────┼───────┤
# │ 1   │ Noop |> Noop |> ARDRegression                            │ 27.9648 │ 13.7292 │ 10.3579 │ 5     │
# │ 2   │ MinMaxScaler |> FastICA |> ARDRegression                 │ 30.2844 │ 15.4899 │ 3.57426 │ 5     │
# │ 3   │ Noop |> FastICA |> ARDRegression                         │ 31.0432 │ 14.6194 │ 4.17557 │ 5     │
# │ 4   │ MinMaxScaler |> Noop |> ARDRegression                    │ 32.6249 │ 14.2134 │ 8.75153 │ 5     │
# │ 5   │ StandardScaler |> FastICA |> ARDRegression               │ 33.4454 │ 8.99663 │ 4.6386  │ 5     │
# │ 6   │ StandardScaler |> Noop |> ARDRegression                  │ 36.6641 │ 31.8255 │ 9.94754 │ 5     │
# │ 7   │ RobustScaler |> Noop |> ARDRegression                    │ 39.0926 │ 26.2172 │ 6.26191 │ 5     │
# │ 8   │ PowerTransformer |> Noop |> RandomForestRegressor        │ 39.2263 │ 31.1596 │ 8.80404 │ 5     │
# │ 9   │ RobustScaler |> FastICA |> ARDRegression                 │ 39.7136 │ 29.9239 │ 1.84589 │ 5     │
# │ 10  │ MinMaxScaler |> Noop |> GradientBoostingRegressor        │ 41.0551 │ 25.5872 │ 9.38505 │ 5     │
# │ 11  │ StandardScaler |> Noop |> GradientBoostingRegressor      │ 41.36   │ 20.1155 │ 10.0138 │ 5     │
# │ 12  │ PowerTransformer |> Noop |> GradientBoostingRegressor    │ 43.3656 │ 26.0543 │ 2.18419 │ 5     │
# │ 13  │ RobustScaler |> Noop |> RandomForestRegressor            │ 43.6272 │ 29.6591 │ 5.29398 │ 5     │
# │ 14  │ MinMaxScaler |> FastICA |> GradientBoostingRegressor     │ 43.8841 │ 27.3864 │ 3.92624 │ 5     │
# │ 15  │ MinMaxScaler |> FastICA |> RandomForestRegressor         │ 45.1753 │ 29.3817 │ 3.45992 │ 5     │
# │ 16  │ StandardScaler |> FastICA |> RandomForestRegressor       │ 46.4128 │ 34.0334 │ 3.91176 │ 5     │
# │ 17  │ Noop |> Noop |> RandomForestRegressor                    │ 47.2083 │ 30.9533 │ 10.4714 │ 5     │
# │ 18  │ MinMaxScaler |> Noop |> RandomForestRegressor            │ 47.2111 │ 29.9185 │ 9.48901 │ 5     │
# │ 19  │ Noop |> FastICA |> GradientBoostingRegressor             │ 47.4874 │ 30.6249 │ 3.61537 │ 5     │
# │ 20  │ Noop |> Noop |> GradientBoostingRegressor                │ 48.2528 │ 43.806  │ 10.4152 │ 5     │
# │ 21  │ PowerTransformer |> Noop |> rf                           │ 49.7945 │ 41.6643 │ 2.30911 │ 5     │
# │ 22  │ StandardScaler |> Noop |> RandomForestRegressor          │ 53.2663 │ 34.92   │ 10.1013 │ 5     │
# │ 23  │ RobustScaler |> FastICA |> RandomForestRegressor         │ 53.418  │ 50.8877 │ 5.85017 │ 5     │
# │ 24  │ StandardScaler |> FastICA |> GradientBoostingRegressor   │ 53.5788 │ 31.6798 │ 4.55676 │ 5     │
# │ 25  │ MinMaxScaler |> Noop |> rf                               │ 53.7789 │ 48.7091 │ 12.2575 │ 5     │
# │ 26  │ RobustScaler |> FastICA |> GradientBoostingRegressor     │ 54.0885 │ 58.3268 │ 2.42302 │ 5     │
# │ 27  │ RobustScaler |> Noop |> GradientBoostingRegressor        │ 54.1217 │ 43.3914 │ 6.2301  │ 5     │
# │ 28  │ Noop |> FastICA |> RandomForestRegressor                 │ 54.6829 │ 42.4997 │ 3.19609 │ 5     │
# │ 29  │ RobustScaler |> Noop |> rf                               │ 54.9467 │ 41.5193 │ 13.617  │ 5     │
# │ 30  │ RobustScaler |> FastICA |> rf                            │ 55.7603 │ 37.2213 │ 5.59549 │ 5     │
# │ 31  │ Noop |> Noop |> rf                                       │ 55.9557 │ 42.3132 │ 11.2333 │ 5     │
# │ 32  │ StandardScaler |> Noop |> rf                             │ 56.1102 │ 50.4858 │ 11.8039 │ 5     │
# │ 33  │ Normalizer |> Noop |> RandomForestRegressor              │ 58.9078 │ 44.7048 │ 6.20456 │ 5     │
# │ 34  │ MinMaxScaler |> FastICA |> rf                            │ 59.9273 │ 31.5446 │ 4.26098 │ 5     │
# │ 35  │ Normalizer |> Noop |> rf                                 │ 63.9487 │ 36.4597 │ 9.93583 │ 5     │
# │ 36  │ StandardScaler |> FastICA |> rf                          │ 64.7483 │ 27.208  │ 4.26888 │ 5     │
# │ 37  │ Noop |> FastICA |> rf                                    │ 65.3998 │ 50.2697 │ 4.55012 │ 5     │
# │ 38  │ Normalizer |> Noop |> GradientBoostingRegressor          │ 67.8624 │ 40.8005 │ 8.73729 │ 5     │
# │ 39  │ PowerTransformer |> Noop |> GaussianProcessRegressor     │ 69.1618 │ 61.1155 │ 2.44378 │ 5     │
# │ 40  │ PowerTransformer |> FastICA |> RandomForestRegressor     │ 69.266  │ 37.8997 │ 4.54214 │ 5     │
# │ 41  │ Normalizer |> Noop |> ARDRegression                      │ 69.6318 │ 69.4051 │ 8.47509 │ 5     │
# │ 42  │ PowerTransformer |> FastICA |> rf                        │ 69.9793 │ 61.5592 │ 12.9961 │ 5     │
# │ 43  │ PowerTransformer |> Noop |> ARDRegression                │ 71.9045 │ 47.2803 │ 2.24671 │ 5     │
# │ 44  │ StandardScaler |> Noop |> SVR                            │ 73.1158 │ 66.6209 │ 6.39419 │ 5     │
# │ 45  │ PowerTransformer |> FastICA |> SVR                       │ 73.1837 │ 66.0195 │ 6.64447 │ 5     │
# │ 46  │ StandardScaler |> FastICA |> SVR                         │ 75.8567 │ 63.3065 │ 2.23749 │ 5     │
# │ 47  │ RobustScaler |> Noop |> SVR                              │ 76.1097 │ 60.2079 │ 5.48779 │ 5     │
# │ 48  │ PowerTransformer |> FastICA |> ARDRegression             │ 76.2155 │ 36.1098 │ 7.84421 │ 5     │
# │ 49  │ Normalizer |> Noop |> SVR                                │ 77.8195 │ 61.4995 │ 8.44747 │ 5     │
# │ 50  │ MinMaxScaler |> Noop |> SVR                              │ 79.2574 │ 58.0325 │ 6.32317 │ 5     │
# │ 51  │ StandardScaler |> Noop |> GaussianProcessRegressor       │ 79.4391 │ 49.4555 │ 9.31439 │ 5     │
# │ 52  │ Noop |> FastICA |> SVR                                   │ 79.6753 │ 57.3811 │ 1.4879  │ 5     │
# │ 53  │ MinMaxScaler |> FastICA |> SVR                           │ 79.9115 │ 56.9335 │ 1.83341 │ 5     │
# │ 54  │ Normalizer |> FastICA |> SVR                             │ 80.0798 │ 55.317  │ 4.40425 │ 5     │
# │ 55  │ Normalizer |> FastICA |> rf                              │ 81.74   │ 46.1013 │ 6.59536 │ 5     │
# │ 56  │ Noop |> Noop |> SVR                                      │ 83.2621 │ 48.7177 │ 9.67101 │ 5     │
# │ 57  │ RobustScaler |> FastICA |> SVR                           │ 85.2618 │ 46.2876 │ 1.5485  │ 5     │
# │ 58  │ Normalizer |> FastICA |> RandomForestRegressor           │ 85.5235 │ 37.835  │ 3.02794 │ 5     │
# │ 59  │ PowerTransformer |> Noop |> SVR                          │ 85.8522 │ 41.4471 │ 4.61355 │ 5     │
# │ 60  │ Noop |> Noop |> GaussianProcessRegressor                 │ 86.8258 │ 44.959  │ 10.3659 │ 5     │
# │ 61  │ RobustScaler |> Noop |> GaussianProcessRegressor         │ 86.8492 │ 42.7796 │ 6.37808 │ 5     │
# │ 62  │ PowerTransformer |> FastICA |> GradientBoostingRegressor │ 88.0368 │ 33.2428 │ 7.63603 │ 5     │
# │ 63  │ MinMaxScaler |> Noop |> GaussianProcessRegressor         │ 90.1205 │ 88.3445 │ 8.75775 │ 5     │
# │ 64  │ PowerTransformer |> FastICA |> GaussianProcessRegressor  │ 90.4807 │ 21.4902 │ 7.94395 │ 5     │
# │ 65  │ Normalizer |> FastICA |> GradientBoostingRegressor       │ 91.6711 │ 51.747  │ 3.28306 │ 5     │
# │ 66  │ Normalizer |> FastICA |> ARDRegression                   │ 361.815 │ 633.502 │ 4.61037 │ 5     │
# │ 67  │ Noop |> FastICA |> GaussianProcessRegressor              │ 366.504 │ 432.286 │ 4.11924 │ 5     │
# │ 68  │ StandardScaler |> FastICA |> GaussianProcessRegressor    │ 442.503 │ 435.086 │ 4.24826 │ 5     │
# │ 69  │ RobustScaler |> FastICA |> GaussianProcessRegressor      │ 482.823 │ 524.708 │ 1.80154 │ 5     │
# │ 70  │ MinMaxScaler |> FastICA |> GaussianProcessRegressor      │ 753.555 │ 654.4   │ 4.09765 │ 5     │
# │ 71  │ Normalizer |> Noop |> GaussianProcessRegressor           │ 1588.22 │ 3271.58 │ 8.5018  │ 5     │
# │ 72  │ Normalizer |> FastICA |> GaussianProcessRegressor        │ 73029.9 │ 80681.8 │ 4.64537 │ 5     │

# %% [markdown]
# ### Extend the pipeline with R ML implementations

# %%
module RMachine

using RCall
using DataFrames
using Random

using AMLPipelineBase
using AMLPipelineBase.AbsTypes
using AMLPipelineBase.Utils

import AMLPipelineBase.AbsTypes: fit!, transform!

export CRTLearner,fit!,transform!,fit_transform!
export caretrun, crossvalidate

mutable struct CRTLearner <: Learner
   name
   model
   function CRTLearner(args::Dict{Symbol,<:Any} = Dict())
      fitControl="trainControl(method = 'none')"
      default_args = Dict{Symbol,Any}(
                      :name => "R_learner",
                      :learner => "rf",
                      :fitControl => fitControl,
                      :impl_args => Dict{Symbol,Any}()
                     )
      cargs = nested_dict_merge(default_args, args)
      cargs[:name] = cargs[:name]*"_"*randstring(3)
      rl = cargs[:learner]
      new(cargs[:name],cargs)
   end
end

function fit!(crt::CRTLearner,x::DataFrame,y::Vector)
   rmodel = rcall(:train,x,y,method=crt.model[:learner],trControl = reval(crt.model[:fitControl]))
   crt.model[:rmodel] = rmodel
end

function transform!(crt::CRTLearner,x::DataFrame)
   res = rcall(:predict,crt.model[:rmodel],x)
   return rcopy(res) |> Array
end


end
# Out:
# WARNING: replacing module RMachine.
# Main.RMachine

# %%
module RTest
using Test
using DataFrames
using RDatasets

using ..RMachine

function test_r()
   rf = CRTLearner(Dict(:learner=>"rf"))
   gbm = CRTLearner(Dict(:learner=>"gbm"))
   iris=dataset("datasets","iris")
   x=iris[:,1:4]
   y=iris[:,5] |> Array{String}
   @test (fit_transform!(rf,x,y) .== y ) |> sum == 150
   @test crossvalidate(rf,x,y,"accuracy_score",3,false).mean > 0.80
end
@testset "rmachine tests" begin
   test_r()
end
end
# Out:
# Test Summary:  | Pass  Total
# rmachine tests |    2      2
# WARNING: replacing module RTest.
# Main.RTest

# %%
@everywhere using AMLPipelineR

# %%
r_rf = CRTLearner(Dict(:name=>"RF_fromR",:learner=>"rf"));

# %%
function prpsearch(X,Y)
    learners = [sk_rf,sk_gb,sk_svr,sk_ard,sk_gp,jl_rf,r_rf];
    scalers = [rb,pt,norm,mx,mstd,noop];
    extractors = [ica,noop];
    dftable = @sync @distributed (vcat) for lr in learners
    @distributed (vcat) for sc in scalers
     @distributed (vcat) for xt  in extractors
          pipe  = @pipeline (numf |> sc |> xt)  |> lr
          scn   = sc.name[1:end - 4]; xtn = xt.name[1:end - 4]; lrn = lr.name[1:end - 4]
          pname = "$scn |> $xtn |> $lrn"
          ptime = @elapsed begin
             mean, sd, kfold, _ = crossvalidate(pipe, X, Y, rmse, 3,true)
          end
          DataFrame(pipeline=pname, mean=mean, sd=sd, time=ptime, folds=kfold)
        end
     end
    end
    sort!(dftable, :mean, rev=false);
    dftable
end

runtime = @elapsed begin
    dfres = prpsearch(X,Y)
end;
serialtime = dfres.time |> sum;

(serialtime = "$(round(serialtime / 60.0)) minutes", 
    paralleltime = "$(round(runtime)) seconds")
# Out:
#       From worker 7:	fold: 1, 47.60562200265507
#       From worker 7:	fold: 1, 18.95241792939585
#       From worker 7:	fold: 2, 65.6203915646111
#       From worker 8:	fold: 1, 109.8191179594075
#       From worker 7:	fold: 3, 55.36644826502138
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 99.75013961662336
#       From worker 7:	fold: 2, 23.93526649100652
#       From worker 7:	fold: 3, 128.84891796678903
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 39.43892752357571
#       From worker 7:	fold: 2, 71.53869219006133
#       From worker 3:	fold: 1, 32.749056365322986
#       From worker 7:	fold: 3, 26.664310479628487
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 75.87245315842128
#       From worker 7:	fold: 2, 83.78577840544183
#       From worker 8:	fold: 2, 46.5246963889781
#       From worker 4:	fold: 1, 63.53362389755619
#       From worker 7:	fold: 3, 348.25221105259635
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 53.99459050484783
#       From worker 6:	fold: 1, 98.55381396302728
#       From worker 4:	fold: 2, 136.47389236694144
#       From worker 4:	fold: 3, 64.41976247641152
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 101.11064413022481
#       From worker 6:	fold: 2, 86.50045678010595
#       From worker 7:	fold: 2, 81.00566562193293
#       From worker 6:	fold: 3, 428.47972112203274
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 25.13797890640841
#       From worker 5:	fold: 1, 43.15452152747677
#       From worker 7:	fold: 3, 46.775840243851924
#       From worker 7:	errors: 0
#       From worker 7:	fold: 2, 42.572376093100075
#       From worker 3:	fold: 2, 45.44084549976029
#       From worker 5:	fold: 2, 37.11849805005112
#       From worker 3:	fold: 3, 118.13986980373913
#       From worker 7:	fold: 3, 96.7311427675127
#       From worker 3:	errors: 0
#       From worker 7:	errors: 0
#       From worker 3:	fold: 1, 106.0214135254995
#       From worker 4:	fold: 2, 114.02290260285186
#       From worker 5:	fold: 3, 31.543770053250313
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 61.591513077045114
#       From worker 2:	fold: 1, 25.175159018190413
#       From worker 6:	fold: 2, 70.20955334209624
#       From worker 4:	fold: 3, 61.925098743204686
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 16.77340260371544
#       From worker 8:	fold: 3, 20.937104832357207
#       From worker 8:	errors: 0
#       From worker 4:	fold: 2, 38.664662485681774
#       From worker 4:	fold: 3, 95.54543711791118
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 436.50536600748984
#       From worker 5:	fold: 2, 80.64616883645054
#       From worker 4:	fold: 2, 129.88955255259853
#       From worker 3:	fold: 2, 75.11045919372158
#       From worker 4:	fold: 3, 739.7043175992768
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 28.532752488750166
#       From worker 6:	fold: 3, 37.183409984639226
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 52.552735677442335
#       From worker 6:	fold: 2, 137.3264653931639
#       From worker 6:	fold: 3, 71.67434557407856
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 32.08547644085852
#       From worker 6:	fold: 2, 39.63366513439038
#       From worker 6:	fold: 3, 82.18075605096355
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 84.34652571440627
#       From worker 5:	fold: 3, 34.63401129019628
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 104.99580759942131
#       From worker 5:	fold: 2, 118.37373687794906
#       From worker 3:	fold: 3, 81.88893905495092
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 146.19528537064548
#       From worker 5:	fold: 3, 43.04085080175998
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 89.95072672903166
#       From worker 5:	fold: 2, 65.1601028300928
#       From worker 3:	fold: 2, 35.08562391572305
#       From worker 3:	fold: 3, 63.69998209274808
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 964.7738513747313
#       From worker 3:	fold: 2, 72.76351211179004
#       From worker 3:	fold: 3, 127.76643882423134
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 82831.95071693526
#       From worker 5:	fold: 3, 52.17843294373207
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 38.15814248785819
#       From worker 3:	fold: 2, 6797.502345313091
#       From worker 3:	fold: 3, 131278.3088112277
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 59.20825654039258
#       From worker 4:	fold: 2, 38.68740150946466
#       From worker 6:	fold: 2, 71.05735976907808
#       From worker 3:	fold: 2, 78.73820984748875
#       From worker 5:	fold: 2, 91.95146522204385
#       From worker 4:	fold: 3, 105.56734185198299
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 30.0679304343229
#       From worker 4:	fold: 2, 109.00751503383623
#       From worker 4:	fold: 3, 186.02095412717009
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 91.69959826038726
#       From worker 4:	fold: 2, 37.96890761414317
#       From worker 6:	fold: 3, 31.977510600858775
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 25.63265130135606
#       From worker 4:	fold: 3, 54.374604975488715
#       From worker 4:	errors: 0
#       From worker 6:	fold: 2, 80.04045622114668
#       From worker 6:	fold: 3, 58.93369804909551
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 49.46522554554168
#       From worker 6:	fold: 2, 96.86726764121718
#       From worker 3:	fold: 3, 120.4069621187632
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 84.2186467443931
#       From worker 6:	fold: 3, 48.43070721471893
#       From worker 6:	errors: 0
#       From worker 3:	fold: 1, 91.09538617011022
#       From worker 5:	fold: 3, 54.58495854151297
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 64.10917322157565
#       From worker 5:	fold: 2, 37.008330344982355
#       From worker 3:	fold: 2, 57.77323823554315
#       From worker 5:	fold: 3, 25.862601907615726
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 49.21607128797908
#       From worker 5:	fold: 2, 98.32476634641418
#       From worker 5:	fold: 3, 59.15015708557925
#       From worker 5:	errors: 0
#       From worker 3:	fold: 3, 18.5742564879222
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 131.84668643287634
#       From worker 3:	fold: 2, 75.90408728756167
#       From worker 3:	fold: 3, 56.77138709331055
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 54.98673643956262
#       From worker 3:	fold: 2, 57.42006231893631
#       From worker 3:	fold: 3, 120.79248660258845
#       From worker 3:	errors: 0
#       From worker 3:	fold: 2, 104.09694248848324
#       From worker 3:	fold: 3, 96.41371213475621
#       From worker 3:	errors: 0
#       From worker 2:	fold: 2, 80.92957690290494
#       From worker 3:	fold: 1, 70.50377910208397
#       From worker 3:	fold: 2, 128.2015109387217
#       From worker 3:	fold: 3, 52.15961945312349
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 50.25698660587432
#       From worker 3:	fold: 2, 42.7523938688848
#       From worker 3:	fold: 3, 89.05149850565391
#       From worker 3:	errors: 0
#       From worker 2:	fold: 3, 39.582549966390935
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 71.2017474255099
#       From worker 2:	fold: 2, 33.50443528663681
#       From worker 3:	fold: 1, 120.46098563328098
#       From worker 2:	fold: 3, 84.35412590752162
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 19.856864449340318
#       From worker 2:	fold: 2, 42.09696102737132
#       From worker 2:	fold: 3, 28.754953868195763
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 99.24411388793612
#       From worker 2:	fold: 2, 153.03536019976187
#       From worker 2:	fold: 3, 32.17849318878701
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 25.711276905721288
#       From worker 2:	fold: 1, 88.35370429889718
#       From worker 3:	fold: 2, 44.31219664968399
#       From worker 2:	fold: 2, 31.616475592610886
#       From worker 3:	fold: 3, 24.733005111450648
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 73.37633818515502
#       From worker 3:	fold: 2, 24.320025502376993
#       From worker 3:	fold: 3, 65.59434185549927
#       From worker 3:	errors: 0
#       From worker 2:	fold: 3, 61.194619010776755
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 44.29177581077011
#       From worker 2:	fold: 2, 153.387778218188
#       From worker 2:	fold: 3, 56.535393762542824
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 83.51182088784711
#       From worker 2:	fold: 2, 33.8453406678255
#       From worker 2:	fold: 3, 137.27004741907007
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 49.69616929203554
#       From worker 2:	fold: 2, 55.22355443742835
#       From worker 2:	fold: 3, 10.100231686457413
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 47.719848651459024
#       From worker 2:	fold: 1, 79.66754248490545
#       From worker 2:	fold: 2, 58.423479270448205
#       From worker 2:	fold: 3, 35.21902338745926
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 71.28759915912616
#       From worker 2:	fold: 2, 77.04705796020792
#       From worker 2:	fold: 3, 36.25607533636381
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 77.69625259280087
#       From worker 2:	fold: 2, 32.08001248044022
#       From worker 2:	fold: 3, 141.1275806096001
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 141.5982423995783
#       From worker 2:	fold: 2, 58.351263289535105
#       From worker 2:	fold: 3, 50.937089866142415
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 35.308338309562565
#       From worker 2:	fold: 1, 27.438738383787975
#       From worker 2:	fold: 2, 121.36786734490093
#       From worker 2:	fold: 3, 55.49960784292044
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 102.59166970406754
#       From worker 2:	fold: 2, 63.6052056714922
#       From worker 2:	fold: 3, 30.45308318321654
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 93.96067452337066
#       From worker 2:	fold: 2, 62.398979336184546
#       From worker 2:	fold: 3, 116.72774887893539
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 40.46039446145754
#       From worker 2:	fold: 2, 24.11086740259695
#       From worker 2:	fold: 3, 29.792987167432706
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 58.271077242317475
#       From worker 2:	fold: 2, 79.77050367599772
#       From worker 2:	fold: 3, 132.76641718037916
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 98.02864182526866
#       From worker 2:	fold: 2, 31.860503345888063
#       From worker 2:	fold: 3, 64.65246319296595
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 58.558680538088005
#       From worker 2:	fold: 2, 93.91780183329365
#       From worker 2:	fold: 3, 119.77215976602649
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 110.31695972114794
#       From worker 2:	fold: 2, 95.65230127995505
#       From worker 2:	fold: 3, 47.082172742567124
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 113.56045802646831
#       From worker 2:	fold: 2, 84.34611821605728
#       From worker 2:	fold: 3, 128.88355205656947
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 87.68157944611067
#       From worker 2:	fold: 1, 50.64123787947156
#       From worker 2:	fold: 2, 57.299144073165785
#       From worker 2:	fold: 3, 120.08714247072874
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 111.54858798263034
#       From worker 2:	fold: 2, 107.85415719974813
#       From worker 2:	fold: 3, 83.49834133118216
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 130.92989992418927
#       From worker 2:	fold: 1, 72.51994703445833
#       From worker 2:	fold: 2, 40.291540161280196
#       From worker 2:	fold: 3, 50.52516689058151
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 34.6226503070117
#       From worker 2:	fold: 2, 100.14729905720237
#       From worker 2:	fold: 3, 98.5135314443331
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 22.949022182287077
#       From worker 2:	fold: 2, 68.31231040413866
#       From worker 2:	fold: 3, 75.03651936772079
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 24.204484482369658
#       From worker 2:	fold: 2, 80.83749781592334
#       From worker 2:	fold: 3, 43.109298506463766
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 145.98416559015024
#       From worker 2:	fold: 2, 47.2694234169328
#       From worker 2:	fold: 3, 61.67730786167634
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 45.83826714197767
#       From worker 2:	fold: 2, 150.00757061720628
#       From worker 2:	fold: 3, 36.42830067479395
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 65.70615994478833
#       From worker 2:	fold: 2, 12027.943142231392
#       From worker 2:	fold: 3, 97.0325801299376
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 100.05915805686949
#       From worker 2:	fold: 2, 86.52370869451758
#       From worker 2:	fold: 3, 50.73315064712506
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 80.59049759105544
#       From worker 2:	fold: 2, 31.998960076077356
#       From worker 2:	fold: 3, 33.20929655672027
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 95.7690490843149
#       From worker 2:	fold: 2, 128.75932752276793
#       From worker 2:	fold: 3, 26.622356853855063
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 39.35734629581644
#       From worker 2:	fold: 2, 29.66457487925935
#       From worker 2:	fold: 3, 11.482171271017119
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 45.07615145605406
#       From worker 2:	fold: 2, 76.9850783700915
#       From worker 2:	fold: 3, 139.85705175119358
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 38.6539861372716
#       From worker 2:	fold: 2, 20.52376514171856
#       From worker 2:	fold: 3, 92.3801729228327
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 50.869847859658606
#       From worker 2:	fold: 2, 95.37074739598421
#       From worker 2:	fold: 2, 25.78331590106154
#       From worker 2:	fold: 2, 86.63904665333466
#       From worker 2:	fold: 2, 101.87258629751085
#       From worker 2:	fold: 2, 79.74225224036304
#       From worker 2:	fold: 2, 116.49710137044674
#       From worker 2:	fold: 3, 54.173163633593845
#       From worker 2:	errors: 0
#       From worker 2:	fold: 3, 106.14274078052557
#       From worker 2:	errors: 0
#       From worker 2:	fold: 3, 53.31193319636034
#       From worker 2:	errors: 0
#       From worker 2:	fold: 3, 30.425866537732794
#       From worker 2:	errors: 0
#       From worker 2:	fold: 3, 14.463070304202233
#       From worker 2:	errors: 0
#       From worker 2:	fold: 3, 72.46228582074316
#       From worker 2:	errors: 0
# (serialtime = "9.0 minutes", paralleltime = "20.0 seconds")

# %%
dfres
# Out:
# 84×5 DataFrame
# │ Row │ pipeline                                                 │ mean    │ sd      │ time     │ folds │
# │     │ String                                                   │ Float64 │ Float64 │ Float64  │ Int64 │
# ├─────┼──────────────────────────────────────────────────────────┼─────────┼─────────┼──────────┼───────┤
# │ 1   │ Noop |> Noop |> ARDRegression                            │ 26.8347 │ 14.1514 │ 11.8771  │ 3     │
# │ 2   │ MinMaxScaler |> Noop |> ARDRegression                    │ 30.2363 │ 11.1938 │ 3.14222  │ 3     │
# │ 3   │ RobustScaler |> Noop |> ARDRegression                    │ 31.4547 │ 8.30047 │ 12.8923  │ 3     │
# │ 4   │ RobustScaler |> FastICA |> ARDRegression                 │ 37.2723 │ 5.8069  │ 4.33922  │ 3     │
# │ 5   │ StandardScaler |> Noop |> ARDRegression                  │ 38.34   │ 24.612  │ 3.75042  │ 3     │
# │ 6   │ MinMaxScaler |> FastICA |> GradientBoostingRegressor     │ 42.3267 │ 19.6701 │ 3.08776  │ 3     │
# │ 7   │ StandardScaler |> FastICA |> RandomForestRegressor       │ 44.177  │ 23.3355 │ 4.40624  │ 3     │
# │ 8   │ Noop |> FastICA |> ARDRegression                         │ 45.8806 │ 23.1203 │ 2.10264  │ 3     │
# │ 9   │ Noop |> FastICA |> RandomForestRegressor                 │ 46.6464 │ 24.5256 │ 2.17816  │ 3     │
# │ 10  │ RobustScaler |> FastICA |> RandomForestRegressor         │ 48.5624 │ 28.9416 │ 9.83627  │ 3     │
# │ 11  │ Noop |> Noop |> RandomForestRegressor                    │ 48.5996 │ 27.7116 │ 12.0846  │ 3     │
# │ 12  │ PowerTransformer |> Noop |> RandomForestRegressor        │ 49.3838 │ 28.8332 │ 11.7515  │ 3     │
# │ 13  │ MinMaxScaler |> FastICA |> ARDRegression                 │ 50.3278 │ 40.6606 │ 3.51456  │ 3     │
# │ 14  │ Noop |> Noop |> GradientBoostingRegressor                │ 50.5193 │ 37.3688 │ 11.9669  │ 3     │
# │ 15  │ StandardScaler |> FastICA |> ARDRegression               │ 51.3    │ 27.0085 │ 3.66222  │ 3     │
# │ 16  │ PowerTransformer |> Noop |> GradientBoostingRegressor    │ 54.4302 │ 26.3649 │ 1.32918  │ 3     │
# │ 17  │ MinMaxScaler |> Noop |> RandomForestRegressor            │ 54.4456 │ 16.468  │ 11.6932  │ 3     │
# │ 18  │ StandardScaler |> FastICA |> GradientBoostingRegressor   │ 54.8689 │ 27.4307 │ 2.90549  │ 3     │
# │ 19  │ StandardScaler |> Noop |> RandomForestRegressor          │ 55.4326 │ 28.3318 │ 11.5567  │ 3     │
# │ 20  │ RobustScaler |> Noop |> RandomForestRegressor            │ 55.8143 │ 36.3002 │ 3.50328  │ 3     │
# │ 21  │ MinMaxScaler |> FastICA |> RF_fromR                      │ 57.5958 │ 41.8537 │ 4.35573  │ 3     │
# │ 22  │ Noop |> Noop |> RF_fromR                                 │ 57.77   │ 22.2315 │ 4.52258  │ 3     │
# │ 23  │ MinMaxScaler |> Noop |> rf                               │ 58.4184 │ 35.0232 │ 11.2377  │ 3     │
# │ 24  │ StandardScaler |> Noop |> rf                             │ 58.4198 │ 26.0438 │ 10.0427  │ 3     │
# │ 25  │ MinMaxScaler |> FastICA |> RandomForestRegressor         │ 58.9572 │ 23.1189 │ 4.6431   │ 3     │
# │ 26  │ RobustScaler |> FastICA |> RF_fromR                      │ 59.0936 │ 45.7546 │ 3.95667  │ 3     │
# │ 27  │ Noop |> Noop |> rf                                       │ 59.882  │ 41.5373 │ 10.638   │ 3     │
# │ 28  │ MinMaxScaler |> Noop |> RF_fromR                         │ 60.3883 │ 28.3772 │ 4.1014   │ 3     │
# │ 29  │ Noop |> FastICA |> GradientBoostingRegressor             │ 60.592  │ 18.0434 │ 2.47452  │ 3     │
# │ 30  │ PowerTransformer |> Noop |> rf                           │ 60.687  │ 24.8493 │ 0.138959 │ 3     │
# │ 31  │ MinMaxScaler |> FastICA |> rf                            │ 61.3477 │ 27.5357 │ 4.92706  │ 3     │
# │ 32  │ StandardScaler |> Noop |> GradientBoostingRegressor      │ 61.5302 │ 22.0767 │ 4.13925  │ 3     │
# │ 33  │ StandardScaler |> FastICA |> RF_fromR                    │ 61.5649 │ 27.5675 │ 4.75068  │ 3     │
# │ 34  │ RobustScaler |> FastICA |> rf                            │ 62.303  │ 29.9216 │ 4.20845  │ 3     │
# │ 35  │ Noop |> FastICA |> RF_fromR                              │ 62.4605 │ 27.2224 │ 4.40744  │ 3     │
# │ 36  │ RobustScaler |> Noop |> RF_fromR                         │ 63.0201 │ 26.3937 │ 3.59467  │ 3     │
# │ 37  │ PowerTransformer |> Noop |> RF_fromR                     │ 63.1687 │ 50.5731 │ 1.70443  │ 3     │
# │ 38  │ RobustScaler |> Noop |> GradientBoostingRegressor        │ 64.8472 │ 33.0845 │ 12.6341  │ 3     │
# │ 39  │ Noop |> FastICA |> rf                                    │ 64.9211 │ 27.6711 │ 5.0081   │ 3     │
# │ 40  │ RobustScaler |> FastICA |> GradientBoostingRegressor     │ 65.4433 │ 46.0757 │ 4.05524  │ 3     │
# │ 41  │ MinMaxScaler |> Noop |> GradientBoostingRegressor        │ 65.55   │ 36.1086 │ 4.60591  │ 3     │
# │ 42  │ StandardScaler |> Noop |> RF_fromR                       │ 68.1021 │ 48.216  │ 5.01643  │ 3     │
# │ 43  │ StandardScaler |> FastICA |> rf                          │ 68.897  │ 25.9647 │ 5.15468  │ 3     │
# │ 44  │ StandardScaler |> FastICA |> GaussianProcessRegressor    │ 69.0964 │ 19.1913 │ 3.86854  │ 3     │
# │ 45  │ PowerTransformer |> FastICA |> rf                        │ 73.3267 │ 37.8247 │ 16.9058  │ 3     │
# │ 46  │ RobustScaler |> Noop |> rf                               │ 75.0451 │ 58.3753 │ 17.5057  │ 3     │
# │ 47  │ PowerTransformer |> FastICA |> RF_fromR                  │ 76.0092 │ 38.3175 │ 13.3764  │ 3     │
# │ 48  │ Normalizer |> Noop |> ARDRegression                      │ 77.4247 │ 63.0344 │ 11.4289  │ 3     │
# │ 49  │ PowerTransformer |> Noop |> ARDRegression                │ 77.7331 │ 37.3104 │ 0.570521 │ 3     │
# │ 50  │ Normalizer |> Noop |> RandomForestRegressor              │ 77.7612 │ 37.368  │ 11.4002  │ 3     │
# │ 51  │ Normalizer |> Noop |> RF_fromR                           │ 79.1053 │ 25.486  │ 12.4633  │ 3     │
# │ 52  │ Normalizer |> Noop |> rf                                 │ 79.9431 │ 33.4471 │ 12.9439  │ 3     │
# │ 53  │ Normalizer |> FastICA |> SVR                             │ 81.6603 │ 57.6912 │ 3.74877  │ 3     │
# │ 54  │ PowerTransformer |> Noop |> GaussianProcessRegressor     │ 83.6216 │ 39.6819 │ 0.115331 │ 3     │
# │ 55  │ StandardScaler |> Noop |> GaussianProcessRegressor       │ 83.6289 │ 50.3396 │ 4.10873  │ 3     │
# │ 56  │ MinMaxScaler |> Noop |> SVR                              │ 83.6346 │ 54.7658 │ 4.1014   │ 3     │
# │ 57  │ Noop |> Noop |> SVR                                      │ 83.7169 │ 52.1242 │ 11.869   │ 3     │
# │ 58  │ Noop |> FastICA |> SVR                                   │ 84.1781 │ 54.1626 │ 1.93563  │ 3     │
# │ 59  │ PowerTransformer |> FastICA |> ARDRegression             │ 84.3505 │ 33.0977 │ 12.7436  │ 3     │
# │ 60  │ Normalizer |> Noop |> GradientBoostingRegressor          │ 84.7383 │ 59.7665 │ 3.75523  │ 3     │
# │ 61  │ StandardScaler |> Noop |> SVR                            │ 84.8757 │ 51.7258 │ 3.72041  │ 3     │
# │ 62  │ Normalizer |> Noop |> SVR                                │ 84.977  │ 53.3227 │ 11.4172  │ 3     │
# │ 63  │ Normalizer |> FastICA |> RF_fromR                        │ 86.1178 │ 31.2596 │ 4.784    │ 3     │
# │ 64  │ StandardScaler |> FastICA |> SVR                         │ 87.1845 │ 44.4643 │ 3.61372  │ 3     │
# │ 65  │ Noop |> Noop |> GaussianProcessRegressor                 │ 87.3061 │ 48.226  │ 11.878   │ 3     │
# │ 66  │ PowerTransformer |> FastICA |> RandomForestRegressor     │ 87.6736 │ 16.2471 │ 4.3652   │ 3     │
# │ 67  │ RobustScaler |> FastICA |> SVR                           │ 88.1424 │ 41.8586 │ 3.84413  │ 3     │
# │ 68  │ PowerTransformer |> Noop |> SVR                          │ 88.1741 │ 39.0127 │ 3.17749  │ 3     │
# │ 69  │ MinMaxScaler |> FastICA |> SVR                           │ 88.8035 │ 40.1921 │ 3.96293  │ 3     │
# │ 70  │ RobustScaler |> Noop |> GaussianProcessRegressor         │ 90.2693 │ 38.3413 │ 12.834   │ 3     │
# │ 71  │ PowerTransformer |> FastICA |> SVR                       │ 90.7495 │ 30.7295 │ 12.7242  │ 3     │
# │ 72  │ RobustScaler |> Noop |> SVR                              │ 91.0291 │ 27.2828 │ 12.8813  │ 3     │
# │ 73  │ Normalizer |> FastICA |> RandomForestRegressor           │ 92.3529 │ 27.1306 │ 4.13762  │ 3     │
# │ 74  │ MinMaxScaler |> Noop |> GaussianProcessRegressor         │ 94.8193 │ 60.5498 │ 3.14788  │ 3     │
# │ 75  │ Normalizer |> FastICA |> rf                              │ 94.9098 │ 10.0241 │ 5.54148  │ 3     │
# │ 76  │ PowerTransformer |> FastICA |> GradientBoostingRegressor │ 100.967 │ 15.2407 │ 11.5974  │ 3     │
# │ 77  │ Normalizer |> FastICA |> GradientBoostingRegressor       │ 108.365 │ 77.9785 │ 2.76824  │ 3     │
# │ 78  │ PowerTransformer |> FastICA |> GaussianProcessRegressor  │ 108.93  │ 22.6269 │ 12.7554  │ 3     │
# │ 79  │ Noop |> FastICA |> GaussianProcessRegressor              │ 169.303 │ 155.025 │ 2.19217  │ 3     │
# │ 80  │ RobustScaler |> FastICA |> GaussianProcessRegressor      │ 204.511 │ 194.056 │ 3.82598  │ 3     │
# │ 81  │ Normalizer |> FastICA |> ARDRegression                   │ 388.435 │ 499.882 │ 3.78771  │ 3     │
# │ 82  │ MinMaxScaler |> FastICA |> GaussianProcessRegressor      │ 435.366 │ 304.909 │ 3.52387  │ 3     │
# │ 83  │ Normalizer |> Noop |> GaussianProcessRegressor           │ 4063.56 │ 6897.38 │ 11.4305  │ 3     │
# │ 84  │ Normalizer |> FastICA |> GaussianProcessRegressor        │ 73635.9 │ 62747.9 │ 3.81099  │ 3     │
