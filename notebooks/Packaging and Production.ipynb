# %%
using RCall
using DataFrames, DataFramesMeta
using CSV
using DataVoyager
using AMLPipelineBase
using AutoMLPipeline
using Statistics

using Distributed
nprocs() == 1 && addprocs(;exeflags="--project")
@everywhere begin
    using AutoMLPipeline
    using DataFrames
    using Statistics
end

ENV["LINES"] = 10
ENV["COLUMNS"]=10000;

# %% [markdown]
# ### Load Covid Data
#
# source: https://covid.ourworldindata.org/data/owid-covid-data.csv

# %%
function getdata()
   df = CSV.read("../data/owid-covid-data.csv",DataFrame);
   @rput df
   R"""
      library(tidyverse)
      library(mice)

      sdf = df %>% group_by(location) %>% 
      summarise(
        mnewcases = mean(new_cases,na.rm=T),
        mnewdeaths = mean(new_deaths,na.rm=T),
        mpopulation = mean(population,na.rm=T),
        mcardio = mean(cardiovasc_death_rate,na.rm=T),
        mdiab = mean(diabetes_prevalence,na.rm=T),
        mhandwash = mean(handwashing_facilities,na.rm=T),
        mhbed = mean(hospital_beds_per_thousand,na.rm=T),
        mpatient = mean(hosp_patients,na.rm=T),
        madmission = mean(weekly_hosp_admissions,na.rm=T),
        mhdi = mean(human_development_index,na.rm=T),
        mle = mean(life_expectancy,na.rm=T)
      ) 
      imputed=mice(sdf,meth='sample',printFlag=F)
      complete(imputed)
   """ |> rcopy
end;

# %%
dfimp = getdata()
X = dfimp[:,Not([:location,:mnewdeaths])]
Y = dfimp.mnewdeaths;
# Out:
# ┌ Warning: RCall.jl: `summarise()` ungrouping output (override with `.groups` argument)
# └ @ RCall /Users/ppalmes/.julia/packages/RCall/eRsxl/src/io.jl:160
# ┌ Warning: RCall.jl: Warning: Number of logged events: 1
# └ @ RCall /Users/ppalmes/.julia/packages/RCall/eRsxl/src/io.jl:160

# %%
R"""
library(caret)

fitControl <- trainControl(## 5-fold CV
                           method = "repeatedcv",
                           number = 5,
                          )
rfcaret <- train($X,$Y,  
                 method = "rf", 
                 trControl = fitControl,
                 )
rfcaret
"""
# Out:
# ┌ Warning: RCall.jl: Loading required package: lattice
# │
# │ Attaching package: ‘caret’
# │
# │ The following object is masked from ‘package:purrr’:
# │
# │     lift
# │
# └ @ RCall /Users/ppalmes/.julia/packages/RCall/eRsxl/src/io.jl:160
# RObject{VecSxp}
# Random Forest
#
# 190 samples
#  10 predictor
#
# No pre-processing
# Resampling: Cross-Validated (5 fold, repeated 1 times)
# Summary of sample sizes: 152, 151, 153, 152, 152
# Resampling results across tuning parameters:
#
#   mtry  RMSE      Rsquared   MAE
#    2    59.08423  0.6733149  21.33716
#    6    49.07606  0.7537993  14.91031
#   10    48.15070  0.7846335  13.48423
#
# RMSE was used to select the optimal model using the smallest value.
# The final value used for the model was mtry = 10.

# %%
using AutoMLPipeline

#### Decomposition
pca = SKPreprocessor("PCA")
fa  = SKPreprocessor("FactorAnalysis")
ica = SKPreprocessor("FastICA")

#### Scaler 
rb   = SKPreprocessor("RobustScaler")
pt   = SKPreprocessor("PowerTransformer")
norm = SKPreprocessor("Normalizer")
mx   = SKPreprocessor("MinMaxScaler")
mstd    = SKPreprocessor("StandardScaler")

#### categorical preprocessing
ohe = OneHotEncoder()
noop = Identity(Dict(:name=>"Noop"))

#### Column selector
catf = CatFeatureSelector()
numf = NumFeatureSelector()

#### Learners
sk_rf       = SKLearner("RandomForestRegressor")
sk_gb       = SKLearner("GradientBoostingRegressor")
sk_svr      = SKLearner("SVR")
sk_gp       = SKLearner("GaussianProcessRegressor")
sk_ard      = SKLearner("ARDRegression")
jl_rf       = RandomForest()
jl_vote     = VoteEnsemble()
jl_stack    = StackEnsemble()
jl_best     = BestLearner();

# %%
plsvc = @pipeline  numf |> rb |> sk_svr
pred = fit_transform!(plsvc,X,Y)
# Out:
# 190-element Array{Float64,1}:
#   1.9947016077660855
#   1.563442127520517
#   3.4132272470427374
#   0.8165241542589561
#   1.4180225483173476
#   0.97321360257612
#  16.78504012363476
#   2.567986932013074
#   3.9583847301788952
#   4.710616972286513
#   2.880876084994698
#   0.6787592751847766
#   2.0291946736187603
#  10.051261959262849
#   1.8186288749064978
#   3.7577187394637956
#   8.545811513665335
#   0.9985165935001552
#   0.45993993880024675
#   0.7836066497892746
#   2.4289669007137675
#   2.342838246753356
#   0.9558367140371962
#   7.707238226696546
#   1.5067009570712955
#   3.691756834293649
#   0.32078481560837346
#   0.5240855036773739
#   1.1141984987107048
#   1.6079858605584478
#   7.177311302570495
#   3.7759189733698615
#   0.29266047847861465
#   0.027356154088445273
#   7.589918796681051
#   7.676588011864249
#  15.581892802530605
#   0.3385358630418498
#   0.7885790194452911
#   2.823995876789053
#   1.3142218946972086
#   3.4331242811942784
#   2.114963927460807
#   1.6581760692361422
#   7.912986451407457
#   2.8497855613142957
#   2.805684919614369
#  -0.0023094421684026756
#   0.7418928117093184
#   2.6682852938664663
#   4.064249289775644
#   4.905216761854305
#   1.4304618153854811
#   0.46479340102492017
#   0.37568427354397915
#   1.7513363006917722
#   0.4383695856193226
#   4.638538024969155
#   0.6414969559479484
#   1.5167498682588931
#  16.322772579961704
#   1.165160634441171
#   0.5342454182594158
#   3.262376120429682
#  16.56064458175537
#   1.7691876863058873
#   3.998676898853
#   0.46068282143597905
#   2.5115655827742582
#   0.8571088800686102
#   0.46821560476959334
#   0.5058119644973385
#   0.7770306798131932
#   2.325841839547164
#   2.1813350320892138
#   4.844442636917972
#   1.5234099854239957
#   7.676583301970822
#  12.173205436202377
#  14.824398306829686
#   7.053098405402219
#   2.472068153695023
#   5.426165897418568
#  17.969284131364027
#   1.0218773394754894
#   7.286068838370836
#   3.8020682011074087
#   3.2138277898530156
#   2.7095920234607207
#   0.6615142277461157
#   2.515681702652877
#   2.1060684437196278
#   1.644841757223265
#   1.7764092437231094
#   2.6246713566025575
#   0.46657524465089395
#   3.1129513122655172
#   1.9839135829349592
#   1.5358418809319856
#   2.5625810652495797
#   2.025906581668975
#   1.7903897972424145
#   0.5802501929927768
#   2.616538729972593
#   1.7927447611336635
#   0.8599485485595704
#   1.6475068831002897
#   1.3906488523163674
#   1.5895917179183927
#   0.6596150952590918
#  16.1704203276658
#   2.5512906317102093
#   2.5676163501586817
#   2.1827672762324726
#   1.398921235480393
#   5.9281697302075935
#   1.2763205032170308
#   3.196815359740302
#   0.7508501376951893
#   3.8435848223376876
#   8.641348884300399
#   1.4116737273707614
#   0.555972346354646
#   3.5217955843840727
#   4.055843394186155
#   1.708864572454246
#   2.273161302778127
#   2.5365672323153188
#  10.363398227722064
#   2.0885793796314776
#   2.3881855627416275
#   0.7318658037414103
#   2.0256253224299936
#  11.971304958227858
#   8.544404067143264
#  14.484700900801847
#   5.320642540009263
#   1.7268154381609238
#   5.241375307099929
#  16.181968176969228
#   0.9456397883319454
#   0.9646328731417348
#   0.799693818380379
#   0.6712452483911173
#   0.4396578557766144
#   1.4037619842172342
#   0.9088344096642471
#   5.567786359931382
#   0.8815359433983438
#   4.399788482877619
#   0.7473215916619811
#   0.7997003618587675
#   1.9602192771798155
#   2.8891135650881425
#   2.5873529804187587
#   0.6503652817449828
#   0.3341456254256201
#  11.562481323752715
#   4.147811553853975
#   0.08960229883565951
#  16.71315038852515
#   1.9792969534149556
#   1.6691421192130278
#   0.9361652878588176
#   5.0439696994009156
#   5.642248396693299
#   1.439886147522822
#   1.1521363059391714
#   1.0888683574480522
#   2.1057907918298886
#   2.374429689437724
#   1.4823556785185366
#   0.5116295029203606
#   1.1767566797130584
#   2.733281794502385
#  17.910214242631028
#   1.5098750517611146
#  12.244270146256678
#   2.987350298604638
#  17.448866071354807
#   7.676582916739852
#   1.0419457991755348
#   2.9793079459271223
#   0.6629763285446657
#   1.164112907124501
#   2.5677938111106426
#   3.8139049769532978
#   1.3038356947757004
#   1.1698097661286608
#   0.8496825804615797

# %%
@everywhere rmse(x,y) = sqrt(mean((x .- y).^2))

plsvc = @pipeline ((numf |> rb |> ica )) |> sk_rf
crossvalidate(plsvc,X,Y,mrmse)
# Out:
# fold: 1, 15.385363620728153
# fold: 2, 16.15377894552439
# fold: 3, 56.57020873254884
# fold: 4, 17.367717620616904
# fold: 5, 8.615273868958266
# fold: 6, 5.344016547484432
# fold: 7, 46.401204634717985
# fold: 8, 53.941357896864595
# fold: 9, 26.814311295547505
# fold: 10, 137.21184482441765
# errors: 0
# (mean = 38.38050779874087, std = 39.41300873914402, folds = 10, errors = 0)

# %%
function prpsearch(X,Y)
    learners = [sk_rf,sk_gb,sk_svr,sk_ard,sk_gp,jl_rf];
    scalers = [rb,pt,norm,mx,mstd,noop];
    extractors = [ica,noop];
    dftable = @sync @distributed (vcat) for lr in learners
    @distributed (vcat) for sc in scalers
     @distributed (vcat) for xt  in extractors
          pipe  = @pipeline (numf |> sc |> xt)  |> lr
          scn   = sc.name[1:end - 4]; xtn = xt.name[1:end - 4]; lrn = lr.name[1:end - 4]
          pname = "$scn |> $xtn |> $lrn"
          ptime = @elapsed begin
             mean, sd, kfold, _ = crossvalidate(pipe, X, Y, rmse, 5,true)
          end
          DataFrame(pipeline=pname, mean=mean, sd=sd, time=ptime, folds=kfold)
        end
     end
    end
    sort!(dftable, :mean, rev=false);
    dftable
end
# Out:
# prpsearch (generic function with 1 method)

# %%
ENV["LINES"]=1000

runtime = @elapsed begin
    dfres = prpsearch(X,Y)
end;
serialtime = dfres.time |> sum;

(serialtime = "$(round(serialtime / 60.0)) minutes", 
    paralleltime = "$(round(runtime)) seconds")
# Out:
#       From worker 3:	fold: 1, 13.604523452548
#       From worker 5:	fold: 1, 24.31309619750921
#       From worker 4:	fold: 1, 80.26477808844527
#       From worker 7:	fold: 1, 67.11608408502565
#       From worker 5:	fold: 2, 9.456298568178553
#       From worker 7:	fold: 1, 33.67827580789317
#       From worker 5:	fold: 3, 21.8788945509615
#       From worker 5:	fold: 4, 60.10066061996548
#       From worker 4:	fold: 2, 29.704466641354166
#       From worker 4:	fold: 3, 151.52456273243888
#       From worker 6:	fold: 1, 137.98782722612634
#       From worker 7:	fold: 2, 23.746907647917336
#       From worker 4:	fold: 4, 109.05667844126138
#       From worker 5:	fold: 5, 25.532258549816227
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 85.44986902233022
#       From worker 6:	fold: 2, 130.30846320194348
#       From worker 4:	fold: 5, 52.14163983022657
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 72.83927172792453
#       From worker 6:	fold: 3, 50.01266807552282
#       From worker 5:	fold: 2, 99.70734058482624
#       From worker 7:	fold: 3, 41.72544515094301
#       From worker 6:	fold: 4, 98.65053535297331
#       From worker 5:	fold: 3, 15.054026764017435
#       From worker 7:	fold: 4, 28.606249964679428
#       From worker 6:	fold: 5, 889.4967194712349
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 62.63428625574589
#       From worker 3:	fold: 2, 149.0544827348121
#       From worker 5:	fold: 4, 18.043597861588204
#       From worker 6:	fold: 2, 145.74120463612732
#       From worker 7:	fold: 5, 85.77650423828375
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 16.49801438548912
#       From worker 4:	fold: 2, 75.58013835999103
#       From worker 3:	fold: 3, 12.28048469505869
#       From worker 5:	fold: 5, 25.579200932615063
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 37.40328815674331
#       From worker 6:	fold: 3, 16.378106783383497
#       From worker 2:	fold: 1, 23.817536939567468
#       From worker 3:	fold: 4, 44.04659050706362
#       From worker 6:	fold: 4, 15.012283283791557
#       From worker 3:	fold: 5, 35.88877574239766
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 51.735806076721445
#       From worker 6:	fold: 5, 31.633977750088114
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 95.97404899931773
#       From worker 4:	fold: 3, 92.17406832127718
#       From worker 5:	fold: 2, 21.628971558980897
#       From worker 7:	fold: 2, 86.9331839940285
#       From worker 4:	fold: 4, 168.28779155904192
#       From worker 6:	fold: 2, 16.324618584712667
#       From worker 3:	fold: 2, 25.519701255230284
#       From worker 7:	fold: 3, 38.61350378822452
#       From worker 5:	fold: 3, 92.84220158090513
#       From worker 4:	fold: 5, 67.7464438879212
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 95.22003254024179
#       From worker 4:	fold: 2, 43.95671704452378
#       From worker 6:	fold: 3, 87.29372070099043
#       From worker 7:	fold: 4, 18.71946526097673
#       From worker 4:	fold: 3, 71.92163247346436
#       From worker 3:	fold: 3, 75.49957386062943
#       From worker 5:	fold: 4, 48.48634769383659
#       From worker 4:	fold: 4, 161.8586462206134
#       From worker 4:	fold: 5, 57.45550997670167
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 11.915201129461682
#       From worker 6:	fold: 4, 29.6997150603739
#       From worker 4:	fold: 2, 30.6206699893303
#       From worker 7:	fold: 5, 84.51185604283572
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 113.63389755139603
#       From worker 7:	fold: 2, 41.71385516845674
#       From worker 4:	fold: 3, 17.466135566693577
#       From worker 3:	fold: 4, 62.27274166854296
#       From worker 4:	fold: 4, 60.00383913203571
#       From worker 4:	fold: 5, 27.59988219632224
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 54.93363286519182
#       From worker 7:	fold: 3, 150.85154968855312
#       From worker 5:	fold: 5, 45.40667225698452
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 35.594370174613886
#       From worker 7:	fold: 4, 18.85876240094968
#       From worker 5:	fold: 2, 184.9485609880602
#       From worker 7:	fold: 5, 84.92109265125097
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 36.4771213068644
#       From worker 5:	fold: 3, 81.38124318443379
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 4:	  ConvergenceWarning)
#       From worker 4:	fold: 2, 51.293384888574145
#       From worker 5:	fold: 4, 49.138620486618
#       From worker 4:	fold: 3, 541.8309940668594
#       From worker 6:	fold: 5, 27.34563450758119
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 152.4331495055207
#       From worker 5:	fold: 5, 20.083815604747922
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 132.464390873328
#       From worker 7:	fold: 2, 53.223668003989346
#       From worker 5:	fold: 2, 1114.9463121440872
#       From worker 5:	fold: 3, 503.525821650417
#       From worker 4:	fold: 4, 693.3968211731109
#       From worker 5:	fold: 4, 24.170172353983137
#       From worker 6:	fold: 2, 22.38468940130868
#       From worker 5:	fold: 5, 960.3228097511677
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 66.45110141516525
#       From worker 4:	fold: 5, 119.38173295416856
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 68.5012381279177
#       From worker 6:	fold: 3, 87.42563751580553
#       From worker 7:	fold: 3, 11.595340334435434
#       From worker 4:	fold: 2, 21.54326515129588
#       From worker 5:	fold: 2, 5.822224411259469
#       From worker 6:	fold: 4, 100.78823371897995
#       From worker 4:	fold: 3, 119.5750034339285
#       From worker 6:	fold: 5, 58.36521054227812
#       From worker 5:	fold: 3, 27.294148003942148
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 28.176789817378427
#       From worker 5:	fold: 4, 75.37344020470077
#       From worker 4:	fold: 4, 51.03352916598674
#       From worker 7:	fold: 4, 19.950956047638975
#       From worker 3:	fold: 5, 142.0562795913009
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 95.51497474170613
#       From worker 7:	fold: 5, 27.33924078093245
#       From worker 3:	fold: 2, 69.29535593744521
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 720.9761762242664
#       From worker 7:	fold: 2, 105.08387925431562
#       From worker 4:	fold: 5, 26.42248682051913
#       From worker 3:	fold: 3, 44.15691751951468
#       From worker 6:	fold: 2, 28.953813817492783
#       From worker 4:	errors: 0
#       From worker 5:	fold: 5, 112.06353246596738
#       From worker 5:	errors: 0
#       From worker 3:	fold: 4, 149.14314798831663
#       From worker 3:	fold: 5, 78.2281625637514
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 149.07724139301996
#       From worker 3:	fold: 2, 1427.8984605566159
#       From worker 7:	fold: 3, 86.55112033116335
#       From worker 3:	fold: 3, 72.50263510300007
#       From worker 6:	fold: 3, 20.535533238192855
#       From worker 7:	fold: 4, 137.48606184869385
#       From worker 3:	fold: 4, 56.25815817076675
#       From worker 3:	fold: 5, 118.03162046636503
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 218143.29890470486
#       From worker 7:	fold: 5, 70.3691894716945
#       From worker 7:	errors: 0
#       From worker 7:	fold: 2, 119.65672091449919
#       From worker 7:	fold: 3, 54.434970769566064
#       From worker 3:	fold: 2, 145588.10392596177
#       From worker 7:	fold: 4, 47.077010062982495
#       From worker 3:	fold: 3, 92635.80826653237
#       From worker 7:	fold: 5, 8.671029854760528
#       From worker 7:	errors: 0
#       From worker 3:	fold: 4, 22240.14613723371
#       From worker 2:	fold: 2, 29.550257351455393
#       From worker 6:	fold: 4, 33.12461522709907
#       From worker 6:	fold: 5, 47.91529980651729
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 131.4176005996978
#       From worker 3:	fold: 5, 53650.9093050787
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 89.16602512466159
#       From worker 3:	fold: 1, 52.07362300263326
#       From worker 6:	fold: 2, 52.96922357574247
#       From worker 6:	fold: 3, 28.197055572693642
#       From worker 6:	fold: 4, 29.024117471177924
#       From worker 2:	fold: 3, 43.542905299046375
#       From worker 6:	fold: 5, 30.133153282417922
#       From worker 6:	errors: 0
#       From worker 3:	fold: 2, 16.181305603412635
#       From worker 2:	fold: 4, 42.544229462693615
#       From worker 3:	fold: 3, 94.40522558524823
#       From worker 2:	fold: 5, 93.70908755692227
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 67.54892675735701
#       From worker 2:	fold: 1, 31.899234683900204
#       From worker 3:	fold: 4, 96.57355659044856
#       From worker 2:	fold: 2, 38.55193239406072
#       From worker 2:	fold: 3, 77.88064616951098
#       From worker 2:	fold: 4, 34.29799504183431
#       From worker 3:	fold: 5, 13.316852798757536
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 24.54113092543928
#       From worker 2:	fold: 5, 8.961270534091698
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 73.16495290880235
#       From worker 2:	fold: 2, 23.50884586848271
#       From worker 2:	fold: 3, 173.78331639960436
#       From worker 2:	fold: 4, 32.551488184627274
#       From worker 2:	fold: 5, 79.49722928566091
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 12.142718251454255
#       From worker 2:	fold: 2, 57.00673441825146
#       From worker 2:	fold: 3, 24.156476377838707
#       From worker 2:	fold: 4, 29.60134680519378
#       From worker 2:	fold: 5, 24.517676311171304
#       From worker 2:	errors: 0
#       From worker 3:	fold: 2, 50.41818020467726
#       From worker 2:	fold: 1, 13.723071826471562
#       From worker 2:	fold: 2, 40.54738522037743
#       From worker 3:	fold: 3, 19.3848415008855
#       From worker 2:	fold: 3, 101.85786552299946
#       From worker 3:	fold: 4, 15.79593795572122
#       From worker 2:	fold: 4, 69.42953469315958
#       From worker 2:	fold: 5, 7.051150828063986
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 99.0107180247839
#       From worker 3:	fold: 5, 83.0608854651782
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 50.49206814112196
#       From worker 2:	fold: 2, 26.340036569827816
#       From worker 2:	fold: 3, 19.25574961169232
#       From worker 2:	fold: 4, 165.72690628740457
#       From worker 3:	fold: 2, 43.35324109831735
#       From worker 2:	fold: 5, 84.19256349542181
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 42.863747346061814
#       From worker 3:	fold: 3, 60.7190136212485
#       From worker 3:	fold: 4, 115.19536200186265
#       From worker 2:	fold: 2, 121.9772193331281
#       From worker 3:	fold: 5, 148.53554114715294
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 152.66887694424295
#       From worker 3:	fold: 2, 59.94882162750783
#       From worker 2:	fold: 3, 18.44506597160163
#       From worker 3:	fold: 3, 41.07934777920059
#       From worker 2:	fold: 4, 15.328348344994085
#       From worker 3:	fold: 4, 41.990065020632564
#       From worker 3:	fold: 5, 54.59819431396873
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 27.4174288423068
#       From worker 2:	fold: 5, 104.63360114357705
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 85.58906135882617
#       From worker 3:	fold: 2, 143.80351908077756
#       From worker 3:	fold: 3, 6.787032915910293
#       From worker 2:	fold: 2, 59.06555888767943
#       From worker 3:	fold: 4, 120.67810092164659
#       From worker 3:	fold: 5, 38.98148073529027
#       From worker 3:	errors: 0
#       From worker 3:	fold: 2, 33.805515941396685
#       From worker 3:	fold: 1, 42.019964219470864
#       From worker 3:	fold: 3, 75.76430523749771
#       From worker 3:	fold: 2, 30.973207615635687
#       From worker 3:	fold: 4, 64.34875652992676
#       From worker 3:	fold: 3, 17.767814819123096
#       From worker 2:	fold: 3, 136.8297100803517
#       From worker 3:	fold: 5, 148.62975321326735
#       From worker 3:	errors: 0
#       From worker 3:	fold: 4, 128.13310796751838
#       From worker 3:	fold: 5, 35.340429588629085
#       From worker 3:	errors: 0
#       From worker 2:	fold: 4, 63.62902525439657
#       From worker 2:	fold: 5, 34.347851398212434
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 21.882223237458152
#       From worker 2:	fold: 2, 174.76681876188442
#       From worker 2:	fold: 3, 46.57370232306967
#       From worker 2:	fold: 4, 96.6013691796498
#       From worker 2:	fold: 5, 38.54003598558188
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 140.0574458383664
#       From worker 2:	fold: 2, 47.20848505299602
#       From worker 2:	fold: 3, 58.69381869836244
#       From worker 2:	fold: 4, 73.61335298322689
#       From worker 2:	fold: 5, 42.29602767082701
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 79.20768892341047
#       From worker 2:	fold: 2, 102.36390670555585
#       From worker 2:	fold: 3, 104.44604831879721
#       From worker 2:	fold: 4, 96.04298591979064
#       From worker 2:	fold: 5, 64.668394361083
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 50.673297057912336
#       From worker 2:	fold: 1, 126.625647549624
#       From worker 2:	fold: 1, 28.67919398050893
#       From worker 2:	fold: 2, 91.6254556538764
#       From worker 2:	fold: 3, 31.386672141244382
#       From worker 2:	fold: 4, 40.82221814847387
#       From worker 2:	fold: 5, 94.17824235549249
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 55.38930941739582
#       From worker 2:	fold: 2, 101.38611300413702
#       From worker 2:	fold: 3, 14.00027798103735
#       From worker 2:	fold: 4, 90.26097449610631
#       From worker 2:	fold: 5, 22.982639465644084
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 94.75476867284844
#       From worker 2:	fold: 2, 58.65558189514006
#       From worker 2:	fold: 3, 13.73591666488345
#       From worker 2:	fold: 4, 9.119327242560686
#       From worker 2:	fold: 5, 18.197024762608166
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 49.54286182674964
#       From worker 2:	fold: 2, 88.31242963155474
#       From worker 2:	fold: 3, 58.2648436099801
#       From worker 2:	fold: 4, 82.57420722743048
#       From worker 2:	fold: 5, 54.40270970363472
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 9.997915918715547
#       From worker 2:	fold: 2, 91.51495594396049
#       From worker 2:	fold: 3, 40.93526073426206
#       From worker 2:	fold: 4, 35.272594126213086
#       From worker 2:	fold: 5, 27.884750817709246
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 42.12828431141952
#       From worker 2:	fold: 2, 56.96100990436906
#       From worker 2:	fold: 3, 72.78239144916205
#       From worker 2:	fold: 4, 151.89112423714207
#       From worker 2:	fold: 5, 109.76200709044235
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 43.377977021791246
#       From worker 2:	fold: 2, 36.294650288928814
#       From worker 2:	fold: 3, 64.32647627505526
#       From worker 2:	fold: 4, 112.97570441491757
#       From worker 2:	fold: 5, 150.26184646827505
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 140.0402858331091
#       From worker 2:	fold: 2, 13293.626940820743
#       From worker 2:	fold: 3, 67.91669683555531
#       From worker 2:	fold: 4, 702.0124070594671
#       From worker 2:	fold: 5, 128.3114021926568
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 52.80671015503106
#       From worker 2:	fold: 1, 44.50018043835984
#       From worker 2:	fold: 2, 16.729006950763598
#       From worker 2:	fold: 3, 91.22544926174518
#       From worker 2:	fold: 4, 58.6960082113159
#       From worker 2:	fold: 5, 14.825445685099126
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 39.43398999226944
#       From worker 2:	fold: 2, 96.78303035561758
#       From worker 2:	fold: 3, 67.43695016862696
#       From worker 2:	fold: 4, 75.01943423994544
#       From worker 2:	fold: 5, 154.26654181835198
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 59.912338737277366
#       From worker 2:	fold: 2, 94.85974194460793
#       From worker 2:	fold: 3, 33.39588075784905
#       From worker 2:	fold: 4, 25.887377512624813
#       From worker 2:	fold: 5, 167.18594716673195
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 38.65906235359748
#       From worker 2:	fold: 1, 28.424896900771305
#       From worker 2:	fold: 2, 36.12322771517704
#       From worker 2:	fold: 3, 79.51714989783315
#       From worker 2:	fold: 4, 12.25554982380343
#       From worker 2:	fold: 5, 21.036288415313546
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 89.30350995548864
#       From worker 2:	fold: 2, 27.8362337603127
#       From worker 2:	fold: 3, 61.10834929746142
#       From worker 2:	fold: 4, 41.36640142410056
#       From worker 2:	fold: 5, 41.306852671641686
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 52.068673391104134
#       From worker 2:	fold: 2, 159.90174165529422
#       From worker 2:	fold: 3, 119.90158264477897
#       From worker 2:	fold: 4, 38.4624829337784
#       From worker 2:	fold: 5, 7.847480219177942
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 36.54564330012014
#       From worker 2:	fold: 2, 28.673726137237093
#       From worker 2:	fold: 3, 15.721924077383772
#       From worker 2:	fold: 4, 45.00614158503657
#       From worker 2:	fold: 5, 21.086153197962506
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 149.72972725427735
#       From worker 2:	fold: 2, 30.56205818442036
#       From worker 2:	fold: 3, 86.75705178606111
#       From worker 2:	fold: 4, 98.78993447223132
#       From worker 2:	fold: 5, 71.68901056515686
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 17.5401008744688
#       From worker 2:	fold: 2, 92.88470697242599
#       From worker 2:	fold: 3, 85.4117769508177
#       From worker 2:	fold: 4, 15.649367230103378
#       From worker 2:	fold: 5, 26.077809387473803
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 64.50128224602736
#       From worker 2:	fold: 2, 167.60548667123254
#       From worker 2:	fold: 3, 21.13340878571054
#       From worker 2:	fold: 4, 97.63935913287902
#       From worker 2:	fold: 5, 50.2659751836953
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 93.48348893596729
#       From worker 2:	fold: 2, 16.912254800807194
#       From worker 2:	fold: 3, 18.421744693811988
#       From worker 2:	fold: 4, 10.208589574385885
#       From worker 2:	fold: 5, 34.47664209524482
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 33.727176433467754
#       From worker 2:	fold: 2, 17.370728880692905
#       From worker 2:	fold: 2, 158.58358308487428
#       From worker 2:	fold: 2, 37.90179831944659
#       From worker 2:	fold: 2, 126.69057389575248
#       From worker 2:	fold: 2, 25.404334107597716
#       From worker 2:	fold: 2, 30.66224289415507
#       From worker 2:	fold: 3, 137.4731642257712
#       From worker 2:	fold: 3, 23.675411712512613
#       From worker 2:	fold: 3, 14.834594950065643
#       From worker 2:	fold: 3, 18.160891603989175
#       From worker 2:	fold: 3, 39.36386442145738
#       From worker 2:	fold: 3, 113.28464867722157
#       From worker 2:	fold: 4, 29.67435742659033
#       From worker 2:	fold: 4, 51.697328533081134
#       From worker 2:	fold: 4, 12.738661837185179
#       From worker 2:	fold: 4, 58.25743505197725
#       From worker 2:	fold: 4, 32.09636534776844
#       From worker 2:	fold: 4, 53.30752565115718
#       From worker 2:	fold: 5, 20.298201378510285
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 30.749305379526817
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 53.21759172925998
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 61.79088538647324
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 135.73835123641004
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 52.94823509674095
#       From worker 2:	errors: 0
# (serialtime = "6.0 minutes", paralleltime = "12.0 seconds")

# %%
dfres
# Out:
# 72×5 DataFrame
# │ Row │ pipeline                                                 │ mean      │ sd      │ time     │ folds │
# │     │ String                                                   │ Float64   │ Float64 │ Float64  │ Int64 │
# ├─────┼──────────────────────────────────────────────────────────┼───────────┼─────────┼──────────┼───────┤
# │ 1   │ RobustScaler |> FastICA |> ARDRegression                 │ 28.2562   │ 18.9152 │ 0.884838 │ 5     │
# │ 2   │ Noop |> Noop |> ARDRegression                            │ 29.4067   │ 11.7404 │ 7.73995  │ 5     │
# │ 3   │ RobustScaler |> Noop |> ARDRegression                    │ 29.485    │ 16.6679 │ 4.51522  │ 5     │
# │ 4   │ MinMaxScaler |> FastICA |> ARDRegression                 │ 29.5211   │ 18.6372 │ 2.46762  │ 5     │
# │ 5   │ Noop |> FastICA |> ARDRegression                         │ 29.7173   │ 16.0288 │ 2.90426  │ 5     │
# │ 6   │ StandardScaler |> FastICA |> ARDRegression               │ 31.7412   │ 10.1188 │ 3.06498  │ 5     │
# │ 7   │ StandardScaler |> Noop |> ARDRegression                  │ 34.7005   │ 34.0469 │ 8.18524  │ 5     │
# │ 8   │ Noop |> Noop |> GradientBoostingRegressor                │ 35.4714   │ 26.1603 │ 7.51235  │ 5     │
# │ 9   │ RobustScaler |> Noop |> GradientBoostingRegressor        │ 38.3182   │ 24.9221 │ 4.50711  │ 5     │
# │ 10  │ PowerTransformer |> Noop |> GradientBoostingRegressor    │ 38.6402   │ 28.299  │ 4.16924  │ 5     │
# │ 11  │ MinMaxScaler |> Noop |> ARDRegression                    │ 38.8925   │ 36.9417 │ 6.39702  │ 5     │
# │ 12  │ PowerTransformer |> Noop |> RandomForestRegressor        │ 41.1211   │ 30.4862 │ 7.11322  │ 5     │
# │ 13  │ Noop |> FastICA |> GradientBoostingRegressor             │ 42.7067   │ 24.9789 │ 1.1726   │ 5     │
# │ 14  │ MinMaxScaler |> Noop |> RandomForestRegressor            │ 45.1952   │ 31.7576 │ 7.52709  │ 5     │
# │ 15  │ MinMaxScaler |> Noop |> GradientBoostingRegressor        │ 46.5218   │ 39.5482 │ 4.73828  │ 5     │
# │ 16  │ RobustScaler |> FastICA |> RandomForestRegressor         │ 46.6328   │ 27.6351 │ 4.57917  │ 5     │
# │ 17  │ StandardScaler |> Noop |> RandomForestRegressor          │ 47.5128   │ 38.3016 │ 8.44698  │ 5     │
# │ 18  │ MinMaxScaler |> FastICA |> GradientBoostingRegressor     │ 48.7668   │ 40.493  │ 1.23876  │ 5     │
# │ 19  │ Noop |> FastICA |> RandomForestRegressor                 │ 49.0552   │ 34.573  │ 2.69242  │ 5     │
# │ 20  │ RobustScaler |> Noop |> rf                               │ 49.0637   │ 46.4996 │ 11.1315  │ 5     │
# │ 21  │ MinMaxScaler |> FastICA |> RandomForestRegressor         │ 49.1535   │ 26.5464 │ 2.75394  │ 5     │
# │ 22  │ PowerTransformer |> Noop |> rf                           │ 50.8469   │ 44.1042 │ 1.8557   │ 5     │
# │ 23  │ RobustScaler |> FastICA |> GradientBoostingRegressor     │ 50.975    │ 56.5442 │ 1.51872  │ 5     │
# │ 24  │ StandardScaler |> FastICA |> RandomForestRegressor       │ 51.3275   │ 37.2659 │ 2.87285  │ 5     │
# │ 25  │ Noop |> Noop |> RandomForestRegressor                    │ 52.1843   │ 23.9042 │ 8.09828  │ 5     │
# │ 26  │ StandardScaler |> Noop |> rf                             │ 54.2524   │ 45.9017 │ 9.26788  │ 5     │
# │ 27  │ StandardScaler |> FastICA |> GradientBoostingRegressor   │ 54.28     │ 54.6038 │ 1.43984  │ 5     │
# │ 28  │ Noop |> FastICA |> rf                                    │ 54.3482   │ 44.309  │ 3.29399  │ 5     │
# │ 29  │ MinMaxScaler |> Noop |> rf                               │ 54.4731   │ 50.5457 │ 9.92044  │ 5     │
# │ 30  │ RobustScaler |> Noop |> RandomForestRegressor            │ 54.5101   │ 40.4131 │ 4.2981   │ 5     │
# │ 31  │ Noop |> Noop |> rf                                       │ 56.786    │ 33.2907 │ 8.42066  │ 5     │
# │ 32  │ Normalizer |> Noop |> GradientBoostingRegressor          │ 56.8039   │ 39.0031 │ 6.43518  │ 5     │
# │ 33  │ Normalizer |> Noop |> RandomForestRegressor              │ 57.3384   │ 32.7887 │ 6.5612   │ 5     │
# │ 34  │ StandardScaler |> FastICA |> rf                          │ 57.4009   │ 41.7124 │ 2.88826  │ 5     │
# │ 35  │ MinMaxScaler |> FastICA |> rf                            │ 57.4151   │ 39.6069 │ 2.92019  │ 5     │
# │ 36  │ RobustScaler |> FastICA |> rf                            │ 59.3912   │ 40.1259 │ 3.66374  │ 5     │
# │ 37  │ StandardScaler |> Noop |> GradientBoostingRegressor      │ 60.6496   │ 49.6166 │ 4.93115  │ 5     │
# │ 38  │ PowerTransformer |> FastICA |> rf                        │ 63.0758   │ 54.7778 │ 10.5345  │ 5     │
# │ 39  │ Normalizer |> Noop |> rf                                 │ 63.5413   │ 39.3492 │ 9.56461  │ 5     │
# │ 40  │ MinMaxScaler |> Noop |> GaussianProcessRegressor         │ 66.6194   │ 17.577  │ 6.38583  │ 5     │
# │ 41  │ PowerTransformer |> Noop |> GaussianProcessRegressor     │ 67.5335   │ 60.7374 │ 1.956    │ 5     │
# │ 42  │ PowerTransformer |> Noop |> ARDRegression                │ 70.0571   │ 46.8864 │ 1.78725  │ 5     │
# │ 43  │ PowerTransformer |> FastICA |> RandomForestRegressor     │ 71.4168   │ 43.5434 │ 3.28054  │ 5     │
# │ 44  │ PowerTransformer |> FastICA |> ARDRegression             │ 72.3738   │ 39.7106 │ 5.99459  │ 5     │
# │ 45  │ MinMaxScaler |> FastICA |> SVR                           │ 74.2293   │ 65.886  │ 2.62155  │ 5     │
# │ 46  │ Noop |> Noop |> SVR                                      │ 75.6364   │ 62.4354 │ 7.72163  │ 5     │
# │ 47  │ PowerTransformer |> FastICA |> SVR                       │ 75.6728   │ 62.0013 │ 5.66798  │ 5     │
# │ 48  │ PowerTransformer |> FastICA |> GradientBoostingRegressor │ 75.8922   │ 38.6227 │ 5.54263  │ 5     │
# │ 49  │ StandardScaler |> Noop |> GaussianProcessRegressor       │ 76.2483   │ 57.5662 │ 7.28935  │ 5     │
# │ 50  │ RobustScaler |> Noop |> SVR                              │ 76.5012   │ 59.6315 │ 4.46592  │ 5     │
# │ 51  │ RobustScaler |> Noop |> GaussianProcessRegressor         │ 78.9052   │ 59.7732 │ 4.70949  │ 5     │
# │ 52  │ StandardScaler |> Noop |> SVR                            │ 80.2291   │ 56.0696 │ 8.15918  │ 5     │
# │ 53  │ Normalizer |> Noop |> ARDRegression                      │ 81.4473   │ 48.7613 │ 6.8011   │ 5     │
# │ 54  │ Noop |> FastICA |> SVR                                   │ 81.9958   │ 53.2906 │ 2.51365  │ 5     │
# │ 55  │ Normalizer |> FastICA |> rf                              │ 82.3429   │ 42.3186 │ 5.2933   │ 5     │
# │ 56  │ PowerTransformer |> Noop |> SVR                          │ 83.659    │ 45.9738 │ 1.93584  │ 5     │
# │ 57  │ StandardScaler |> FastICA |> SVR                         │ 84.2794   │ 48.5538 │ 2.71139  │ 5     │
# │ 58  │ RobustScaler |> FastICA |> SVR                           │ 84.5384   │ 47.8614 │ 0.940843 │ 5     │
# │ 59  │ Normalizer |> FastICA |> GradientBoostingRegressor       │ 86.0825   │ 46.4223 │ 2.22208  │ 5     │
# │ 60  │ MinMaxScaler |> Noop |> SVR                              │ 86.588    │ 43.0361 │ 7.2638   │ 5     │
# │ 61  │ Normalizer |> Noop |> SVR                                │ 86.705    │ 44.2902 │ 6.79048  │ 5     │
# │ 62  │ Normalizer |> FastICA |> SVR                             │ 87.2677   │ 39.2423 │ 3.05141  │ 5     │
# │ 63  │ Noop |> Noop |> GaussianProcessRegressor                 │ 87.5056   │ 43.2795 │ 7.75242  │ 5     │
# │ 64  │ PowerTransformer |> FastICA |> GaussianProcessRegressor  │ 89.3458   │ 16.986  │ 6.12283  │ 5     │
# │ 65  │ Normalizer |> FastICA |> RandomForestRegressor           │ 95.3255   │ 41.8017 │ 2.08883  │ 5     │
# │ 66  │ Noop |> FastICA |> GaussianProcessRegressor              │ 224.093   │ 278.884 │ 3.02383  │ 5     │
# │ 67  │ RobustScaler |> FastICA |> GaussianProcessRegressor      │ 261.291   │ 352.879 │ 1.10596  │ 5     │
# │ 68  │ MinMaxScaler |> FastICA |> GaussianProcessRegressor      │ 292.167   │ 303.097 │ 2.75892  │ 5     │
# │ 69  │ Normalizer |> FastICA |> ARDRegression                   │ 364.754   │ 595.45  │ 3.11437  │ 5     │
# │ 70  │ StandardScaler |> FastICA |> GaussianProcessRegressor    │ 547.086   │ 484.892 │ 2.69576  │ 5     │
# │ 71  │ Normalizer |> Noop |> GaussianProcessRegressor           │ 2866.38   │ 5834.67 │ 6.82477  │ 5     │
# │ 72  │ Normalizer |> FastICA |> GaussianProcessRegressor        │ 1.06452e5 │ 77583.9 │ 3.23473  │ 5     │

# %%
module RMachine

using RCall
using DataFrames
using Random

using AMLPipelineBase
using AMLPipelineBase.AbsTypes
using AMLPipelineBase.Utils


import AMLPipelineBase.AbsTypes: fit!, transform!

export CRTLearner,fit!,transform!,fit_transform!
export caretrun, crossvalidate

const RLearners=["rf","gbm"]

mutable struct CRTLearner <: Learner
   name
   model
   function CRTLearner(args::Dict{Symbol,<:Any} = Dict())
      fitControl="trainControl(method = 'none')"
      default_args = Dict{Symbol,Any}(
                      :name => "rlearner",
                      :learner => "rf",
                      :fitControl => fitControl,
                      :impl_args => Dict{Symbol,Any}()
                     )
      cargs = nested_dict_merge(default_args, args)
      cargs[:name] = cargs[:name]*"_"*randstring(3)
      rl = cargs[:learner]
      if !(rl in RLearners)
         println("$rl is not supported.")
         println()
         throw(ArgumentError("Argument keyword error"))
      end
      new(cargs[:name],cargs)
   end
end

function fit!(crt::CRTLearner,x::DataFrame,y::Vector)
   rmodel = rcall(:train,x,y,method=crt.model[:learner],trControl = reval(crt.model[:fitControl]))
   crt.model[:rmodel] = rmodel
end

function transform!(crt::CRTLearner,x::DataFrame)
   res = rcall(:predict,crt.model[:rmodel],x)
   return rcopy(res) |> Array
end


end
# Out:
# WARNING: replacing module RMachine.
# Main.RMachine

# %%
module RTest
using Test
using DataFrames
using RDatasets

using ..RMachine

function caretrun()
   rf = CRTLearner(Dict(:learner=>"rf"))
   gbm = CRTLearner(Dict(:learner=>"gbm"))
   iris=dataset("datasets","iris")
   x=iris[:,1:4]
   y=iris[:,5] |> Array{String}
   @test (fit_transform!(rf,x,y) .== y ) |> sum == 150
   @test crossvalidate(rf,x,y,"accuracy_score",3,false).mean > 0.80
end
@testset "rmachine tests" begin
   caretrun()
end
end
# Out:
# Test Summary:  | Pass  Total
# rmachine tests |    2      2
# WARNING: replacing module RTest.
# Main.RTest

# %%
@everywhere using JuliaR

# %%
r_rf = JuliaR.CRTLearner(Dict(:name=>"RFfromR",:learner=>"rf"));

# %%
function prpsearch(X,Y)
    learners = [sk_rf,sk_gb,sk_svr,sk_ard,sk_gp,jl_rf,r_rf];
    scalers = [rb,pt,norm,mx,mstd,noop];
    extractors = [ica,noop];
    dftable = @sync @distributed (vcat) for lr in learners
    @distributed (vcat) for sc in scalers
     @distributed (vcat) for xt  in extractors
          pipe  = @pipeline (numf |> sc |> xt)  |> lr
          scn   = sc.name[1:end - 4]; xtn = xt.name[1:end - 4]; lrn = lr.name[1:end - 4]
          pname = "$scn |> $xtn |> $lrn"
          ptime = @elapsed begin
             mean, sd, kfold, _ = crossvalidate(pipe, X, Y, rmse, 5,true)
          end
          DataFrame(pipeline=pname, mean=mean, sd=sd, time=ptime, folds=kfold)
        end
     end
    end
    sort!(dftable, :mean, rev=false);
    dftable
end

runtime = @elapsed begin
    dfres = prpsearch(X,Y)
end;
serialtime = dfres.time |> sum;

(serialtime = "$(round(serialtime / 60.0)) minutes", 
    paralleltime = "$(round(runtime)) seconds")
# Out:
#       From worker 8:	fold: 1, 17.37625575290625
#       From worker 7:	fold: 1, 16.07191851750751
#       From worker 7:	fold: 1, 19.181015487619263
#       From worker 7:	fold: 2, 98.85924279948307
#       From worker 8:	fold: 2, 71.20823953939491
#       From worker 7:	fold: 3, 38.5244147269735
#       From worker 4:	fold: 1, 95.15695930007472
#       From worker 5:	fold: 1, 9.240200905707054
#       From worker 3:	fold: 1, 39.82829273265745
#       From worker 4:	fold: 2, 14.615407461674936
#       From worker 5:	fold: 2, 27.0093095126894
#       From worker 4:	fold: 3, 101.40513138011558
#       From worker 6:	fold: 1, 77.23381225142415
#       From worker 4:	fold: 4, 158.35594186613275
#       From worker 4:	fold: 5, 18.341582595914815
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 71.8370705318638
#       From worker 6:	fold: 2, 1436.3862661093217
#       From worker 5:	fold: 3, 76.94722996327246
#       From worker 6:	fold: 3, 937.4681504106672
#       From worker 5:	fold: 4, 18.354640985784016
#       From worker 6:	fold: 4, 861.926943821566
#       From worker 6:	fold: 5, 75.26119253387476
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 24.545987652184127
#       From worker 7:	fold: 4, 17.129193710493798
#       From worker 5:	fold: 5, 17.132995448118514
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 64.09652694731663
#       From worker 4:	fold: 2, 101.5984132334387
#       From worker 8:	fold: 3, 99.21605527070494
#       From worker 3:	fold: 2, 26.690479248104296
#       From worker 7:	fold: 5, 67.3280495061895
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 72.57214147008281
#       From worker 4:	fold: 3, 142.7158683768532
#       From worker 6:	fold: 2, 30.61746203276805
#       From worker 3:	fold: 3, 31.969873901122806
#       From worker 5:	fold: 2, 23.667954541464198
#       From worker 2:	fold: 1, 93.13166183593883
#       From worker 7:	fold: 2, 71.95583847908925
#       From worker 3:	fold: 4, 138.72930178243692
#       From worker 7:	fold: 3, 38.24255406113554
#       From worker 3:	fold: 5, 34.833863162238444
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 69.41210453440829
#       From worker 4:	fold: 4, 39.534217184364664
#       From worker 6:	fold: 3, 85.95881301408929
#       From worker 7:	fold: 4, 34.41529444888344
#       From worker 5:	fold: 3, 35.19777938861113
#       From worker 7:	fold: 5, 14.040808274499922
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 51.8723043607304
#       From worker 7:	fold: 2, 19.37035195039566
#       From worker 4:	fold: 5, 57.80072947364092
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 67.23470929226599
#       From worker 7:	fold: 3, 10.184003154010412
#       From worker 8:	fold: 4, 27.32810848160979
#       From worker 6:	fold: 4, 22.547222796803947
#       From worker 3:	fold: 2, 53.7633125331019
#       From worker 4:	fold: 2, 93.37020907230833
#       From worker 7:	fold: 4, 17.849867522005567
#       From worker 7:	fold: 5, 59.21698412410244
#       From worker 7:	errors: 0
#       From worker 4:	fold: 3, 78.85030787676762
#       From worker 7:	fold: 1, 27.81984293038344
#       From worker 7:	fold: 2, 14.571135085733323
#       From worker 5:	fold: 4, 114.86232399643795
#       From worker 4:	fold: 4, 131.64321195992704
#       From worker 7:	fold: 3, 74.75106402320098
#       From worker 7:	fold: 4, 192.97780762990112
#       From worker 6:	fold: 5, 43.25756959281367
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 74.2291800697252
#       From worker 7:	fold: 5, 32.02076236094912
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 90.28624707809651
#       From worker 4:	fold: 5, 173.80907938065036
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 50.06652871880829
#       From worker 4:	fold: 2, 25.288250552714075
#       From worker 7:	fold: 2, 62.297980813160315
#       From worker 3:	fold: 3, 72.94807857418414
#       From worker 7:	fold: 3, 128.46404091574433
#       From worker 7:	fold: 4, 103.8047174768349
#       From worker 4:	fold: 3, 14.982618611539987
#       From worker 5:	fold: 5, 23.64700929632538
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 8.814010961760827
#       From worker 7:	fold: 5, 281.25677180982865
#       From worker 7:	errors: 0
#       From worker 6:	fold: 2, 101.69997003750646
#       From worker 7:	fold: 2, 115.05926813267354
#       From worker 7:	fold: 3, 16.007802631329067
#       From worker 4:	fold: 4, 33.71624700936476
#       From worker 7:	fold: 4, 69.70258481112288
#       From worker 4:	fold: 5, 28.319756171028686
#       From worker 5:	fold: 2, 7.479088880425096
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 51.8853065264154
#       From worker 6:	fold: 3, 23.340124069475007
#       From worker 7:	fold: 5, 59.561200698281894
#       From worker 7:	errors: 0
#       From worker 5:	fold: 3, 66.50153011881818
#       From worker 6:	fold: 4, 44.73369801701731
#       From worker 8:	fold: 5, 49.825842042216514
#       From worker 8:	errors: 0
#       From worker 3:	fold: 4, 102.91871223787203
#       From worker 5:	fold: 4, 72.28259728474207
#       From worker 6:	fold: 5, 12.431287611856153
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 12.233860402146275
#       From worker 6:	fold: 2, 46.22863877513356
#       From worker 5:	fold: 5, 16.87389085265927
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 46.485275658600294
#       From worker 6:	fold: 3, 35.17055967187214
#       From worker 6:	fold: 4, 18.562492967277365
#       From worker 3:	fold: 5, 97.82068712417147
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 89.68045780958049
#       From worker 6:	fold: 5, 61.35330743023314
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 51.63175882237249
#       From worker 4:	fold: 2, 23.584959474870747
#       From worker 3:	fold: 2, 164.18428083052646
#       From worker 3:	fold: 3, 1968.1897964537968
#       From worker 3:	fold: 4, 89.52786539639173
#       From worker 3:	fold: 5, 53.63247589610269
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 50.18439437343658
#       From worker 5:	fold: 2, 27.29020769570811
#       From worker 6:	fold: 2, 100.92900614152619
#       From worker 4:	fold: 3, 37.03895992190309
#       From worker 3:	fold: 2, 100.52374415930511
#       From worker 5:	fold: 3, 46.91539186252518
#       From worker 4:	fold: 4, 17.510584216214667
#       From worker 6:	fold: 3, 25.634351577205983
#       From worker 3:	fold: 3, 40.53576034309155
#       From worker 5:	fold: 4, 123.04955250441675
#       From worker 3:	fold: 4, 51.007238152951274
#       From worker 4:	fold: 5, 105.30639906292683
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 133.66459867009814
#       From worker 6:	fold: 4, 46.02018828910568
#       From worker 4:	fold: 2, 386.5275864112837
#       From worker 4:	fold: 3, 365.3280211386568
#       From worker 4:	fold: 4, 49.71944463874987
#       From worker 4:	fold: 5, 115.27279902166104
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 59.76951636768083
#       From worker 4:	fold: 2, 23.53807307203121
#       From worker 4:	fold: 3, 110.71860680172107
#       From worker 4:	fold: 4, 68.51148731164017
#       From worker 4:	fold: 5, 25.962253844701777
#       From worker 4:	errors: 0
#       From worker 5:	fold: 5, 71.48846127639723
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 156.74970093155935
#       From worker 5:	fold: 2, 29.929796993817476
#       From worker 5:	fold: 3, 70.1102142764978
#       From worker 5:	fold: 4, 117.4011628397889
#       From worker 5:	fold: 5, 27.88638612646875
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 75.86728139617546
#       From worker 5:	fold: 2, 914.4738367376015
#       From worker 5:	fold: 3, 50.07593688023203
#       From worker 5:	fold: 4, 1033.554529892196
#       From worker 5:	fold: 5, 46.147907186725
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 49.72217395540477
#       From worker 3:	fold: 5, 165.03035010197033
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 32.72344908497791
#       From worker 5:	fold: 2, 49.61260889846107
#       From worker 3:	fold: 2, 165.45713084205215
#       From worker 3:	fold: 3, 39.8504911998074
#       From worker 3:	fold: 4, 114.82900208344493
#       From worker 3:	fold: 5, 32.19432731468961
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 128544.76688350207
#       From worker 3:	fold: 2, 48580.62637539865
#       From worker 5:	fold: 3, 101.79749564946384
#       From worker 6:	fold: 5, 30.018291038972464
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 38.638824819774314
#       From worker 6:	fold: 2, 34.313481464378576
#       From worker 5:	fold: 4, 52.504349872796894
#       From worker 3:	fold: 3, 39085.61944481998
#       From worker 5:	fold: 5, 9.688070360547842
#       From worker 5:	errors: 0
#       From worker 3:	fold: 4, 97260.07305294329
#       From worker 6:	fold: 3, 47.98165793034724
#       From worker 3:	fold: 5, 39292.132179397966
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 140.98329876579325
#       From worker 6:	fold: 4, 178.17533300924734
#       From worker 3:	fold: 1, 42.752850936412045
#       From worker 6:	fold: 5, 90.16055809198498
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 38.53542100812605
#       From worker 6:	fold: 2, 118.17097538274744
#       From worker 6:	fold: 3, 53.20845875349788
#       From worker 6:	fold: 4, 34.599106620989225
#       From worker 6:	fold: 5, 42.01150961563016
#       From worker 6:	errors: 0
#       From worker 3:	fold: 2, 42.10176492928447
#       From worker 3:	fold: 3, 25.231566982558416
#       From worker 3:	fold: 4, 94.09421646124046
#       From worker 2:	fold: 2, 26.982321830126157
#       From worker 2:	fold: 3, 37.698074131911795
#       From worker 2:	fold: 4, 74.0485551133328
#       From worker 3:	fold: 5, 43.07475555158154
#       From worker 2:	fold: 5, 34.544219486023
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 125.40823725327485
#       From worker 2:	fold: 1, 92.95305831143187
#       From worker 2:	fold: 2, 101.85030928835526
#       From worker 2:	fold: 3, 538.2969885157771
#       From worker 2:	fold: 4, 113.15620107387292
#       From worker 2:	fold: 5, 190174.31409713445
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 65.31611167297116
#       From worker 3:	errors: 0
#       From worker 2:	fold: 1, 14.135861510107812
#       From worker 3:	fold: 1, 12.577544618752885
#       From worker 2:	fold: 2, 73.95142237569202
#       From worker 3:	fold: 2, 43.80376964187135
#       From worker 2:	fold: 3, 34.97040174619414
#       From worker 3:	fold: 3, 45.93746424717228
#       From worker 2:	fold: 4, 52.210140338598926
#       From worker 2:	fold: 5, 19.76635109202839
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 18.926077162540476
#       From worker 3:	fold: 4, 40.56964008150129
#       From worker 2:	fold: 2, 54.37288415611651
#       From worker 2:	fold: 3, 17.974270620573613
#       From worker 2:	fold: 4, 31.888910113892244
#       From worker 2:	fold: 5, 75.45420220901451
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 23.180187760458793
#       From worker 2:	fold: 2, 66.90308335229959
#       From worker 3:	fold: 5, 138.20400259885966
#       From worker 3:	errors: 0
#       From worker 3:	fold: 2, 34.1238636518916
#       From worker 2:	fold: 3, 36.944324104450544
#       From worker 2:	fold: 4, 169.81111238881422
#       From worker 3:	fold: 1, 46.484195139751854
#       From worker 2:	fold: 5, 92.0383516623555
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 84.68071240305723
#       From worker 2:	fold: 2, 152.68794362643308
#       From worker 2:	fold: 3, 50.82949754903992
#       From worker 2:	fold: 4, 91.28613841608454
#       From worker 2:	fold: 5, 61.15338431299954
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 77.53951352198565
#       From worker 3:	fold: 2, 42.718434500935736
#       From worker 3:	fold: 3, 152.21950243286852
#       From worker 3:	fold: 4, 64.58196051766141
#       From worker 3:	fold: 5, 55.07788303473611
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 107.51513791731936
#       From worker 2:	fold: 2, 64.61919209389559
#       From worker 2:	fold: 3, 54.23931090716236
#       From worker 2:	fold: 4, 23.588306701114494
#       From worker 2:	fold: 5, 126.76695440400073
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 150.69200688078826
#       From worker 3:	fold: 2, 8.92257212213912
#       From worker 2:	fold: 2, 41.81750148330945
#       From worker 2:	fold: 3, 48.44467607826297
#       From worker 2:	fold: 4, 53.829694430009724
#       From worker 2:	fold: 5, 66.22621801002317
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 127.21800633010702
#       From worker 3:	fold: 3, 27.576438614084815
#       From worker 2:	fold: 2, 82.55138063138145
#       From worker 3:	fold: 4, 29.08720573084923
#       From worker 2:	fold: 3, 33.37546330730249
#       From worker 3:	fold: 5, 54.60279554769275
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 29.632711716986922
#       From worker 3:	fold: 1, 30.476090581247114
#       From worker 3:	fold: 2, 198.28436087481526
#       From worker 3:	fold: 3, 41.158661140693106
#       From worker 3:	fold: 4, 33.54905734525566
#       From worker 3:	fold: 5, 22.642501231394714
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 25.805162976017765
#       From worker 3:	fold: 2, 162.95625600577856
#       From worker 3:	fold: 3, 9.03717819469032
#       From worker 3:	fold: 4, 30.43310788106522
#       From worker 3:	fold: 5, 83.03095289312145
#       From worker 3:	errors: 0
#       From worker 3:	fold: 3, 68.93959780535744
#       From worker 3:	fold: 2, 43.583487902738185
#       From worker 3:	fold: 4, 66.12039465541932
#       From worker 3:	fold: 3, 115.79928340815677
#       From worker 3:	fold: 5, 100.16366875683671
#       From worker 3:	errors: 0
#       From worker 3:	fold: 4, 40.9916886527263
#       From worker 3:	fold: 5, 50.13699997923039
#       From worker 3:	errors: 0
#       From worker 2:	fold: 4, 101.23017049243036
#       From worker 2:	fold: 5, 55.76775993489816
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 49.58772844126351
#       From worker 2:	fold: 1, 151.50944316798558
#       From worker 2:	fold: 2, 38.56300144723968
#       From worker 2:	fold: 3, 61.96508568992265
#       From worker 2:	fold: 4, 84.41246360552377
#       From worker 2:	fold: 5, 93.70706611151503
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 83.9922228089395
#       From worker 2:	fold: 2, 70.67578710397115
#       From worker 2:	fold: 3, 81.21937618740851
#       From worker 2:	fold: 4, 192.79801149657504
#       From worker 2:	fold: 5, 89.42094100202667
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 17.543369218612316
#       From worker 2:	fold: 1, 46.15353204045846
#       From worker 2:	fold: 2, 94.40889799710995
#       From worker 2:	fold: 3, 36.44560531731587
#       From worker 2:	fold: 4, 40.7968579145833
#       From worker 2:	fold: 5, 16.902187770810613
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 35.45407364876833
#       From worker 2:	fold: 2, 32.95322615152428
#       From worker 2:	fold: 3, 67.1625658847001
#       From worker 2:	fold: 4, 89.10205176223742
#       From worker 2:	fold: 5, 26.171532414839216
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 119.6651784202633
#       From worker 2:	fold: 2, 25.06582556094666
#       From worker 2:	fold: 3, 15.148018873903776
#       From worker 2:	fold: 4, 62.786109854929165
#       From worker 2:	fold: 5, 18.020421765401387
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 26.800671823173968
#       From worker 2:	fold: 2, 38.861195229249255
#       From worker 2:	fold: 3, 34.416129206304966
#       From worker 2:	fold: 4, 51.59756208487829
#       From worker 2:	fold: 5, 196.78244765305487
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 105.00925971093345
#       From worker 2:	fold: 2, 168.07282958418028
#       From worker 2:	fold: 3, 24.8350245795907
#       From worker 2:	fold: 4, 36.35819266196528
#       From worker 2:	fold: 5, 12.234455041239745
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 36.63709493800656
#       From worker 2:	fold: 2, 60.61319019783186
#       From worker 2:	fold: 3, 95.72045568732005
#       From worker 2:	fold: 4, 12.62049113625508
#       From worker 2:	fold: 5, 8.454791378195788
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 46.70701823647661
#       From worker 2:	fold: 2, 49.56281852791725
#       From worker 2:	fold: 3, 46.35226097434049
#       From worker 2:	fold: 4, 64.96165555408025
#       From worker 2:	fold: 5, 12.160999781802952
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 12.58593310359977
#       From worker 2:	fold: 2, 33.29850620479759
#       From worker 2:	fold: 3, 56.55217080327228
#       From worker 2:	fold: 4, 15.089270945471197
#       From worker 2:	fold: 5, 92.03812840147556
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 97.67012393833397
#       From worker 2:	fold: 2, 58.988138420919704
#       From worker 2:	fold: 3, 18.047818069642798
#       From worker 2:	fold: 4, 39.223229599951665
#       From worker 2:	fold: 5, 55.102607715149915
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 135.4113343319633
#       From worker 2:	fold: 2, 44.736533153638455
#       From worker 2:	fold: 3, 24.243062192914376
#       From worker 2:	fold: 4, 149.10954840089857
#       From worker 2:	fold: 5, 39.81740835889948
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 6.471334328891898
#       From worker 2:	fold: 1, 105.81622378155014
#       From worker 2:	fold: 2, 61.44529763745993
#       From worker 2:	fold: 3, 41.01679261859065
#       From worker 2:	fold: 4, 87.3808246094166
#       From worker 2:	fold: 5, 50.031485200093684
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 19.069973112004707
#       From worker 2:	fold: 2, 134.82431108027032
#       From worker 2:	fold: 3, 120.92580245847199
#       From worker 2:	fold: 4, 18.029232558912284
#       From worker 2:	fold: 5, 22.15160297790936
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 35.26851690675266
#       From worker 2:	fold: 2, 18.717991275684426
#       From worker 2:	fold: 3, 64.95190322578209
#       From worker 2:	fold: 4, 16.5579035875168
#       From worker 2:	fold: 5, 45.534050199965186
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 62.70344237756136
#       From worker 2:	fold: 2, 20.966610319308263
#       From worker 2:	fold: 3, 37.46263148845632
#       From worker 2:	fold: 4, 21.2184937950007
#       From worker 2:	fold: 5, 135.30693910095215
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 33.430092987090525
#       From worker 2:	fold: 1, 68.65035638631974
#       From worker 2:	fold: 2, 60.50428537076656
#       From worker 2:	fold: 3, 131.2085633002886
#       From worker 2:	fold: 4, 65.30780640840766
#       From worker 2:	fold: 5, 195.95072766721273
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 10.025051665671679
#       From worker 2:	fold: 2, 43.388628390936205
#       From worker 2:	fold: 3, 30.125895454795213
#       From worker 2:	fold: 4, 96.24304361395491
#       From worker 2:	fold: 5, 35.59575498684315
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 46.052218798829244
#       From worker 2:	fold: 2, 125.66815898574525
#       From worker 2:	fold: 3, 32.573206479135806
#       From worker 2:	fold: 4, 146.70219724490184
#       From worker 2:	fold: 5, 47.25163695191213
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 99.02986158932254
#       From worker 2:	fold: 2, 29.87567188384357
#       From worker 2:	fold: 3, 28.836332124693243
#       From worker 2:	fold: 4, 72.2121012645799
#       From worker 2:	fold: 5, 111.51917003128808
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 99.58648817783012
#       From worker 2:	fold: 2, 102.35893456395544
#       From worker 2:	fold: 3, 26.961387877097792
#       From worker 2:	fold: 4, 150.53949117313996
#       From worker 2:	fold: 5, 40.61502537460356
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 7.447929798381182
#       From worker 2:	fold: 2, 58.77588714058778
#       From worker 2:	fold: 3, 86.73405445125903
#       From worker 2:	fold: 4, 39.22304226259708
#       From worker 2:	fold: 5, 39.575400257726365
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 77.04801385643
#       From worker 2:	fold: 2, 33.446200180056024
#       From worker 2:	fold: 3, 14.35741688538654
#       From worker 2:	fold: 4, 39.84574758889504
#       From worker 2:	fold: 5, 24.652613954880717
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 9.899992584728565
#       From worker 2:	fold: 2, 16.140525587078866
#       From worker 2:	fold: 3, 87.93530328853423
#       From worker 2:	fold: 4, 15.432730840654896
#       From worker 2:	fold: 5, 8.367310957855342
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 77.28152034876757
#       From worker 2:	fold: 2, 15.029657391068081
#       From worker 2:	fold: 3, 49.60308474459218
#       From worker 2:	fold: 4, 24.965145911855593
#       From worker 2:	fold: 5, 187.2053540010188
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 28.42703175024322
#       From worker 2:	fold: 2, 71.34441783510248
#       From worker 2:	fold: 3, 121.4930457509623
#       From worker 2:	fold: 4, 47.81234644432604
#       From worker 2:	fold: 5, 151.10883269630438
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 29.677161070443905
#       From worker 2:	fold: 2, 61.56831969177046
#       From worker 2:	fold: 3, 59.63175265373281
#       From worker 2:	fold: 4, 26.61316993199348
#       From worker 2:	fold: 5, 110.68749788457558
#       From worker 2:	errors: 0
#       From worker 2:	fold: 2, 75.81530075834064
#       From worker 2:	fold: 2, 41.22615777925458
#       From worker 2:	fold: 2, 156.32301448812947
#       From worker 2:	fold: 2, 3.054403294260864
#       From worker 2:	fold: 2, 33.278880034870966
#       From worker 2:	fold: 2, 140.1266924180221
#       From worker 2:	fold: 3, 34.417115862858914
#       From worker 2:	fold: 3, 8.01365205498189
#       From worker 2:	fold: 3, 58.516710107666704
#       From worker 2:	fold: 3, 39.513724204609794
#       From worker 2:	fold: 4, 148.15860265814578
#       From worker 2:	fold: 3, 25.627544825331995
#       From worker 2:	fold: 3, 3.6415660856000214
#       From worker 2:	fold: 4, 49.958966421020264
#       From worker 2:	fold: 4, 123.08122203309871
#       From worker 2:	fold: 4, 45.05349136024196
#       From worker 2:	fold: 5, 46.526157385290205
#       From worker 2:	errors: 0
#       From worker 2:	fold: 4, 42.975863215717055
#       From worker 2:	fold: 4, 22.118525615197832
#       From worker 2:	fold: 5, 19.1592515355501
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 37.33226036870402
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 63.83829767483883
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 133.38248975918677
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 32.80132329425288
#       From worker 2:	errors: 0
# (serialtime = "14.0 minutes", paralleltime = "29.0 seconds")

# %%
dfres
# Out:
# 84×5 DataFrame
# │ Row │ pipeline                                                 │ mean    │ sd      │ time     │ folds │
# │     │ String                                                   │ Float64 │ Float64 │ Float64  │ Int64 │
# ├─────┼──────────────────────────────────────────────────────────┼─────────┼─────────┼──────────┼───────┤
# │ 1   │ Noop |> Noop |> ARDRegression                            │ 27.5552 │ 33.9223 │ 18.1298  │ 5     │
# │ 2   │ RobustScaler |> FastICA |> ARDRegression                 │ 29.7369 │ 27.1329 │ 2.37118  │ 5     │
# │ 3   │ MinMaxScaler |> FastICA |> ARDRegression                 │ 30.4747 │ 12.9025 │ 3.57303  │ 5     │
# │ 4   │ Noop |> FastICA |> ARDRegression                         │ 31.6987 │ 22.1974 │ 2.89394  │ 5     │
# │ 5   │ MinMaxScaler |> FastICA |> GradientBoostingRegressor     │ 34.3902 │ 32.2186 │ 4.21285  │ 5     │
# │ 6   │ StandardScaler |> FastICA |> ARDRegression               │ 34.7098 │ 20.0542 │ 4.42542  │ 5     │
# │ 7   │ MinMaxScaler |> Noop |> ARDRegression                    │ 36.2061 │ 20.0381 │ 14.8857  │ 5     │
# │ 8   │ Noop |> Noop |> GradientBoostingRegressor                │ 37.87   │ 23.9057 │ 18.1809  │ 5     │
# │ 9   │ RobustScaler |> Noop |> GradientBoostingRegressor        │ 39.0068 │ 24.4975 │ 9.57602  │ 5     │
# │ 10  │ RobustScaler |> Noop |> ARDRegression                    │ 39.7233 │ 24.7903 │ 9.56614  │ 5     │
# │ 11  │ StandardScaler |> FastICA |> RandomForestRegressor       │ 41.3854 │ 26.1949 │ 3.72632  │ 5     │
# │ 12  │ StandardScaler |> Noop |> ARDRegression                  │ 41.9128 │ 33.0932 │ 13.3368  │ 5     │
# │ 13  │ StandardScaler |> Noop |> RandomForestRegressor          │ 42.8092 │ 36.2155 │ 13.4947  │ 5     │
# │ 14  │ PowerTransformer |> Noop |> RandomForestRegressor        │ 43.0757 │ 32.1825 │ 16.8674  │ 5     │
# │ 15  │ StandardScaler |> Noop |> GradientBoostingRegressor      │ 43.949  │ 19.3449 │ 13.3855  │ 5     │
# │ 16  │ PowerTransformer |> Noop |> RFfromR                      │ 45.5408 │ 38.2664 │ 3.36574  │ 5     │
# │ 17  │ Noop |> FastICA |> GradientBoostingRegressor             │ 46.2453 │ 25.4718 │ 2.68021  │ 5     │
# │ 18  │ Noop |> Noop |> RandomForestRegressor                    │ 46.3513 │ 29.1347 │ 18.2148  │ 5     │
# │ 19  │ MinMaxScaler |> Noop |> rf                               │ 46.4236 │ 53.7487 │ 21.837   │ 5     │
# │ 20  │ MinMaxScaler |> Noop |> RandomForestRegressor            │ 46.9414 │ 28.7405 │ 12.0126  │ 5     │
# │ 21  │ MinMaxScaler |> FastICA |> RFfromR                       │ 47.0652 │ 35.1447 │ 6.3356   │ 5     │
# │ 22  │ StandardScaler |> Noop |> RFfromR                        │ 48.1371 │ 44.3239 │ 13.6275  │ 5     │
# │ 23  │ Noop |> FastICA |> RandomForestRegressor                 │ 48.2044 │ 34.7612 │ 2.36245  │ 5     │
# │ 24  │ Noop |> Noop |> rf                                       │ 48.3472 │ 49.3879 │ 22.8695  │ 5     │
# │ 25  │ RobustScaler |> Noop |> RandomForestRegressor            │ 49.451  │ 26.0726 │ 7.73273  │ 5     │
# │ 26  │ MinMaxScaler |> Noop |> GradientBoostingRegressor        │ 50.1687 │ 26.895  │ 11.8973  │ 5     │
# │ 27  │ Noop |> FastICA |> RFfromR                               │ 50.8467 │ 30.0068 │ 7.19646  │ 5     │
# │ 28  │ RobustScaler |> Noop |> rf                               │ 50.9593 │ 57.0304 │ 27.7194  │ 5     │
# │ 29  │ StandardScaler |> FastICA |> GradientBoostingRegressor   │ 51.2869 │ 36.7476 │ 4.05044  │ 5     │
# │ 30  │ MinMaxScaler |> FastICA |> RandomForestRegressor         │ 52.2943 │ 38.6862 │ 3.89671  │ 5     │
# │ 31  │ StandardScaler |> FastICA |> rf                          │ 52.6649 │ 32.7071 │ 6.17405  │ 5     │
# │ 32  │ RobustScaler |> FastICA |> RFfromR                       │ 52.9909 │ 33.1875 │ 4.38862  │ 5     │
# │ 33  │ RobustScaler |> FastICA |> RandomForestRegressor         │ 53.281  │ 28.744  │ 9.6074   │ 5     │
# │ 34  │ Noop |> Noop |> RFfromR                                  │ 53.8064 │ 29.3424 │ 15.1266  │ 5     │
# │ 35  │ RobustScaler |> FastICA |> GradientBoostingRegressor     │ 54.4104 │ 47.3749 │ 2.96575  │ 5     │
# │ 36  │ StandardScaler |> Noop |> rf                             │ 54.9939 │ 43.1598 │ 24.3059  │ 5     │
# │ 37  │ RobustScaler |> FastICA |> rf                            │ 55.2806 │ 41.4713 │ 4.23631  │ 5     │
# │ 38  │ MinMaxScaler |> Noop |> RFfromR                          │ 55.5316 │ 47.734  │ 16.7784  │ 5     │
# │ 39  │ PowerTransformer |> Noop |> rf                           │ 56.0288 │ 34.2234 │ 3.14234  │ 5     │
# │ 40  │ PowerTransformer |> Noop |> GradientBoostingRegressor    │ 56.2185 │ 47.7778 │ 7.7461   │ 5     │
# │ 41  │ Noop |> FastICA |> rf                                    │ 57.3051 │ 34.7246 │ 6.16801  │ 5     │
# │ 42  │ RobustScaler |> Noop |> RFfromR                          │ 57.6356 │ 33.8305 │ 20.0824  │ 5     │
# │ 43  │ MinMaxScaler |> FastICA |> rf                            │ 57.7    │ 35.7298 │ 5.72079  │ 5     │
# │ 44  │ Normalizer |> Noop |> rf                                 │ 60.9518 │ 41.6746 │ 19.5181  │ 5     │
# │ 45  │ PowerTransformer |> Noop |> GaussianProcessRegressor     │ 62.2525 │ 62.741  │ 2.9785   │ 5     │
# │ 46  │ Normalizer |> Noop |> GradientBoostingRegressor          │ 63.0002 │ 59.4452 │ 14.8502  │ 5     │
# │ 47  │ StandardScaler |> FastICA |> RFfromR                     │ 63.0458 │ 37.0292 │ 6.97737  │ 5     │
# │ 48  │ PowerTransformer |> Noop |> SVR                          │ 65.2221 │ 74.6795 │ 2.89585  │ 5     │
# │ 49  │ Normalizer |> Noop |> RFfromR                            │ 68.2946 │ 38.2797 │ 18.3746  │ 5     │
# │ 50  │ Noop |> FastICA |> SVR                                   │ 68.4281 │ 73.191  │ 2.99332  │ 5     │
# │ 51  │ Normalizer |> Noop |> RandomForestRegressor              │ 69.1381 │ 26.8939 │ 14.9091  │ 5     │
# │ 52  │ StandardScaler |> Noop |> GaussianProcessRegressor       │ 69.302  │ 65.8597 │ 12.8514  │ 5     │
# │ 53  │ PowerTransformer |> FastICA |> GradientBoostingRegressor │ 69.3507 │ 37.7777 │ 9.96903  │ 5     │
# │ 54  │ MinMaxScaler |> Noop |> SVR                              │ 69.6916 │ 71.6135 │ 12.841   │ 5     │
# │ 55  │ Noop |> Noop |> SVR                                      │ 70.817  │ 69.377  │ 18.1357  │ 5     │
# │ 56  │ PowerTransformer |> FastICA |> ARDRegression             │ 72.202  │ 44.7816 │ 9.9919   │ 5     │
# │ 57  │ PowerTransformer |> Noop |> ARDRegression                │ 72.2164 │ 45.5104 │ 1.42152  │ 5     │
# │ 58  │ PowerTransformer |> FastICA |> rf                        │ 74.6638 │ 46.2378 │ 26.0298  │ 5     │
# │ 59  │ Normalizer |> FastICA |> SVR                             │ 77.0109 │ 60.423  │ 6.17423  │ 5     │
# │ 60  │ RobustScaler |> FastICA |> SVR                           │ 77.575  │ 60.9817 │ 2.05349  │ 5     │
# │ 61  │ RobustScaler |> Noop |> SVR                              │ 77.7754 │ 57.9656 │ 9.39514  │ 5     │
# │ 62  │ StandardScaler |> FastICA |> SVR                         │ 77.854  │ 60.2947 │ 6.34102  │ 5     │
# │ 63  │ StandardScaler |> Noop |> SVR                            │ 78.6636 │ 58.7465 │ 14.363   │ 5     │
# │ 64  │ PowerTransformer |> FastICA |> RandomForestRegressor     │ 79.3726 │ 20.5613 │ 4.73501  │ 5     │
# │ 65  │ Normalizer |> Noop |> ARDRegression                      │ 79.6495 │ 52.4604 │ 16.5974  │ 5     │
# │ 66  │ PowerTransformer |> FastICA |> RFfromR                   │ 80.0286 │ 36.9047 │ 12.0697  │ 5     │
# │ 67  │ MinMaxScaler |> FastICA |> SVR                           │ 80.4155 │ 56.1453 │ 6.09913  │ 5     │
# │ 68  │ Normalizer |> FastICA |> RFfromR                         │ 81.4563 │ 52.268  │ 6.99921  │ 5     │
# │ 69  │ Normalizer |> FastICA |> rf                              │ 82.0662 │ 40.385  │ 10.8241  │ 5     │
# │ 70  │ Normalizer |> FastICA |> RandomForestRegressor           │ 82.6973 │ 40.4979 │ 3.24502  │ 5     │
# │ 71  │ Normalizer |> Noop |> SVR                                │ 84.0123 │ 50.3566 │ 17.6925  │ 5     │
# │ 72  │ Noop |> Noop |> GaussianProcessRegressor                 │ 84.0371 │ 51.1551 │ 18.1461  │ 5     │
# │ 73  │ PowerTransformer |> FastICA |> SVR                       │ 86.0314 │ 42.3714 │ 11.3182  │ 5     │
# │ 74  │ RobustScaler |> Noop |> GaussianProcessRegressor         │ 88.1275 │ 39.7135 │ 9.41522  │ 5     │
# │ 75  │ PowerTransformer |> FastICA |> GaussianProcessRegressor  │ 103.621 │ 50.3157 │ 11.4763  │ 5     │
# │ 76  │ MinMaxScaler |> Noop |> GaussianProcessRegressor         │ 104.324 │ 58.8075 │ 16.1172  │ 5     │
# │ 77  │ Normalizer |> FastICA |> GradientBoostingRegressor       │ 108.982 │ 43.6193 │ 3.4089   │ 5     │
# │ 78  │ Noop |> FastICA |> GaussianProcessRegressor              │ 133.222 │ 86.1336 │ 3.08936  │ 5     │
# │ 79  │ MinMaxScaler |> FastICA |> GaussianProcessRegressor      │ 210.102 │ 154.741 │ 5.53705  │ 5     │
# │ 80  │ StandardScaler |> FastICA |> GaussianProcessRegressor    │ 424.024 │ 503.962 │ 6.00912  │ 5     │
# │ 81  │ Normalizer |> FastICA |> ARDRegression                   │ 473.043 │ 836.782 │ 4.54388  │ 5     │
# │ 82  │ RobustScaler |> FastICA |> GaussianProcessRegressor      │ 677.655 │ 591.717 │ 2.25034  │ 5     │
# │ 83  │ Normalizer |> Noop |> GaussianProcessRegressor           │ 38204.1 │ 84954.1 │ 0.842198 │ 5     │
# │ 84  │ Normalizer |> FastICA |> GaussianProcessRegressor        │ 70552.6 │ 40393.5 │ 6.11279  │ 5     │
