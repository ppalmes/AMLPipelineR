# %%
using RCall
using DataFrames, DataFramesMeta
using CSV
using DataVoyager
using AMLPipelineBase
using AutoMLPipeline
using Statistics

using Distributed
nprocs() == 1 && addprocs(;exeflags="--project")
@everywhere begin
    using AutoMLPipeline
    using DataFrames
    using Statistics
end

ENV["LINES"] = 10
ENV["COLUMNS"]=10000;
# Out:
# ┌ Info: Precompiling AutoMLPipeline [08437348-eef5-4817-bc1b-d4e9459680d6]
# └ @ Base loading.jl:1278

# %% [markdown]
# ### Load Covid Data
#
# source: https://covid.ourworldindata.org/data/owid-covid-data.csv

# %%
function getdata()
   df = CSV.read("../data/owid-covid-data.csv",DataFrame);
   @rput df
   R"""
      library(tidyverse)
      library(mice)

      sdf = df %>% group_by(location) %>% 
      summarise(
        mnewcases = mean(new_cases,na.rm=T),
        mnewdeaths = mean(new_deaths,na.rm=T),
        mpopulation = mean(population,na.rm=T),
        mcardio = mean(cardiovasc_death_rate,na.rm=T),
        mdiab = mean(diabetes_prevalence,na.rm=T),
        mhandwash = mean(handwashing_facilities,na.rm=T),
        mhbed = mean(hospital_beds_per_thousand,na.rm=T),
        mpatient = mean(hosp_patients,na.rm=T),
        madmission = mean(weekly_hosp_admissions,na.rm=T),
        mhdi = mean(human_development_index,na.rm=T),
        mle = mean(life_expectancy,na.rm=T)
      ) 
      imputed=mice(sdf,meth='sample',printFlag=F)
      complete(imputed)
   """ |> rcopy
end;

# %%
dfimp = getdata()
X = dfimp[:,Not([:location,:mnewdeaths])]
Y = dfimp.mnewdeaths;
# Out:
# ┌ Warning: RCall.jl: ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
# │ ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# │ ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# │ ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# │ ✔ readr   1.4.0     ✔ forcats 0.5.0
# │ ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# │ ✖ dplyr::filter() masks stats::filter()
# │ ✖ dplyr::lag()    masks stats::lag()
# └ @ RCall /Users/ppalmes/.julia/packages/RCall/eRsxl/src/io.jl:160
# ┌ Warning: RCall.jl:
# │ Attaching package: ‘mice’
# │
# │ The following object is masked from ‘package:stats’:
# │
# │     filter
# │
# │ The following objects are masked from ‘package:base’:
# │
# │     cbind, rbind
# │
# └ @ RCall /Users/ppalmes/.julia/packages/RCall/eRsxl/src/io.jl:160
# ┌ Warning: RCall.jl: `summarise()` ungrouping output (override with `.groups` argument)
# └ @ RCall /Users/ppalmes/.julia/packages/RCall/eRsxl/src/io.jl:160
# ┌ Warning: RCall.jl: Warning: Number of logged events: 1
# └ @ RCall /Users/ppalmes/.julia/packages/RCall/eRsxl/src/io.jl:160

# %% [markdown]
# ### Baseline performance using Random Forest

# %%
R"""
library(caret)

fitControl <- trainControl(method = "repeatedcv",number = 5)
rfcaret <- train($X,$Y, method = "rf",trControl = fitControl)
rfcaret
"""
# Out:
# RObject{VecSxp}
# Random Forest
#
# 190 samples
#  10 predictor
#
# No pre-processing
# Resampling: Cross-Validated (5 fold, repeated 1 times)
# Summary of sample sizes: 151, 152, 152, 152, 153
# Resampling results across tuning parameters:
#
#   mtry  RMSE      Rsquared   MAE
#    2    54.65968  0.6606754  22.15499
#    6    45.43660  0.7791667  15.80200
#   10    44.47021  0.8219964  14.13773
#
# RMSE was used to select the optimal model using the smallest value.
# The final value used for the model was mtry = 10.

# %% [markdown]
# #### NOTE: Best RMSE is around 44

# %% [markdown]
# ### Use AutoML to find better RMSE by searching optimal pipelines

# %%
using AutoMLPipeline

#### Decomposition
pca = SKPreprocessor("PCA")
fa  = SKPreprocessor("FactorAnalysis")
ica = SKPreprocessor("FastICA")

#### Scaler 
rb   = SKPreprocessor("RobustScaler")
pt   = SKPreprocessor("PowerTransformer")
norm = SKPreprocessor("Normalizer")
mx   = SKPreprocessor("MinMaxScaler")
mstd    = SKPreprocessor("StandardScaler")

#### categorical preprocessing
ohe = OneHotEncoder()
noop = Identity(Dict(:name=>"Noop"))

#### Column selector
catf = CatFeatureSelector()
numf = NumFeatureSelector()

#### Learners
sk_rf       = SKLearner("RandomForestRegressor")
sk_gb       = SKLearner("GradientBoostingRegressor")
sk_svr      = SKLearner("SVR")
sk_gp       = SKLearner("GaussianProcessRegressor")
sk_ard      = SKLearner("ARDRegression")
jl_rf       = RandomForest()
jl_vote     = VoteEnsemble()
jl_stack    = StackEnsemble()
jl_best     = BestLearner();

# %%
plsvc = @pipeline  numf |> rb |> sk_svr
pred = fit_transform!(plsvc,X,Y)
# Out:
# 190-element Array{Float64,1}:
#  1.8818731662116281
#  1.3110213771957344
#  3.02758398489245
#  ⋮
#  0.8148068720569519
#  0.8149204723981107

# %%
@everywhere rmse(x,y) = sqrt(mean((x .- y).^2))

plsvc = @pipeline ((numf |> rb |> ica )) |> sk_rf
crossvalidate(plsvc,X,Y,rmse)
# Out:
# fold: 1, 23.75377291811001
# fold: 2, 118.3160119227099
# fold: 3, 31.333725620472336
# fold: 4, 25.83782646779016
# fold: 5, 89.29041825244632
# fold: 6, 7.989249499667266
# fold: 7, 73.58475299973867
# fold: 8, 57.94725987307732
# fold: 9, 13.984975191955701
# fold: 10, 35.82085383553789
# errors: 0
# (mean = 47.78588465815056, std = 36.002051049719974, folds = 10, errors = 0)

# %% [markdown]
# ### Parallel algo to search optimal combinations of preprocessing elements and learner

# %%
function prpsearch(X,Y)
    learners = [sk_rf,sk_gb,sk_svr,sk_ard,sk_gp,jl_rf];
    scalers = [rb,pt,norm,mx,mstd,noop];
    extractors = [ica,noop];
    dftable = @sync @distributed (vcat) for lr in learners
    @distributed (vcat) for sc in scalers
     @distributed (vcat) for xt  in extractors
          pipe  = @pipeline (numf |> sc |> xt)  |> lr
          scn   = sc.name[1:end - 4]; xtn = xt.name[1:end - 4]; lrn = lr.name[1:end - 4]
          pname = "$scn |> $xtn |> $lrn"
          ptime = @elapsed begin
             mean, sd, kfold, _ = crossvalidate(pipe, X, Y, rmse, 5,true)
          end
          DataFrame(pipeline=pname, mean=mean, sd=sd, time=ptime, folds=kfold)
        end
     end
    end
    sort!(dftable, :mean, rev=false);
    dftable
end
# Out:
# prpsearch (generic function with 1 method)

# %%
ENV["LINES"]=1000

runtime = @elapsed begin
    dfres = prpsearch(X,Y)
end;
serialtime = dfres.time |> sum;

(serialtime = "$(round(serialtime / 60.0)) minutes", 
    paralleltime = "$(round(runtime)) seconds")
# Out:
#       From worker 2:	fold: 1, 142.25146403445717
#       From worker 5:	fold: 1, 32.50584127021188
#       From worker 6:	fold: 1, 1213.9015660141276
#       From worker 4:	fold: 1, 75.2578182491557
#       From worker 6:	fold: 2, 1529.8005363946424
#       From worker 5:	fold: 2, 9.587368395916121
#       From worker 5:	fold: 3, 79.44117771857492
#       From worker 2:	fold: 2, 47.38469350623029
#       From worker 3:	fold: 1, 8.254081313172394
#       From worker 4:	fold: 2, 31.816555976518863
#       From worker 6:	fold: 3, 813.6011519195193
#       From worker 6:	fold: 4, 61.49262552957701
#       From worker 6:	fold: 5, 86.75153121570264
#       From worker 6:	errors: 0
#       From worker 3:	fold: 2, 88.41329767031164
#       From worker 5:	fold: 4, 47.61135746983782
#       From worker 3:	fold: 3, 53.08320397635213
#       From worker 6:	fold: 1, 53.179985236752195
#       From worker 3:	fold: 4, 76.40442430171119
#       From worker 6:	fold: 2, 11.707490479899207
#       From worker 6:	fold: 3, 32.91475619435752
#       From worker 4:	fold: 3, 74.36745189926603
#       From worker 6:	fold: 4, 24.460487769798686
#       From worker 4:	fold: 4, 177.32666663750405
#       From worker 5:	fold: 5, 33.922838704644846
#       From worker 5:	errors: 0
#       From worker 7:	fold: 1, 27.929605932241138
#       From worker 3:	fold: 5, 14.833251587536147
#       From worker 4:	fold: 5, 34.61429680221867
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 66.42291852829804
#       From worker 5:	fold: 1, 849.2884712047651
#       From worker 5:	fold: 2, 1028.0232623694346
#       From worker 5:	fold: 3, 77.95511430356173
#       From worker 6:	fold: 5, 37.74310860737739
#       From worker 4:	fold: 2, 79.5477451223297
#       From worker 3:	errors: 0
#       From worker 5:	fold: 4, 205.1461715892975
#       From worker 5:	fold: 5, 489.2779373271381
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 162.52496782613127
#       From worker 5:	fold: 2, 47.69791696931919
#       From worker 7:	fold: 1, 68.63539090840119
#       From worker 5:	fold: 3, 81.47204321254729
#       From worker 7:	fold: 2, 72.10686294387718
#       From worker 3:	fold: 1, 4567.550075014014
#       From worker 3:	fold: 2, 90.53566865561946
#       From worker 7:	fold: 3, 29.920887785916694
#       From worker 7:	fold: 4, 104.45122794287116
#       From worker 3:	fold: 3, 89.76600493110837
#       From worker 5:	fold: 4, 38.23742331100454
#       From worker 3:	fold: 4, 40.55677209146479
#       From worker 5:	fold: 5, 89.74393593981955
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 45.670002918959455
#       From worker 3:	fold: 5, 171.03046910369665
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 95.0617278108919
#       From worker 3:	fold: 2, 151.78383145266673
#       From worker 3:	fold: 3, 43.293295998959074
#       From worker 4:	fold: 3, 103.37607821748026
#       From worker 7:	fold: 5, 152.160589721495
#       From worker 7:	errors: 0
#       From worker 3:	fold: 4, 95.74636082554227
#       From worker 3:	fold: 5, 33.05025057730897
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 133881.7069414101
#       From worker 7:	fold: 1, 33.4764695148278
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 72.71560959328765
#       From worker 7:	fold: 2, 47.74194607506605
#       From worker 3:	fold: 2, 22423.263711862975
#       From worker 3:	fold: 3, 141153.66569281428
#       From worker 6:	fold: 2, 81.943123597467
#       From worker 7:	fold: 3, 19.204026547215083
#       From worker 5:	fold: 2, 21.81182879871033
#       From worker 3:	fold: 4, 2079.6038797418914
#       From worker 6:	fold: 3, 151.70113349194094
#       From worker 7:	fold: 4, 96.84459717861778
#       From worker 3:	fold: 5, 11555.772002993834
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 65.82729024658613
#       From worker 4:	fold: 4, 148.1984631302546
#       From worker 3:	fold: 1, 56.72361381495097
#       From worker 6:	fold: 4, 98.33338755972278
#       From worker 7:	fold: 5, 11.806596519552704
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 1061.0214230267054
#       From worker 3:	fold: 2, 50.43865806678229
#       From worker 6:	fold: 5, 11.372293018094396
#       From worker 7:	fold: 2, 409.3720577664875
#       From worker 3:	fold: 3, 39.527113986791
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 80.27872322811439
#       From worker 3:	fold: 4, 92.95942041767644
#       From worker 7:	fold: 3, 349.67142933173466
#       From worker 3:	fold: 5, 133.29603677048803
#       From worker 3:	errors: 0
#       From worker 5:	fold: 3, 91.84219150201385
#       From worker 6:	fold: 2, 92.79913641969463
#       From worker 7:	fold: 4, 53.96057714859128
#       From worker 4:	fold: 5, 33.103367795223114
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 57.31244966623665
#       From worker 7:	fold: 5, 79.04098843702927
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 61.32758967191455
#       From worker 3:	fold: 1, 9.365017491496722
#       From worker 4:	fold: 2, 11.280956292136873
#       From worker 4:	fold: 3, 28.325365834173063
#       From worker 7:	fold: 2, 28.218597538175846
#       From worker 6:	fold: 3, 51.945559947285425
#       From worker 3:	fold: 2, 21.73805212380329
#       From worker 4:	fold: 4, 32.792467423583716
#       From worker 4:	fold: 5, 33.34374876894758
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 525.1358641620085
#       From worker 3:	fold: 3, 102.35271517587648
#       From worker 7:	fold: 3, 41.371720827265065
#       From worker 6:	fold: 4, 7.1289990339344715
#       From worker 4:	fold: 2, 119.06026637500538
#       From worker 5:	fold: 4, 17.038641008833704
#       From worker 4:	fold: 3, 86.49677314223682
#       From worker 7:	fold: 4, 76.41150185602163
#       From worker 3:	fold: 4, 36.410872394645985
#       From worker 6:	fold: 5, 29.66160817687766
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 51.0253450747121
#       From worker 4:	fold: 4, 1194.7200413181638
#       From worker 6:	fold: 1, 14.14601295210867
#       From worker 4:	fold: 5, 1227.390411604342
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 173.16153998333635
#       From worker 3:	fold: 5, 44.68326914537402
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 45.95460586371208
#       From worker 7:	fold: 5, 48.25561645437751
#       From worker 7:	errors: 0
#       From worker 7:	fold: 2, 61.607488022214405
#       From worker 3:	fold: 2, 30.614727579142173
#       From worker 7:	fold: 1, 132.2092230783917
#       From worker 4:	fold: 2, 151.88373902340726
#       From worker 3:	fold: 2, 59.63071215370779
#       From worker 3:	fold: 3, 84.72714500007145
#       From worker 5:	fold: 5, 35.627122501456405
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 123.02321858200224
#       From worker 3:	fold: 3, 29.597698910636467
#       From worker 2:	fold: 3, 51.18810090812251
#       From worker 4:	fold: 3, 25.619266065748775
#       From worker 3:	fold: 4, 147.43720605466908
#       From worker 3:	fold: 4, 130.24811751289437
#       From worker 5:	fold: 2, 103.79955996411903
#       From worker 3:	fold: 5, 34.025023250470646
#       From worker 3:	errors: 0
#       From worker 3:	fold: 5, 21.964445152351356
#       From worker 3:	errors: 0
#       From worker 4:	fold: 4, 84.22179648916389
#       From worker 5:	fold: 3, 33.06001741373522
#       From worker 6:	fold: 2, 34.98080741418842
#       From worker 4:	fold: 5, 77.67601042071749
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 83.66976591287244
#       From worker 4:	fold: 2, 23.967075691208628
#       From worker 4:	fold: 3, 126.78944985174721
#       From worker 4:	fold: 4, 50.19967393705407
#       From worker 5:	fold: 4, 10.186988894267781
#       From worker 7:	fold: 2, 31.211495439280043
#       From worker 4:	fold: 5, 35.062229741944506
#       From worker 4:	errors: 0
#       From worker 5:	fold: 5, 17.420894718071594
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 47.38488879322898
#       From worker 5:	fold: 2, 28.634926417235505
#       From worker 6:	fold: 3, 97.15314673016695
#       From worker 5:	fold: 3, 120.25210637443527
#       From worker 5:	fold: 4, 42.63040267264933
#       From worker 5:	fold: 5, 50.7322918397516
#       From worker 5:	errors: 0
#       From worker 7:	fold: 3, 21.281855017488
#       From worker 3:	fold: 1, 78.08826307865891
#       From worker 3:	fold: 2, 30.071325157521567
#       From worker 6:	fold: 4, 40.73323731669982
#       From worker 3:	fold: 3, 88.75550477014359
#       From worker 3:	fold: 4, 148.41296073711152
#       From worker 7:	fold: 4, 30.833130737645774
#       From worker 3:	fold: 5, 81.67163346464066
#       From worker 3:	errors: 0
#       From worker 6:	fold: 5, 67.05832382114728
#       From worker 6:	errors: 0
#       From worker 6:	fold: 2, 25.565461107591762
#       From worker 6:	fold: 3, 154.6884447046042
#       From worker 6:	fold: 4, 38.97042291762992
#       From worker 6:	fold: 5, 52.51039868017175
#       From worker 6:	errors: 0
#       From worker 7:	fold: 5, 52.12694615902805
#       From worker 7:	errors: 0
#       From worker 7:	fold: 3, 10.095278092421879
#       From worker 7:	fold: 4, 130.16387696136061
#       From worker 7:	fold: 5, 20.122448774585664
#       From worker 7:	errors: 0
#       From worker 2:	fold: 4, 42.15702056274721
#       From worker 2:	fold: 5, 13.5919949850899
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 45.440576279415595
#       From worker 3:	fold: 1, 77.0949388667192
#       From worker 3:	fold: 2, 171.13597238632968
#       From worker 2:	fold: 1, 42.00390407730261
#       From worker 2:	fold: 2, 39.561530993074875
#       From worker 2:	fold: 3, 83.18017131658856
#       From worker 2:	fold: 4, 148.37073848378597
#       From worker 2:	fold: 5, 109.46385318008159
#       From worker 2:	errors: 0
#       From worker 3:	fold: 3, 25.54066681449915
#       From worker 3:	fold: 4, 24.239851191284256
#       From worker 3:	fold: 5, 56.2799206641175
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 58.693470676754465
#       From worker 2:	fold: 1, 42.60833592632785
#       From worker 2:	fold: 2, 38.33812585899078
#       From worker 3:	fold: 2, 61.16518350335369
#       From worker 2:	fold: 3, 94.98655365879725
#       From worker 3:	fold: 3, 95.50366916205655
#       From worker 2:	fold: 4, 7.2843290529756
#       From worker 2:	fold: 5, 42.591858608987565
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 18.94244283874799
#       From worker 2:	fold: 2, 7.617825690454646
#       From worker 2:	fold: 3, 20.076669975340312
#       From worker 2:	fold: 4, 57.72192859898731
#       From worker 2:	fold: 5, 16.93845380997504
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 41.755365641849515
#       From worker 2:	fold: 2, 75.29820460283563
#       From worker 2:	fold: 3, 165.575848251485
#       From worker 2:	fold: 4, 96.62278868059994
#       From worker 2:	fold: 5, 40.173783481518214
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 116.66799128896405
#       From worker 3:	fold: 4, 130.77475811911856
#       From worker 2:	fold: 2, 44.99353845543098
#       From worker 2:	fold: 3, 27.344631254165545
#       From worker 2:	fold: 4, 43.77550105264073
#       From worker 2:	fold: 5, 29.684677231110953
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 46.16769969790765
#       From worker 3:	fold: 5, 94.17513888302216
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 40.55072305411496
#       From worker 2:	fold: 2, 28.967856391714843
#       From worker 3:	fold: 2, 46.59822789440765
#       From worker 2:	fold: 3, 52.405490901340244
#       From worker 3:	fold: 3, 98.33547893277029
#       From worker 2:	fold: 4, 20.406234140817425
#       From worker 3:	fold: 4, 49.505750860440564
#       From worker 2:	fold: 5, 96.92049955689198
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 60.15070920183841
#       From worker 2:	fold: 2, 10.616175248530759
#       From worker 2:	fold: 3, 17.031538929749928
#       From worker 2:	fold: 4, 78.86695298605898
#       From worker 2:	fold: 5, 14.822993882908838
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 127.72272074579377
#       From worker 2:	fold: 2, 27.321148068030464
#       From worker 2:	fold: 3, 154.45549534132385
#       From worker 2:	fold: 4, 38.1997782720779
#       From worker 2:	fold: 5, 15.88479387908771
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 22.81209083910151
#       From worker 2:	fold: 2, 63.72816105328921
#       From worker 2:	fold: 3, 84.42795799670031
#       From worker 2:	fold: 4, 155.1247004649139
#       From worker 2:	fold: 5, 95.19176109592739
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 147.30397906908414
#       From worker 2:	fold: 2, 33.88663909418191
#       From worker 2:	fold: 3, 59.64631975722221
#       From worker 2:	fold: 4, 44.52116796893701
#       From worker 3:	fold: 5, 26.68656556894104
#       From worker 3:	errors: 0
#       From worker 2:	fold: 5, 120.05003516759959
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 48.277274752160906
#       From worker 2:	fold: 2, 16.506411852284575
#       From worker 2:	fold: 3, 21.981337630306445
#       From worker 2:	fold: 4, 34.74603781790514
#       From worker 2:	fold: 5, 99.27489934170546
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 35.215329069487666
#       From worker 2:	fold: 2, 154.15730492309854
#       From worker 2:	fold: 3, 17.845965998276945
#       From worker 2:	fold: 4, 73.44816177722707
#       From worker 2:	fold: 5, 112.15755048448914
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 46.04960370994209
#       From worker 2:	fold: 2, 57.814216658896505
#       From worker 2:	fold: 3, 22.88815312662981
#       From worker 2:	fold: 4, 19.669310231692148
#       From worker 2:	fold: 5, 25.401603937805195
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 49.43505520642244
#       From worker 2:	fold: 2, 43.30288704029758
#       From worker 2:	fold: 3, 46.05187461887138
#       From worker 2:	fold: 4, 112.28807162158294
#       From worker 2:	fold: 5, 129.57929703363396
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 29.475134579308673
#       From worker 2:	fold: 2, 176.95633137233528
#       From worker 2:	fold: 3, 20.474338139543253
#       From worker 2:	fold: 4, 100.60699100615389
#       From worker 2:	fold: 5, 37.850941531133316
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 71.34987117043548
#       From worker 2:	fold: 2, 67.99339624995413
#       From worker 2:	fold: 3, 71.90437872220234
#       From worker 2:	fold: 4, 82.13066298992112
#       From worker 2:	fold: 5, 133.98030911247184
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 60.74947737325392
#       From worker 2:	fold: 2, 191.759784655125
#       From worker 2:	fold: 3, 75.05419394317256
#       From worker 2:	fold: 4, 67.056650651341
#       From worker 2:	fold: 5, 69.62723173303047
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 21.76761678342733
#       From worker 2:	fold: 2, 95.58706231808695
#       From worker 2:	fold: 3, 90.57697905240711
#       From worker 2:	fold: 4, 37.11306175748225
#       From worker 2:	fold: 5, 49.883234440863205
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 65.26476819801161
#       From worker 2:	fold: 2, 29.582397999898486
#       From worker 2:	fold: 3, 51.87262146722963
#       From worker 2:	fold: 4, 57.096413942223066
#       From worker 2:	fold: 5, 74.26734399301314
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 68.04641259828529
#       From worker 2:	fold: 2, 29.280793260118056
#       From worker 2:	fold: 3, 46.47977088678623
#       From worker 2:	fold: 4, 166.9630619289092
#       From worker 2:	fold: 5, 95.53451870649687
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 44.462478377843304
#       From worker 2:	fold: 2, 35.69843260828079
#       From worker 2:	fold: 3, 11.550725189130572
#       From worker 2:	fold: 4, 67.94101107829192
#       From worker 2:	fold: 5, 52.56671422031645
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 13.973519023423291
#       From worker 2:	fold: 2, 53.970845227377474
#       From worker 2:	fold: 3, 83.96235139799091
#       From worker 2:	fold: 4, 26.341448706842836
#       From worker 2:	fold: 5, 26.990708277572846
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 5.917894073416704
#       From worker 2:	fold: 2, 84.87595770556655
#       From worker 2:	fold: 3, 50.3848035994072
#       From worker 2:	fold: 4, 37.90946288207911
#       From worker 2:	fold: 5, 19.72177634888565
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 113.11137810978994
#       From worker 2:	fold: 2, 91.64428828725055
#       From worker 2:	fold: 3, 55.29406800697017
#       From worker 2:	fold: 4, 164.5210307326601
#       From worker 2:	fold: 5, 169.74817258644512
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 29.77487837893025
#       From worker 2:	fold: 2, 53.644127105380164
#       From worker 2:	fold: 3, 128.83530742601315
#       From worker 2:	fold: 4, 16.112152068037883
#       From worker 2:	fold: 5, 17.910048511959673
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 34.98841607048003
#       From worker 2:	fold: 2, 89.26403978864603
#       From worker 2:	fold: 3, 163.13364123568869
#       From worker 2:	fold: 4, 43.80202613906051
#       From worker 2:	fold: 5, 72.23983663753434
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 2161.702498402926
#       From worker 2:	fold: 2, 30051.754401948878
#       From worker 2:	fold: 3, 68.0561543861318
#       From worker 2:	fold: 4, 189.95527942119665
#       From worker 2:	fold: 5, 168.60374577907402
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 165.0176058476291
#       From worker 2:	fold: 2, 33.826466287046884
#       From worker 2:	fold: 3, 15.929987158333418
#       From worker 2:	fold: 4, 97.02649913597904
#       From worker 2:	fold: 5, 86.01019021004014
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 48.31160471228245
#       From worker 2:	fold: 1, 33.41248414996557
#       From worker 2:	fold: 1, 54.28402265433853
#       From worker 2:	fold: 1, 47.420383568959274
#       From worker 2:	fold: 1, 47.97979168744696
#       From worker 2:	fold: 2, 32.89754181944174
#       From worker 2:	fold: 1, 18.833998902718534
#       From worker 2:	fold: 2, 33.50286195900718
#       From worker 2:	fold: 3, 98.3021059523259
#       From worker 2:	fold: 4, 11.875197236812788
#       From worker 2:	fold: 5, 34.3005837473544
#       From worker 2:	errors: 0
#       From worker 2:	fold: 2, 19.409642509285472
#       From worker 2:	fold: 2, 60.485558161906916
#       From worker 2:	fold: 2, 25.948926626941454
#       From worker 2:	fold: 2, 67.74562745475957
#       From worker 2:	fold: 2, 119.93351805905817
#       From worker 2:	fold: 3, 146.45251243152126
#       From worker 2:	fold: 3, 51.78766906320766
#       From worker 2:	fold: 3, 27.718590711820777
#       From worker 2:	fold: 3, 49.318774781605775
#       From worker 2:	fold: 3, 51.08926694637096
#       From worker 2:	fold: 3, 51.483483509617656
#       From worker 2:	fold: 4, 53.025780725917656
#       From worker 2:	fold: 4, 11.883179695816706
#       From worker 2:	fold: 4, 57.668870406867214
#       From worker 2:	fold: 5, 116.49942234024408
#       From worker 2:	errors: 0
#       From worker 2:	fold: 4, 117.86919863879218
#       From worker 2:	fold: 4, 125.53566971916621
#       From worker 2:	fold: 4, 14.858649060779756
#       From worker 2:	fold: 5, 44.203875259042306
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 111.55196062366564
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 58.03445533051032
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 38.52045988355886
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 44.66952062912763
#       From worker 2:	errors: 0
# (serialtime = "9.0 minutes", paralleltime = "39.0 seconds")

# %%
dfres
# Out:
# 72×5 DataFrame
# │ Row │ pipeline                                                 │ mean    │ sd      │ time     │ folds │
# │     │ String                                                   │ Float64 │ Float64 │ Float64  │ Int64 │
# ├─────┼──────────────────────────────────────────────────────────┼─────────┼─────────┼──────────┼───────┤
# │ 1   │ Noop |> Noop |> ARDRegression                            │ 24.2595 │ 19.3394 │ 1.8202   │ 5     │
# │ 2   │ StandardScaler |> FastICA |> ARDRegression               │ 32.0012 │ 15.4195 │ 4.75838  │ 5     │
# │ 3   │ MinMaxScaler |> FastICA |> ARDRegression                 │ 32.611  │ 16.4626 │ 5.84648  │ 5     │
# │ 4   │ StandardScaler |> Noop |> ARDRegression                  │ 34.3646 │ 16.6915 │ 10.7387  │ 5     │
# │ 5   │ RobustScaler |> Noop |> ARDRegression                    │ 36.2977 │ 31.1167 │ 9.52637  │ 5     │
# │ 6   │ PowerTransformer |> Noop |> RandomForestRegressor        │ 39.3629 │ 34.3177 │ 8.4027   │ 5     │
# │ 7   │ MinMaxScaler |> Noop |> GradientBoostingRegressor        │ 39.762  │ 30.408  │ 11.7218  │ 5     │
# │ 8   │ RobustScaler |> FastICA |> ARDRegression                 │ 40.6137 │ 25.6402 │ 8.8369   │ 5     │
# │ 9   │ MinMaxScaler |> Noop |> RandomForestRegressor            │ 41.0478 │ 28.0872 │ 12.0898  │ 5     │
# │ 10  │ Noop |> FastICA |> ARDRegression                         │ 41.8147 │ 33.7071 │ 2.05513  │ 5     │
# │ 11  │ MinMaxScaler |> FastICA |> RandomForestRegressor         │ 42.398  │ 29.8671 │ 6.04777  │ 5     │
# │ 12  │ StandardScaler |> Noop |> GradientBoostingRegressor      │ 42.4439 │ 20.9555 │ 11.548   │ 5     │
# │ 13  │ PowerTransformer |> Noop |> GradientBoostingRegressor    │ 42.91   │ 35.8899 │ 1.91688  │ 5     │
# │ 14  │ MinMaxScaler |> Noop |> ARDRegression                    │ 44.1572 │ 33.1656 │ 10.6623  │ 5     │
# │ 15  │ Noop |> Noop |> RandomForestRegressor                    │ 45.1618 │ 31.5313 │ 2.0553   │ 5     │
# │ 16  │ RobustScaler |> FastICA |> GradientBoostingRegressor     │ 48.1977 │ 35.8659 │ 12.2591  │ 5     │
# │ 17  │ RobustScaler |> Noop |> rf                               │ 48.5888 │ 39.2855 │ 11.9794  │ 5     │
# │ 18  │ StandardScaler |> Noop |> RandomForestRegressor          │ 48.9736 │ 29.7274 │ 2.78759  │ 5     │
# │ 19  │ RobustScaler |> Noop |> GradientBoostingRegressor        │ 49.2553 │ 46.938  │ 11.8651  │ 5     │
# │ 20  │ RobustScaler |> FastICA |> rf                            │ 49.9837 │ 48.8189 │ 15.4971  │ 5     │
# │ 21  │ StandardScaler |> FastICA |> RandomForestRegressor       │ 50.8143 │ 32.047  │ 3.05035  │ 5     │
# │ 22  │ Noop |> FastICA |> GradientBoostingRegressor             │ 51.117  │ 18.5173 │ 2.60904  │ 5     │
# │ 23  │ RobustScaler |> Noop |> RandomForestRegressor            │ 52.3353 │ 27.1738 │ 2.36758  │ 5     │
# │ 24  │ StandardScaler |> FastICA |> GradientBoostingRegressor   │ 52.3628 │ 35.2704 │ 5.45128  │ 5     │
# │ 25  │ Noop |> Noop |> GradientBoostingRegressor                │ 52.4933 │ 36.7537 │ 2.11423  │ 5     │
# │ 26  │ Noop |> FastICA |> RandomForestRegressor                 │ 53.5325 │ 45.4026 │ 3.44257  │ 5     │
# │ 27  │ Normalizer |> Noop |> GradientBoostingRegressor          │ 55.6167 │ 16.8443 │ 11.4541  │ 5     │
# │ 28  │ StandardScaler |> Noop |> rf                             │ 55.785  │ 38.7072 │ 9.63512  │ 5     │
# │ 29  │ PowerTransformer |> Noop |> rf                           │ 57.4791 │ 43.2187 │ 1.73692  │ 5     │
# │ 30  │ MinMaxScaler |> FastICA |> GradientBoostingRegressor     │ 57.4981 │ 52.1515 │ 6.13024  │ 5     │
# │ 31  │ StandardScaler |> FastICA |> rf                          │ 57.9269 │ 35.8446 │ 5.48893  │ 5     │
# │ 32  │ Normalizer |> Noop |> RandomForestRegressor              │ 58.9856 │ 32.7266 │ 11.78    │ 5     │
# │ 33  │ MinMaxScaler |> Noop |> rf                               │ 59.157  │ 35.1543 │ 10.3631  │ 5     │
# │ 34  │ RobustScaler |> FastICA |> RandomForestRegressor         │ 59.3147 │ 48.6617 │ 16.0828  │ 5     │
# │ 35  │ Noop |> Noop |> rf                                       │ 61.0911 │ 34.1064 │ 10.0352  │ 5     │
# │ 36  │ MinMaxScaler |> FastICA |> rf                            │ 63.9376 │ 41.7129 │ 5.32223  │ 5     │
# │ 37  │ PowerTransformer |> FastICA |> rf                        │ 64.4041 │ 46.4267 │ 12.403   │ 5     │
# │ 38  │ Noop |> FastICA |> rf                                    │ 64.552  │ 51.5435 │ 5.79436  │ 5     │
# │ 39  │ Normalizer |> Noop |> rf                                 │ 66.0623 │ 34.8933 │ 10.0299  │ 5     │
# │ 40  │ PowerTransformer |> Noop |> GaussianProcessRegressor     │ 70.8583 │ 60.2785 │ 0.663972 │ 5     │
# │ 41  │ Normalizer |> FastICA |> rf                              │ 72.5263 │ 47.5508 │ 5.1743   │ 5     │
# │ 42  │ StandardScaler |> Noop |> GaussianProcessRegressor       │ 72.7168 │ 63.6179 │ 9.45968  │ 5     │
# │ 43  │ PowerTransformer |> FastICA |> SVR                       │ 73.0727 │ 66.0641 │ 11.1798  │ 5     │
# │ 44  │ PowerTransformer |> Noop |> ARDRegression                │ 74.589  │ 38.4569 │ 1.29262  │ 5     │
# │ 45  │ PowerTransformer |> FastICA |> ARDRegression             │ 76.1314 │ 41.41   │ 11.1747  │ 5     │
# │ 46  │ RobustScaler |> Noop |> GaussianProcessRegressor         │ 78.5649 │ 55.7558 │ 10.6872  │ 5     │
# │ 47  │ RobustScaler |> FastICA |> SVR                           │ 78.6766 │ 58.9479 │ 11.856   │ 5     │
# │ 48  │ Normalizer |> Noop |> SVR                                │ 79.5621 │ 58.7155 │ 11.7505  │ 5     │
# │ 49  │ Normalizer |> Noop |> ARDRegression                      │ 80.6856 │ 50.9687 │ 11.7491  │ 5     │
# │ 50  │ RobustScaler |> Noop |> SVR                              │ 81.0816 │ 49.8183 │ 10.5924  │ 5     │
# │ 51  │ StandardScaler |> Noop |> SVR                            │ 81.2609 │ 53.9325 │ 11.3532  │ 5     │
# │ 52  │ StandardScaler |> FastICA |> SVR                         │ 83.2131 │ 50.4781 │ 5.05278  │ 5     │
# │ 53  │ Normalizer |> FastICA |> SVR                             │ 83.7871 │ 47.7171 │ 4.34917  │ 5     │
# │ 54  │ Noop |> Noop |> GaussianProcessRegressor                 │ 83.8852 │ 51.4659 │ 1.8351   │ 5     │
# │ 55  │ MinMaxScaler |> FastICA |> SVR                           │ 83.9353 │ 49.0347 │ 4.46605  │ 5     │
# │ 56  │ MinMaxScaler |> Noop |> SVR                              │ 84.2569 │ 48.3186 │ 9.46995  │ 5     │
# │ 57  │ Noop |> Noop |> SVR                                      │ 84.516  │ 46.1784 │ 1.16233  │ 5     │
# │ 58  │ PowerTransformer |> Noop |> SVR                          │ 85.3999 │ 42.1619 │ 0.208327 │ 5     │
# │ 59  │ Noop |> FastICA |> SVR                                   │ 85.455  │ 45.7045 │ 2.56712  │ 5     │
# │ 60  │ PowerTransformer |> FastICA |> GaussianProcessRegressor  │ 85.4717 │ 27.6281 │ 11.2927  │ 5     │
# │ 61  │ Normalizer |> FastICA |> RandomForestRegressor           │ 86.1297 │ 42.9926 │ 5.14237  │ 5     │
# │ 62  │ PowerTransformer |> FastICA |> RandomForestRegressor     │ 88.0624 │ 29.5934 │ 1.81717  │ 5     │
# │ 63  │ MinMaxScaler |> Noop |> GaussianProcessRegressor         │ 92.8495 │ 55.5312 │ 11.1447  │ 5     │
# │ 64  │ Normalizer |> FastICA |> GradientBoostingRegressor       │ 102.512 │ 59.7762 │ 5.91015  │ 5     │
# │ 65  │ PowerTransformer |> FastICA |> GradientBoostingRegressor │ 118.864 │ 48.7055 │ 12.0839  │ 5     │
# │ 66  │ Noop |> FastICA |> GaussianProcessRegressor              │ 390.613 │ 406.782 │ 2.1704   │ 5     │
# │ 67  │ StandardScaler |> FastICA |> GaussianProcessRegressor    │ 529.938 │ 406.665 │ 4.32532  │ 5     │
# │ 68  │ MinMaxScaler |> FastICA |> GaussianProcessRegressor      │ 630.561 │ 557.502 │ 5.93743  │ 5     │
# │ 69  │ RobustScaler |> FastICA |> GaussianProcessRegressor      │ 741.109 │ 659.713 │ 8.34497  │ 5     │
# │ 70  │ Normalizer |> FastICA |> ARDRegression                   │ 991.888 │ 1999.4  │ 4.16864  │ 5     │
# │ 71  │ Normalizer |> Noop |> GaussianProcessRegressor           │ 6528.01 │ 13179.3 │ 11.7622  │ 5     │
# │ 72  │ Normalizer |> FastICA |> GaussianProcessRegressor        │ 62218.8 │ 69161.8 │ 4.57041  │ 5     │

# %% [markdown]
# ### Extend the pipeline with R ML implementations

# %%
module RMachine

using RCall
using DataFrames
using Random

using AMLPipelineBase
using AMLPipelineBase.AbsTypes
using AMLPipelineBase.Utils

import AMLPipelineBase.AbsTypes: fit!, transform!

export CRTLearner,fit!,transform!,fit_transform!
export caretrun, crossvalidate

mutable struct CRTLearner <: Learner
   name
   model
   function CRTLearner(args::Dict{Symbol,<:Any} = Dict())
      fitControl="trainControl(method = 'none')"
      default_args = Dict{Symbol,Any}(
                      :name => "R_learner",
                      :learner => "rf",
                      :fitControl => fitControl,
                      :impl_args => Dict{Symbol,Any}()
                     )
      cargs = nested_dict_merge(default_args, args)
      cargs[:name] = cargs[:name]*"_"*randstring(3)
      rl = cargs[:learner]
      new(cargs[:name],cargs)
   end
end

function fit!(crt::CRTLearner,x::DataFrame,y::Vector)
   rmodel = rcall(:train,x,y,method=crt.model[:learner],trControl = reval(crt.model[:fitControl]))
   crt.model[:rmodel] = rmodel
end

function transform!(crt::CRTLearner,x::DataFrame)
   res = rcall(:predict,crt.model[:rmodel],x)
   return rcopy(res) |> Array
end


end
# Out:
# WARNING: replacing module RMachine.
# Main.RMachine

# %%
module RTest
using Test
using DataFrames
using RDatasets

using ..RMachine

function test_r()
   rf = CRTLearner(Dict(:learner=>"rf"))
   gbm = CRTLearner(Dict(:learner=>"gbm"))
   iris=dataset("datasets","iris")
   x=iris[:,1:4]
   y=iris[:,5] |> Array{String}
   @test (fit_transform!(rf,x,y) .== y ) |> sum == 150
   @test crossvalidate(rf,x,y,"accuracy_score",3,false).mean > 0.80
end
@testset "rmachine tests" begin
   test_r()
end
end
# Out:
# Test Summary:  | Pass  Total
# rmachine tests |    2      2
# WARNING: replacing module RTest.
# Main.RTest

# %%
@everywhere using AMLPipelineR

# %%
r_rf = CRTLearner(Dict(:name=>"RF_fromR",:learner=>"rf"));

# %%
function prpsearch(X,Y)
    learners = [sk_rf,sk_gb,sk_svr,sk_ard,sk_gp,jl_rf,r_rf];
    scalers = [rb,pt,norm,mx,mstd,noop];
    extractors = [ica,noop];
    dftable = @sync @distributed (vcat) for lr in learners
    @distributed (vcat) for sc in scalers
     @distributed (vcat) for xt  in extractors
          pipe  = @pipeline (numf |> sc |> xt)  |> lr
          scn   = sc.name[1:end - 4]; xtn = xt.name[1:end - 4]; lrn = lr.name[1:end - 4]
          pname = "$scn |> $xtn |> $lrn"
          ptime = @elapsed begin
             mean, sd, kfold, _ = crossvalidate(pipe, X, Y, rmse, 5,true)
          end
          DataFrame(pipeline=pname, mean=mean, sd=sd, time=ptime, folds=kfold)
        end
     end
    end
    sort!(dftable, :mean, rev=false);
    dftable
end

runtime = @elapsed begin
    dfres = prpsearch(X,Y)
end;
serialtime = dfres.time |> sum;

(serialtime = "$(round(serialtime / 60.0)) minutes", 
    paralleltime = "$(round(runtime)) seconds")
# Out:
#       From worker 8:	fold: 1, 33.87167649949282
#       From worker 7:	fold: 1, 67.41005090137035
#       From worker 7:	fold: 1, 64.06786583131652
#       From worker 7:	fold: 2, 38.6355379532262
#       From worker 7:	fold: 3, 25.085354329926577
#       From worker 7:	fold: 4, 66.50374543466512
#       From worker 7:	fold: 5, 14.483361972665591
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 58.12911493975861
#       From worker 8:	fold: 2, 93.64898214369772
#       From worker 5:	fold: 1, 18.07299471250063
#       From worker 3:	fold: 1, 11.253499585552964
#       From worker 6:	fold: 1, 805.4605307559489
#       From worker 5:	fold: 2, 58.2529503384154
#       From worker 4:	fold: 1, 150.29340096569345
#       From worker 7:	fold: 2, 16.403777032572815
#       From worker 6:	fold: 2, 77.41815525479717
#       From worker 6:	fold: 3, 278.7220174146623
#       From worker 4:	fold: 2, 81.76013058452963
#       From worker 5:	fold: 3, 26.23263908360398
#       From worker 6:	fold: 4, 37.59812230202251
#       From worker 4:	fold: 3, 93.38267592397735
#       From worker 4:	fold: 4, 69.7370076986643
#       From worker 6:	fold: 5, 2249.3057905275787
#       From worker 6:	errors: 0
#       From worker 5:	fold: 4, 108.30861728117696
#       From worker 6:	fold: 1, 27.82461696249908
#       From worker 4:	fold: 5, 44.175125066750866
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 38.927558421104784
#       From worker 5:	fold: 5, 10.407800600693262
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 81.26911406973589
#       From worker 7:	fold: 3, 28.271360461274572
#       From worker 6:	fold: 2, 43.771116596351376
#       From worker 5:	fold: 2, 11.54031436291084
#       From worker 6:	fold: 3, 48.5583380584257
#       From worker 3:	fold: 2, 168.63348073201516
#       From worker 4:	fold: 2, 72.17855519104377
#       From worker 5:	fold: 3, 28.42706839771324
#       From worker 8:	fold: 3, 24.64149530553273
#       From worker 2:	fold: 1, 48.12368793765446
#       From worker 6:	fold: 4, 129.78930312943177
#       From worker 5:	fold: 4, 59.329906858058884
#       From worker 7:	fold: 4, 100.29518821999591
#       From worker 3:	fold: 3, 40.872851462378165
#       From worker 4:	fold: 3, 112.11938746969945
#       From worker 6:	fold: 5, 17.45007375907096
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 23.603808586401595
#       From worker 5:	fold: 5, 57.713127106474104
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 98.47004043451142
#       From worker 3:	fold: 4, 49.652671274713796
#       From worker 7:	fold: 5, 21.28499880845653
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 34.435380475270335
#       From worker 3:	fold: 5, 13.810395652019386
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 69.6638183357312
#       From worker 7:	fold: 2, 52.81432600525442
#       From worker 4:	fold: 4, 145.20893815771103
#       From worker 7:	fold: 3, 18.929152023360622
#       From worker 6:	fold: 2, 31.81080377584844
#       From worker 5:	fold: 2, 20.146869313596877
#       From worker 7:	fold: 4, 32.68812811096941
#       From worker 7:	fold: 5, 25.37763727136871
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 28.70793968846996
#       From worker 7:	fold: 2, 153.8980290894867
#       From worker 7:	fold: 3, 24.82316150123925
#       From worker 7:	fold: 4, 71.36044126657661
#       From worker 8:	fold: 4, 100.67150355763927
#       From worker 4:	fold: 5, 144.391072197205
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 85.2429795913914
#       From worker 7:	fold: 5, 120.94498753952551
#       From worker 7:	errors: 0
#       From worker 7:	fold: 1, 1600.9031777769026
#       From worker 6:	fold: 3, 108.50843240593056
#       From worker 3:	fold: 2, 86.30699530627439
#       From worker 7:	fold: 2, 2208.143223911911
#       From worker 4:	fold: 2, 108.05841467609181
#       From worker 5:	fold: 3, 26.882079601676992
#       From worker 7:	fold: 3, 51.61181039054583
#       From worker 7:	fold: 4, 264.8079392278796
#       From worker 7:	fold: 5, 74.85492718511715
#       From worker 7:	errors: 0
#       From worker 7:	fold: 2, 64.4663286404042
#       From worker 4:	fold: 3, 140.78282268620137
#       From worker 7:	fold: 3, 28.516745267977218
#       From worker 7:	fold: 4, 38.33752879706382
#       From worker 7:	fold: 5, 110.07363790165566
#       From worker 7:	errors: 0
#       From worker 4:	fold: 4, 85.81773042537405
#       From worker 6:	fold: 4, 14.240898838120076
#       From worker 3:	fold: 3, 135.7603638699676
#       From worker 4:	fold: 5, 94.57309236774874
#       From worker 5:	fold: 4, 27.108745092484895
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 11.649104590008566
#       From worker 4:	fold: 2, 27.03408050454695
#       From worker 4:	fold: 3, 60.887101347217616
#       From worker 4:	fold: 4, 33.35383846739577
#       From worker 4:	fold: 5, 19.914487686048815
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 105.12533269208875
#       From worker 8:	fold: 5, 30.699871591243298
#       From worker 8:	errors: 0
#       From worker 6:	fold: 5, 45.20628206525036
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 48.46124604999007
#       From worker 4:	fold: 2, 360.916229308952
#       From worker 6:	fold: 2, 11.566206357827225
#       From worker 4:	fold: 3, 68.77942003907057
#       From worker 4:	fold: 4, 59.29928264089769
#       From worker 6:	fold: 3, 34.38065777739096
#       From worker 5:	fold: 5, 49.04772229810541
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 20.108543275929136
#       From worker 6:	fold: 4, 32.85643313380024
#       From worker 4:	fold: 5, 183.2097594545022
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 96.89380935151222
#       From worker 6:	fold: 5, 100.93691477433597
#       From worker 6:	errors: 0
#       From worker 3:	fold: 4, 79.10147930640196
#       From worker 6:	fold: 1, 92.24955334864539
#       From worker 5:	fold: 2, 118.80413658152789
#       From worker 6:	fold: 2, 10.407509350467835
#       From worker 5:	fold: 3, 71.16747822141214
#       From worker 6:	fold: 3, 28.168909106348842
#       From worker 5:	fold: 4, 152.90531056421895
#       From worker 6:	fold: 4, 23.756455557887886
#       From worker 5:	fold: 5, 43.127486287704734
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 128.92449312216038
#       From worker 5:	fold: 2, 71.99101523207813
#       From worker 5:	fold: 3, 369.08283157756904
#       From worker 5:	fold: 4, 843.271450238652
#       From worker 6:	fold: 5, 186.53493365077418
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 127.12206094616299
#       From worker 5:	fold: 5, 136.83185150790962
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 24.31707141101428
#       From worker 3:	fold: 5, 18.69611269592307
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 112.79902663279465
#       From worker 3:	fold: 2, 122.67107446888087
#       From worker 3:	fold: 3, 168.11868346020378
#       From worker 3:	fold: 4, 2764.2817572206077
#       From worker 3:	fold: 5, 49.2396192748194
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 14.753250098865692
#       From worker 3:	fold: 2, 176.5177600252156
#       From worker 3:	fold: 3, 11.965824590943066
#       From worker 3:	fold: 4, 83.66349785539714
#       From worker 3:	fold: 5, 76.23806940171218
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 94832.76856685319
#       From worker 3:	fold: 2, 90641.70364863783
#       From worker 4:	fold: 2, 24.924487335703585
#       From worker 3:	fold: 3, 15043.077804233515
#       From worker 3:	fold: 4, 157115.17008092022
#       From worker 3:	fold: 5, 96710.10412576197
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 135.5528716880967
#       From worker 6:	fold: 2, 52.49396609837322
#       From worker 5:	fold: 2, 70.47424433680875
#       From worker 4:	fold: 3, 70.40265312604585
#       From worker 3:	fold: 2, 51.81221200826506
#       From worker 6:	fold: 3, 22.490230154362013
#       From worker 5:	fold: 3, 73.75230240958888
#       From worker 4:	fold: 4, 33.55991876406951
#       From worker 3:	fold: 3, 50.99790011856359
#       From worker 6:	fold: 4, 50.916250661045765
#       From worker 5:	fold: 4, 125.35404578603942
#       From worker 3:	fold: 4, 39.760632559375004
#       From worker 4:	fold: 5, 55.69459481107442
#       From worker 4:	errors: 0
#       From worker 4:	fold: 1, 143.85496457352068
#       From worker 4:	fold: 2, 38.20768576491582
#       From worker 4:	fold: 3, 32.70003307722844
#       From worker 4:	fold: 4, 25.404398756557857
#       From worker 4:	fold: 5, 52.99512789523824
#       From worker 4:	errors: 0
#       From worker 6:	fold: 5, 30.297574779144544
#       From worker 6:	errors: 0
#       From worker 6:	fold: 1, 139.70275345048273
#       From worker 5:	fold: 5, 27.527487143028505
#       From worker 5:	errors: 0
#       From worker 5:	fold: 1, 116.55298869676494
#       From worker 6:	fold: 2, 30.408801761477836
#       From worker 6:	fold: 3, 40.958499437432806
#       From worker 5:	fold: 2, 61.621179268748655
#       From worker 6:	fold: 4, 22.65122659038507
#       From worker 6:	fold: 5, 53.306052878980594
#       From worker 6:	errors: 0
#       From worker 5:	fold: 3, 59.14114578415045
#       From worker 5:	fold: 4, 32.60949531401328
#       From worker 5:	fold: 5, 21.654968961832065
#       From worker 5:	errors: 0
#       From worker 3:	fold: 5, 102.48342420483817
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 144.57413719455164
#       From worker 3:	fold: 1, 91.83458826614608
#       From worker 3:	fold: 2, 15.601437003851505
#       From worker 3:	fold: 3, 80.2773066935709
#       From worker 2:	fold: 2, 27.562728498396623
#       From worker 3:	fold: 4, 42.15941902978027
#       From worker 2:	fold: 3, 32.53456717003425
#       From worker 2:	fold: 4, 90.34339190341242
#       From worker 2:	fold: 5, 58.176892183703146
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 47.44391312032226
#       From worker 2:	fold: 2, 91.02667431937745
#       From worker 3:	fold: 5, 7.779669561677039
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 15.225349185239784
#       From worker 2:	fold: 3, 57.941644124958955
#       From worker 3:	fold: 2, 91.96251546571686
#       From worker 3:	fold: 3, 29.75866961606728
#       From worker 3:	fold: 4, 46.037700838360536
#       From worker 2:	fold: 4, 12.900984864356335
#       From worker 3:	fold: 5, 18.940405830797047
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 36.94207333526575
#       From worker 3:	fold: 2, 41.810339234529785
#       From worker 3:	fold: 3, 88.71838731567897
#       From worker 3:	fold: 4, 95.58317410481166
#       From worker 3:	fold: 5, 153.10477916562587
#       From worker 3:	errors: 0
#       From worker 3:	fold: 2, 53.665833383982516
#       From worker 3:	fold: 1, 43.84529926242029
#       From worker 2:	fold: 5, 43.744936403599134
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 66.77722972056031
#       From worker 2:	fold: 2, 11.83454867244406
#       From worker 2:	fold: 3, 156.7594120128694
#       From worker 2:	fold: 4, 42.29085183834277
#       From worker 2:	fold: 5, 117.91403432024373
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 183.5618598096251
#       From worker 3:	fold: 2, 167.41087525604405
#       From worker 2:	fold: 2, 30.239606484935308
#       From worker 2:	fold: 3, 31.47728155606121
#       From worker 2:	fold: 4, 76.3474209352422
#       From worker 2:	fold: 5, 33.8177055708201
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 101.10070186728771
#       From worker 3:	fold: 3, 38.039058261700994
#       From worker 3:	fold: 4, 45.62134637984343
#       From worker 3:	fold: 5, 62.507858869844256
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 57.72307260147319
#       From worker 3:	fold: 2, 185.84589396061781
#       From worker 3:	fold: 3, 25.279187903178435
#       From worker 3:	fold: 4, 14.394060261773857
#       From worker 3:	fold: 5, 35.979738200112834
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 45.957690447132926
#       From worker 2:	fold: 2, 35.40683669457036
#       From worker 3:	fold: 2, 156.0032201895342
#       From worker 2:	fold: 3, 43.41974763553166
#       From worker 3:	fold: 3, 40.160578632259664
#       From worker 2:	fold: 4, 8.617529090661925
#       From worker 3:	fold: 4, 29.359984139040773
#       From worker 2:	fold: 5, 77.41083189765206
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 37.32663429549302
#       From worker 2:	fold: 2, 115.41108780829144
#       From worker 2:	fold: 3, 62.73399783324024
#       From worker 2:	fold: 4, 41.25838410264368
#       From worker 2:	fold: 5, 149.63921358859633
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 58.495573994667396
#       From worker 2:	fold: 2, 75.06298549611718
#       From worker 2:	fold: 3, 94.36346836701007
#       From worker 2:	fold: 4, 159.20120415879006
#       From worker 2:	fold: 5, 46.20625480364579
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 2277.0161772945353
#       From worker 2:	fold: 2, 13085.661510505823
#       From worker 2:	fold: 3, 104.29715934345246
#       From worker 2:	fold: 4, 103.98384961010574
#       From worker 2:	fold: 5, 141.7501891410604
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 126.32567446528746
#       From worker 2:	fold: 1, 37.06618481089308
#       From worker 3:	fold: 5, 21.35437014610796
#       From worker 3:	errors: 0
#       From worker 3:	fold: 1, 126.28593770464931
#       From worker 3:	fold: 3, 82.99002881990941
#       From worker 3:	fold: 2, 50.12788696510075
#       From worker 3:	fold: 4, 92.59136078381945
#       From worker 3:	fold: 3, 41.98472816746738
#       From worker 3:	fold: 5, 54.97526772493029
#       From worker 3:	errors: 0
#       From worker 3:	fold: 4, 54.42682851609936
#       From worker 3:	fold: 5, 23.538719374293883
#       From worker 3:	errors: 0
#       From worker 2:	fold: 2, 104.51831712005628
#       From worker 2:	fold: 3, 88.77036049099773
#       From worker 2:	fold: 4, 25.838096429005265
#       From worker 2:	fold: 5, 90.8689382312113
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 29.17662776121492
#       From worker 2:	fold: 2, 28.158053531375185
#       From worker 2:	fold: 3, 12.387837333108902
#       From worker 2:	fold: 4, 53.30233284961427
#       From worker 2:	fold: 5, 130.7174133316588
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 18.847677096716797
#       From worker 2:	fold: 2, 51.494643934273846
#       From worker 2:	fold: 3, 28.336231026134968
#       From worker 2:	fold: 4, 30.419099268667168
#       From worker 2:	fold: 5, 7.839565064083124
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 12.800872039445087
#       From worker 2:	fold: 2, 63.80744392481652
#       From worker 2:	fold: 3, 155.51953776153138
#       From worker 2:	fold: 4, 73.55918346100198
#       From worker 2:	fold: 5, 103.88166314967317
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 56.04206639600167
#       From worker 2:	fold: 1, 18.558801451095768
#       From worker 2:	fold: 2, 136.59360823314293
#       From worker 2:	fold: 3, 31.637565462219452
#       From worker 2:	fold: 4, 65.26777036456619
#       From worker 2:	fold: 5, 14.420978940291489
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 73.27481433444717
#       From worker 2:	fold: 2, 48.15054119247677
#       From worker 2:	fold: 3, 47.86219004603641
#       From worker 2:	fold: 4, 49.50979249922642
#       From worker 2:	fold: 5, 45.36132772199263
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 51.73824228335115
#       From worker 2:	fold: 2, 17.148875235285615
#       From worker 2:	fold: 3, 24.430114796063023
#       From worker 2:	fold: 4, 39.9483137168454
#       From worker 2:	fold: 5, 13.843404605397522
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 65.36266699675114
#       From worker 2:	fold: 2, 82.46739721925617
#       From worker 2:	fold: 3, 81.67537058547994
#       From worker 2:	fold: 4, 99.5459059301423
#       From worker 2:	fold: 5, 79.65116505474032
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 9.405303478117506
#       From worker 2:	fold: 1, 103.61087211284594
#       From worker 2:	fold: 2, 60.42336596683985
#       From worker 2:	fold: 3, 51.03759790515229
#       From worker 2:	fold: 4, 23.631230688000542
#       From worker 2:	fold: 5, 37.86705291678453
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 21.06231116439087
#       From worker 2:	fold: 2, 10.557832621828124
#       From worker 2:	fold: 3, 114.5780102372871
#       From worker 2:	fold: 4, 57.64645142511663
#       From worker 2:	fold: 5, 33.665419456687715
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 90.64315862491291
#       From worker 2:	fold: 2, 148.26286095294233
#       From worker 2:	fold: 3, 49.28443989964261
#       From worker 2:	fold: 4, 35.342715614116614
#       From worker 2:	fold: 5, 93.8645578928859
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 17.89195078817202
#       From worker 2:	fold: 2, 29.4049012151928
#       From worker 2:	fold: 3, 21.671781734207773
#       From worker 2:	fold: 4, 30.87389765845601
#       From worker 2:	fold: 5, 48.93905650768662
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 45.363367462716106
#       From worker 2:	fold: 2, 128.45919091238792
#       From worker 2:	fold: 3, 48.757337002752905
#       From worker 2:	fold: 4, 71.20347054963699
#       From worker 2:	fold: 5, 20.573178385414575
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 162.97995382073427
#       From worker 2:	fold: 2, 102.01900682919246
#       From worker 2:	fold: 3, 10.629822195908789
#       From worker 2:	fold: 4, 75.25912883816855
#       From worker 2:	fold: 5, 30.83112023611581
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 10.891351182589268
#       From worker 2:	fold: 2, 60.54076629118346
#       From worker 2:	fold: 3, 28.76676280945562
#       From worker 2:	fold: 4, 41.052382347289885
#       From worker 2:	fold: 5, 141.3054153464545
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 147.9730412696221
#       From worker 2:	fold: 2, 90.25959645843895
#       From worker 2:	fold: 3, 48.29637260741559
#       From worker 2:	fold: 4, 154.42903763353988
#       From worker 2:	fold: 5, 41.20334912497534
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 28.12059747160237
#       From worker 2:	fold: 2, 46.27627704320431
#       From worker 2:	fold: 3, 103.05662729659647
#       From worker 2:	fold: 4, 90.64137978419497
#       From worker 2:	fold: 5, 149.4284467234803
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 45.272609343628915
#       From worker 2:	fold: 2, 53.36567530977032
#       From worker 2:	fold: 3, 94.2452593979856
#       From worker 2:	fold: 4, 43.16728311398307
#       From worker 2:	fold: 5, 141.28450966948995
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 76.67813914173561
#       From worker 2:	fold: 2, 126.94316590778723
#       From worker 2:	fold: 3, 70.09142910493931
#       From worker 2:	fold: 4, 101.1941493175341
#       From worker 2:	fold: 5, 50.681170159595226
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 58.59484138869185
#       From worker 2:	fold: 1, 105.37486431884363
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/preprocessing/_data.py:2995: RuntimeWarning: divide by zero encountered in log
#       From worker 2:	  loglike = -n_samples / 2 * np.log(x_trans.var())
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/preprocessing/_data.py:2995: RuntimeWarning: divide by zero encountered in log
#       From worker 2:	  loglike = -n_samples / 2 * np.log(x_trans.var())
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	/Users/ppalmes/.julia/conda/3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:120: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#       From worker 2:	  ConvergenceWarning)
#       From worker 2:	fold: 2, 33.444015948235936
#       From worker 2:	fold: 3, 46.10959369949265
#       From worker 2:	fold: 4, 135.10863398592642
#       From worker 2:	fold: 5, 24.861537526664048
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 128.0506497440898
#       From worker 2:	fold: 1, 46.46854819784164
#       From worker 2:	fold: 2, 31.02951172128375
#       From worker 2:	fold: 3, 88.80601040860256
#       From worker 2:	fold: 4, 43.82918110849347
#       From worker 2:	fold: 5, 117.87566501345913
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 91.6521208746042
#       From worker 2:	fold: 2, 31.280454417957046
#       From worker 2:	fold: 3, 2.8505799881761114
#       From worker 2:	fold: 4, 10.869148296598896
#       From worker 2:	fold: 5, 40.75503636424105
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 113.35134408928816
#       From worker 2:	fold: 2, 48.28309882103406
#       From worker 2:	fold: 3, 21.518633065817248
#       From worker 2:	fold: 4, 71.51210134263748
#       From worker 2:	fold: 5, 30.12827828534123
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 143.56033356218313
#       From worker 2:	fold: 2, 47.002767417426895
#       From worker 2:	fold: 3, 26.620325881351253
#       From worker 2:	fold: 4, 16.716417014761614
#       From worker 2:	fold: 5, 48.01894836014237
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 31.467942439610948
#       From worker 2:	fold: 2, 42.281718723118296
#       From worker 2:	fold: 3, 47.39148529158125
#       From worker 2:	fold: 4, 89.28257604699469
#       From worker 2:	fold: 5, 41.410752848196466
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 45.348489284816566
#       From worker 2:	fold: 2, 18.115157092307967
#       From worker 2:	fold: 3, 33.14398835329611
#       From worker 2:	fold: 4, 90.01445358642437
#       From worker 2:	fold: 5, 12.101185333682304
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 154.08039418079522
#       From worker 2:	fold: 2, 41.19477157261
#       From worker 2:	fold: 3, 68.52779985659225
#       From worker 2:	fold: 4, 5.603236950634514
#       From worker 2:	fold: 5, 118.00970363150802
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 42.795952637281864
#       From worker 2:	fold: 2, 176.7461398874195
#       From worker 2:	fold: 3, 70.98475998242117
#       From worker 2:	fold: 4, 39.96674022175536
#       From worker 2:	fold: 5, 77.92124146327922
#       From worker 2:	errors: 0
#       From worker 2:	fold: 1, 22.960055943334773
#       From worker 2:	fold: 2, 72.30357549576023
#       From worker 2:	fold: 2, 6.413964456885369
#       From worker 2:	fold: 2, 46.891641534247256
#       From worker 2:	fold: 2, 58.722531548486415
#       From worker 2:	fold: 2, 33.18870401924597
#       From worker 2:	fold: 2, 125.1891721489908
#       From worker 2:	fold: 3, 82.36903844000825
#       From worker 2:	fold: 3, 113.39943325293711
#       From worker 2:	fold: 3, 132.1691253529019
#       From worker 2:	fold: 3, 34.144248531314766
#       From worker 2:	fold: 3, 11.976638845321798
#       From worker 2:	fold: 3, 64.98167365981206
#       From worker 2:	fold: 4, 24.942885593534992
#       From worker 2:	fold: 4, 7.066805939197229
#       From worker 2:	fold: 4, 21.512319353870684
#       From worker 2:	fold: 4, 125.7197700693177
#       From worker 2:	fold: 4, 56.03199022169869
#       From worker 2:	fold: 4, 38.24178927503411
#       From worker 2:	fold: 5, 25.19608130575137
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 50.83533126059941
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 32.0196123127454
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 67.34056114695306
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 48.282482344117675
#       From worker 2:	errors: 0
#       From worker 2:	fold: 5, 7.243764542358088
#       From worker 2:	errors: 0
# (serialtime = "16.0 minutes", paralleltime = "30.0 seconds")

# %%
dfres
# Out:
# 84×5 DataFrame
# │ Row │ pipeline                                                 │ mean    │ sd      │ time    │ folds │
# │     │ String                                                   │ Float64 │ Float64 │ Float64 │ Int64 │
# ├─────┼──────────────────────────────────────────────────────────┼─────────┼─────────┼─────────┼───────┤
# │ 1   │ StandardScaler |> Noop |> ARDRegression                  │ 27.3874 │ 16.1732 │ 8.38338 │ 5     │
# │ 2   │ MinMaxScaler |> Noop |> ARDRegression                    │ 29.4218 │ 16.0239 │ 9.56574 │ 5     │
# │ 3   │ RobustScaler |> Noop |> ARDRegression                    │ 29.7563 │ 11.9945 │ 20.9123 │ 5     │
# │ 4   │ MinMaxScaler |> FastICA |> ARDRegression                 │ 30.5677 │ 18.7811 │ 4.89073 │ 5     │
# │ 5   │ Noop |> FastICA |> ARDRegression                         │ 32.8489 │ 12.7548 │ 3.26554 │ 5     │
# │ 6   │ PowerTransformer |> Noop |> RandomForestRegressor        │ 35.4815 │ 34.8968 │ 23.558  │ 5     │
# │ 7   │ Noop |> Noop |> ARDRegression                            │ 39.7447 │ 30.9597 │ 23.8513 │ 5     │
# │ 8   │ PowerTransformer |> Noop |> GradientBoostingRegressor    │ 40.3849 │ 31.2169 │ 9.57607 │ 5     │
# │ 9   │ Noop |> FastICA |> GradientBoostingRegressor             │ 41.7552 │ 23.1393 │ 1.13656 │ 5     │
# │ 10  │ RobustScaler |> FastICA |> ARDRegression                 │ 44.255  │ 40.1707 │ 2.25392 │ 5     │
# │ 11  │ MinMaxScaler |> FastICA |> RandomForestRegressor         │ 44.3311 │ 32.1684 │ 5.32857 │ 5     │
# │ 12  │ StandardScaler |> FastICA |> RandomForestRegressor       │ 44.674  │ 37.4523 │ 5.18987 │ 5     │
# │ 13  │ Noop |> FastICA |> RandomForestRegressor                 │ 44.8769 │ 34.9637 │ 3.05092 │ 5     │
# │ 14  │ StandardScaler |> FastICA |> ARDRegression               │ 45.6403 │ 33.604  │ 5.09879 │ 5     │
# │ 15  │ Noop |> Noop |> rf                                       │ 46.7515 │ 44.0083 │ 21.2994 │ 5     │
# │ 16  │ RobustScaler |> Noop |> GradientBoostingRegressor        │ 47.502  │ 41.405  │ 20.9241 │ 5     │
# │ 17  │ RobustScaler |> Noop |> RandomForestRegressor            │ 47.5305 │ 37.6286 │ 9.57145 │ 5     │
# │ 18  │ MinMaxScaler |> FastICA |> GradientBoostingRegressor     │ 47.6559 │ 27.5743 │ 2.96489 │ 5     │
# │ 19  │ MinMaxScaler |> Noop |> rf                               │ 48.3996 │ 48.8144 │ 20.4013 │ 5     │
# │ 20  │ Noop |> Noop |> RandomForestRegressor                    │ 50.3669 │ 22.5058 │ 24.2348 │ 5     │
# │ 21  │ MinMaxScaler |> Noop |> RandomForestRegressor            │ 50.6116 │ 28.1353 │ 5.67853 │ 5     │
# │ 22  │ StandardScaler |> Noop |> RandomForestRegressor          │ 50.7485 │ 47.0339 │ 8.67172 │ 5     │
# │ 23  │ RobustScaler |> FastICA |> RandomForestRegressor         │ 51.3483 │ 24.9868 │ 11.1374 │ 5     │
# │ 24  │ StandardScaler |> Noop |> rf                             │ 51.7233 │ 46.2615 │ 23.3276 │ 5     │
# │ 25  │ Normalizer |> Noop |> GradientBoostingRegressor          │ 52.8317 │ 11.5258 │ 9.59312 │ 5     │
# │ 26  │ StandardScaler |> Noop |> RF_fromR                       │ 53.1911 │ 36.3335 │ 7.45931 │ 5     │
# │ 27  │ Noop |> Noop |> RF_fromR                                 │ 53.2957 │ 50.6676 │ 10.091  │ 5     │
# │ 28  │ StandardScaler |> FastICA |> GradientBoostingRegressor   │ 53.4787 │ 44.4352 │ 2.8694  │ 5     │
# │ 29  │ MinMaxScaler |> Noop |> RF_fromR                         │ 55.314  │ 30.3528 │ 11.4728 │ 5     │
# │ 30  │ RobustScaler |> Noop |> rf                               │ 55.5061 │ 43.8977 │ 29.2264 │ 5     │
# │ 31  │ MinMaxScaler |> FastICA |> RF_fromR                      │ 56.2951 │ 28.9337 │ 7.981   │ 5     │
# │ 32  │ Noop |> Noop |> GradientBoostingRegressor                │ 56.3838 │ 50.5398 │ 23.6758 │ 5     │
# │ 33  │ StandardScaler |> Noop |> GradientBoostingRegressor      │ 56.5113 │ 50.7351 │ 21.253  │ 5     │
# │ 34  │ Noop |> FastICA |> RF_fromR                              │ 56.664  │ 41.4662 │ 8.1928  │ 5     │
# │ 35  │ RobustScaler |> FastICA |> RF_fromR                      │ 56.7067 │ 37.1605 │ 5.39622 │ 5     │
# │ 36  │ RobustScaler |> FastICA |> GradientBoostingRegressor     │ 56.8446 │ 64.6801 │ 3.41056 │ 5     │
# │ 37  │ RobustScaler |> Noop |> RF_fromR                         │ 56.9587 │ 36.8886 │ 24.8325 │ 5     │
# │ 38  │ Noop |> FastICA |> rf                                    │ 57.4055 │ 47.4258 │ 8.52348 │ 5     │
# │ 39  │ StandardScaler |> FastICA |> rf                          │ 58.316  │ 36.7696 │ 8.77634 │ 5     │
# │ 40  │ PowerTransformer |> Noop |> RF_fromR                     │ 58.5672 │ 55.2934 │ 3.60424 │ 5     │
# │ 41  │ MinMaxScaler |> FastICA |> rf                            │ 58.6324 │ 48.7043 │ 8.34498 │ 5     │
# │ 42  │ PowerTransformer |> Noop |> rf                           │ 59.2728 │ 39.2864 │ 3.78372 │ 5     │
# │ 43  │ RobustScaler |> FastICA |> rf                            │ 61.7609 │ 31.73   │ 4.77481 │ 5     │
# │ 44  │ MinMaxScaler |> Noop |> GradientBoostingRegressor        │ 62.8713 │ 40.823  │ 21.104  │ 5     │
# │ 45  │ PowerTransformer |> Noop |> GaussianProcessRegressor     │ 63.8444 │ 70.0551 │ 1.69715 │ 5     │
# │ 46  │ StandardScaler |> FastICA |> RF_fromR                    │ 64.285  │ 41.249  │ 8.34569 │ 5     │
# │ 47  │ Normalizer |> Noop |> RandomForestRegressor              │ 65.6018 │ 36.4224 │ 23.1806 │ 5     │
# │ 48  │ Normalizer |> Noop |> rf                                 │ 66.2275 │ 42.712  │ 22.579  │ 5     │
# │ 49  │ StandardScaler |> FastICA |> SVR                         │ 68.2235 │ 73.3131 │ 5.35489 │ 5     │
# │ 50  │ PowerTransformer |> FastICA |> rf                        │ 68.9044 │ 34.0905 │ 28.6788 │ 5     │
# │ 51  │ PowerTransformer |> FastICA |> RF_fromR                  │ 68.9797 │ 48.5538 │ 23.5677 │ 5     │
# │ 52  │ Normalizer |> Noop |> RF_fromR                           │ 69.4124 │ 35.3996 │ 8.76084 │ 5     │
# │ 53  │ StandardScaler |> Noop |> GaussianProcessRegressor       │ 71.0888 │ 65.7737 │ 5.37545 │ 5     │
# │ 54  │ PowerTransformer |> Noop |> ARDRegression                │ 71.4849 │ 54.3918 │ 1.60542 │ 5     │
# │ 55  │ Normalizer |> FastICA |> SVR                             │ 72.6277 │ 67.0024 │ 5.86841 │ 5     │
# │ 56  │ PowerTransformer |> FastICA |> ARDRegression             │ 75.4671 │ 42.2138 │ 21.6922 │ 5     │
# │ 57  │ Normalizer |> FastICA |> RF_fromR                        │ 76.1214 │ 41.1439 │ 8.6391  │ 5     │
# │ 58  │ RobustScaler |> Noop |> GaussianProcessRegressor         │ 76.3438 │ 60.324  │ 21.0554 │ 5     │
# │ 59  │ Noop |> Noop |> SVR                                      │ 77.4832 │ 59.3155 │ 23.8467 │ 5     │
# │ 60  │ PowerTransformer |> FastICA |> RandomForestRegressor     │ 77.9058 │ 41.8117 │ 6.03575 │ 5     │
# │ 61  │ MinMaxScaler |> Noop |> SVR                              │ 79.1152 │ 58.2428 │ 5.36932 │ 5     │
# │ 62  │ Noop |> FastICA |> SVR                                   │ 79.9469 │ 56.7613 │ 3.44528 │ 5     │
# │ 63  │ MinMaxScaler |> FastICA |> SVR                           │ 81.2226 │ 54.4014 │ 5.29479 │ 5     │
# │ 64  │ Normalizer |> Noop |> ARDRegression                      │ 81.2739 │ 49.2836 │ 6.75394 │ 5     │
# │ 65  │ Noop |> Noop |> GaussianProcessRegressor                 │ 81.683  │ 55.7182 │ 23.8586 │ 5     │
# │ 66  │ MinMaxScaler |> Noop |> GaussianProcessRegressor         │ 81.7405 │ 12.1466 │ 9.57902 │ 5     │
# │ 67  │ StandardScaler |> Noop |> SVR                            │ 81.9137 │ 52.618  │ 8.39267 │ 5     │
# │ 68  │ PowerTransformer |> Noop |> SVR                          │ 83.2318 │ 47.2318 │ 5.76803 │ 5     │
# │ 69  │ RobustScaler |> Noop |> SVR                              │ 83.4795 │ 44.279  │ 20.868  │ 5     │
# │ 70  │ PowerTransformer |> FastICA |> SVR                       │ 83.5047 │ 48.043  │ 21.4446 │ 5     │
# │ 71  │ PowerTransformer |> FastICA |> GaussianProcessRegressor  │ 85.1176 │ 29.5411 │ 21.8448 │ 5     │
# │ 72  │ Normalizer |> FastICA |> rf                              │ 85.7593 │ 37.0512 │ 13.8154 │ 5     │
# │ 73  │ Normalizer |> Noop |> SVR                                │ 86.6659 │ 44.401  │ 6.77195 │ 5     │
# │ 74  │ RobustScaler |> FastICA |> SVR                           │ 87.8697 │ 39.3778 │ 2.16813 │ 5     │
# │ 75  │ PowerTransformer |> FastICA |> GradientBoostingRegressor │ 96.4323 │ 53.445  │ 21.3781 │ 5     │
# │ 76  │ Normalizer |> FastICA |> RandomForestRegressor           │ 102.565 │ 46.455  │ 4.02687 │ 5     │
# │ 77  │ Normalizer |> FastICA |> GradientBoostingRegressor       │ 102.895 │ 23.101  │ 4.54485 │ 5     │
# │ 78  │ MinMaxScaler |> FastICA |> GaussianProcessRegressor      │ 155.466 │ 124.776 │ 4.97202 │ 5     │
# │ 79  │ StandardScaler |> FastICA |> GaussianProcessRegressor    │ 310.02  │ 319.098 │ 5.45786 │ 5     │
# │ 80  │ Normalizer |> FastICA |> ARDRegression                   │ 643.422 │ 1186.36 │ 5.81016 │ 5     │
# │ 81  │ RobustScaler |> FastICA |> GaussianProcessRegressor      │ 689.701 │ 923.959 │ 2.14206 │ 5     │
# │ 82  │ Noop |> FastICA |> GaussianProcessRegressor              │ 840.064 │ 998.579 │ 3.70261 │ 5     │
# │ 83  │ Normalizer |> Noop |> GaussianProcessRegressor           │ 3142.54 │ 5636.56 │ 6.80266 │ 5     │
# │ 84  │ Normalizer |> FastICA |> GaussianProcessRegressor        │ 90868.6 │ 50467.8 │ 5.96881 │ 5     │
